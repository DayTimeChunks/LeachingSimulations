# %% [markdown]
# START NOTEBOOK

# %% [markdown]
# ## Set-up

# %%
from hydroplots import *
from leach_hydrology import *
import numpy as np

import mpld3
mpld3.enable_notebook()

# Plot graphs within this document
# %matplotlib inline

# Plot graphs outside (for interaction)
# %matplotlib

from pestmob import *
from mixinglayer import *

# %% [markdown]
# ### Pesticide, soil type and runoff calibration parameter.

# %%
# Soil and pesticide
pesticide = 'Cupper'
initial_condition = 'mean'
soil_type = 'Crop Soil'
soil = 'Alteck'
soil_short = 'Crop'

pesti_obs = choose_pesticide(
    pesticide,
    soil)

# Kd ranges to test
Kd_pest_sterile = pesti_obs[0]
Kd_pest_living = pesti_obs[1]

# Initial concentrations and mass out observed
pest_dict_S_1st = pesti_obs[2]
pest_dict_L_1st = pesti_obs[3]
pest_dict_S_2nd = pesti_obs[4]
pest_dict_L_2nd = pesti_obs[5]

# Assumed (used to calculate Reynolds number)
runoff_vel = 10.0  # mm/min

# %% [markdown]
# ### Microcosm

# %%
d = (14.93 * 2)  # Diameter of falcon tube (mm)
area = ((d / 2) ** 2) * 3.1416  # (mm2)
soil_height1 = 20  # Mixing layer depth in mm
soil_height2 = 20  # mm

# %% [markdown]
# ### Soil hydrological characteristics

# %%
if soil == 'Alteck':
    kSat = 2.24  # mm/min (13.45 cm/h - Crop Soil) 
    psi = 1100  # soil suction Alteck (mm)
    eff_height = 0.80
elif soil == 'Rouff': 
    kSat = 17.62*10/60  # mm/min (17.62 cm/h - Vine Soil) 
    psi = 1100  # soil suction Alteck (mm)
    eff_height = 0.76
    
# Soil characteristics (Equivalent for Alteck and Rouffach)
# Initial bulk density options:
pb_i0 = 0.99/10**3  # bulk density (g/cm^3) -> g/mm^3  (M. Trautmann)
pb_i1 = 2.61/10**3 # inital 1st pulse, calc. from experiment cond.
pb_i2 = 3.59/10**3 # initial 2nd pulse, calc. from experiment cond.

# Final bulk density options (1st and 2nd pulses)
pb_f1 = 3.59/10**3 # final1, calculated from experimental conditions.
pb_f2 = 3.76/10**3 # final2, calculated from experimental conditions.

# %% [markdown]
# ### Store results

# %%
output_hydro_params = {
    soil_short : [{'R1_FA':[],
              'R2_ALL':[],
              'Err1':[{'Fresh':[], 'Aged':[]}],
              'Err2':[{'SF':[], 'SA':[], 'LF':[], 'LA':[]}],
              'Ksat2':[{'SF':[], 'SA':[], 'LF':[], 'LA':[]}]
             }]
    }

# %%
output_pesti_params = {
    soil_short: {'R1': {'SF': None, 'SA': None, 'LF': None, 'LA': None},
                 'R2': {'SF': None, 'SA': None, 'LF': None, 'LA': None},
                 'Err1': {'SF': [], 'SA': [], 'LF': [], 'LA': [],
                          'SFmax': [], 'SAmax': [], 'LFmax': [], 'LAmax': [],
                          'SFmin': [], 'SAmin': [], 'LFmin': [], 'LAmin': []},
                 'Err2': {'SF': [], 'SA': [], 'LF': [], 'LA': [],
                          'SFmax': [], 'SAmax': [], 'LFmax': [], 'LAmax': [],
                          'SFmin': [], 'SAmin': [], 'LFmin': [], 'LAmin': []},
                 'Koc1': {'SF': None, 'SA': None, 'LF': None, 'LA': None},
                 'Koc2': {'SF': None, 'SA': None, 'LF': None, 'LA': None},
                 'Kd1': {'SF': None, 'SA': None, 'LF': None, 'LA': None},
                 'Kd2': {'SF': None, 'SA': None, 'LF': None, 'LA': None}
                 }
}

# %% [markdown]
# ## Hydrology - 1st pulse

# %% [markdown]
# #### Computation

# %%
water_data = leachsim(kSat = kSat,
                      soil_height=soil_height1,
                      eff_height=eff_height,
                      soil = 'Alteck',
                      psi=psi)
# Out:
# Mass balance True
# Mass balance 0.0
# Mass balance 0.0

# %%
water_eval = leachsim2(
    kSat = [kSat],
    soil_height=soil_height1,
    eff_height = eff_height,
    soil = 'Alteck',
    isAGED = False,
    isFirstCycle=True 
)

output_hydro_params = extract_goodness(
    water_eval,
    output_hydro_params,
    soil_short,
    isFirstCycle = True,
    isAGED = False)
# Out:
# FRESH
# --------------------------------------------
# ksat high:  13.440000000000001 cm/h
# ksat med12:  13.440000000000001 cm/h
# ksat med30:  13.440000000000001 cm/h
# ksat low:  13.440000000000001 cm/h
# --------------------------------------------
# R2:  0.979293137692
# --------------------------------------------
# Simulation error percent (%), by modality
# --------------------------------------------
# 135 mm/h - 6min  -1.6576800421
# 55 mm/h - 12min  29.7621075344
# 55 mm/h - 30min  0.193397570593
# 30 mm/h - 30min  -4.44276801315
# --------------------------------------------
# Mass balance:  True True True True

# %%
water_eval = leachsim2(
    kSat = [kSat],
    soil_height=soil_height1,
    eff_height = eff_height,
    soil = 'Alteck',
    isAGED = True,
    isFirstCycle=True 
)

output_hydro_params = extract_goodness(
    water_eval,
    output_hydro_params,
    soil_short,
    isFirstCycle = True,
    isAGED = True)
# Out:
# AGED
# --------------------------------------------
# ksat high:  13.440000000000001 cm/h
# ksat med12:  13.440000000000001 cm/h
# ksat med30:  13.440000000000001 cm/h
# ksat low:  13.440000000000001 cm/h
# --------------------------------------------
# R2:  0.978791656648
# --------------------------------------------
# Simulation error percent (%), by modality
# --------------------------------------------
# 135 mm/h - 6min  -9.94976957607
# 55 mm/h - 12min  -19.8638562158
# 55 mm/h - 30min  -4.35039476974
# 30 mm/h - 30min  -15.6438758946
# --------------------------------------------
# Mass balance:  True True True True

# %%
title = "Percolated Volume [mL] - " + str(soil_type) + "1st Pulse"

# %%
extract_and_plothydro(
    water_data,
    "Percolated at 135mm/h", "Percolated at 55mm/h", "Percolated at 30mm/h", "NA",
    title,
    soil,
    isFirstCycle = True,
    isPercolation = True
)

# %%
hydro1 = extract(
    water_data, 
    isFirstCycle = True
)

percol_data1 = hydro1[0]
runoff_data1 = hydro1[1]
time_sizes1 = hydro1[2]

# %% [markdown]
# ## Transport - 1st pulse

# %% [markdown]
# ### Computation transport - 1st pulse

# %% [markdown]
# #### Test factor X (Sterile)

# %%
x = 2

# %%
pest_sterile_1st = pest_linear_x(
    Kd_pest_sterile,
    x,
    initial_condition,
    pest_dict_S_1st,          
    pb_i1, pb_f1,
    percol_data1, runoff_data1,
    time_sizes1,
    area, soil_height1, 
    d, runoff_vel,
    soil,
    isFirstCycle = True,
    isLiving = False,
    KFILM = True)

output_pesti_params = extract_goodness_pest(
        pest_sterile_1st,
        output_pesti_params,
        soil_short,
        isLiving = False,
        isFirstCycle = True)
# Out:
# 1st Pulse
# Sterile Crop
# --------------------------------------------
# Koc tested:  [  5.60868490e+01   1.40883795e+02   1.77362190e+02   3.53884093e+02
#    7.06091594e+02   2.23285767e+03   2.23285767e+04   2.23285767e+07]
# Best Kd (Fresh):  3.16227766017 cm3/g ( Num:  2 )
#  x factor:  2
#  R2:  0.48085270294
#  Effective Koc (fresh) - [cm3/g]: 70.4418974465
# --------------------------------------------
# Best Kd (Aged):  1.25892541179 cm3/g ( Num:  1 )
#  x factor: No factor considered.
#  R2:  -0.420226279394
#  Effective Koc (aged) [cm3/g]: 56.0868489617
# --------------------------------------------
# --------------------------------------------
# Scenario - modality - Predicted error prcnt (%) | Predicted | Observed |
# --------------------------------------------
# (A) 135 mm/h - Fresh  266.287395987 | 31.5007160549 | 8.6
# (A) 135 mm/h - Aged  229.842763627 | 46.1779869078 | 14.0
# (B) 55 mm/h - Fresh  248.825090104 | 32.0919082896 | 9.2
# (B) 55 mm/h - Aged  235.794596776 | 47.0112435486 | 14.0
# (C) 55 mm/h - Fresh  -65.9963856581 | 114.116129731 | 335.6
# (C) 55 mm/h - Aged  -49.1030141722 | 141.493620601 | 278.0
# (D) 30 mm/h - Fresh  368.049819452 | 114.383439933 | 20.5
# (D) 30 mm/h - Aged  485.468373339 | 141.578004963 | 21.6

# %% [markdown]
# #### Test factor X (Living)

# %%
x = 2

# %%
pest_living_1st = pest_linear_x(
    Kd_pest_living,
    x,
    initial_condition,
    pest_dict_L_1st,          
    pb_i1, pb_f1,
    percol_data1, percol_data1,
    time_sizes1,
    area, soil_height1, 
    d, runoff_vel,
    soil,
    KFILM = True,
    isFirstCycle = True,
    isLiving = True)


output_pesti_params = extract_goodness_pest(
        pest_living_1st,
        output_pesti_params,
        soil_short,
        isLiving = True,
        isFirstCycle = True)
# Out:
# 1st Pulse
# Living Crop
# --------------------------------------------
# Koc tested:  [  3.93931226e+01   9.89510501e+01   1.24571992e+02   2.48553800e+02
#    4.95930031e+02   1.56826846e+03   1.56826846e+04   1.56826846e+07]
# Best Kd (Fresh):  15.8489319246 cm3/g ( Num:  5 )
#  x factor:  2
#  R2:  0.66157950573
#  Effective Koc (fresh) - [cm3/g]: 247.965015405
# --------------------------------------------
# Best Kd (Aged):  1.25892541179 cm3/g ( Num:  1 )
#  x factor: No factor considered.
#  R2:  1.0
#  Effective Koc (aged) [cm3/g]: 39.393122592
# --------------------------------------------
# --------------------------------------------
# Scenario - modality - Predicted error prcnt (%) | Predicted | Observed |
# --------------------------------------------
# (A) 135 mm/h - Fresh  207.362443779 | 2.15153710646 | 0.7
# (A) 135 mm/h - Aged  No obs | 43.0818306201 | nan
# (B) 55 mm/h - Fresh  445.006176804 | 2.18002470722 | 0.4
# (B) 55 mm/h - Aged  No obs | 43.5206623185 | nan
# (C) 55 mm/h - Fresh  -45.4957615981 | 21.8016953608 | 40.0
# (C) 55 mm/h - Aged  No obs | 127.758328589 | nan
# (D) 30 mm/h - Fresh  558.660238973 | 29.8791622721 | 1.5
# (D) 30 mm/h - Aged  No obs | 129.962051285 | nan

# %% [markdown]
# #### Time series

# %%
data_stack = pest_sterile_1st['Data_stack']
sterile1 = extract_pest(data_stack)

mass_percol_sterile1 = sterile1[0]
mass_pond_sterile1 = sterile1[1]

# %%
data_stack = pest_living_1st['Data_stack']
living1 = extract_pest(data_stack)

mass_percol_living1 = living1[0]
mass_pond_living1 = living1[1]

# %% [markdown]
# ## Plotting transport

# %% [markdown]
# ### Sterile (1st Pulse, Crop Soil)

# %%
pestiplot_condition(
    mass_percol_sterile1,
    pest_dict_S_1st,
    pesticide,
    soil_type,
    cycle = '1st pulse',
    LEACH = True,
    STERILE = True
)

# %% [markdown]
# ### Living (1st Pulse, Crop Soil)

# %%
pestiplot_condition(
    mass_percol_living1,
    pest_dict_L_1st,
    pesticide,
    soil_type,
    cycle = '1st pulse',
    LEACH = True,
    STERILE = False
)

# %% [markdown]
# # Hydrology - 2nd pulse

# %% [markdown]
# ### Inverse Ksat determination
#
# Based on hisotric rainfall pattern, fresh and aged.

# %%
water2_ktest = leachsim3(
    soil,
    kSat = [ kSat/5, kSat/10, kSat/15,
        kSat/25, kSat/50,  kSat/75, 
        kSat/100, kSat/125, kSat/150, 
        kSat/175, kSat/200, kSat/250,
        kSat/350, kSat/500, kSat/700, kSat/1000],
    soil_height=soil_height2,
    isFirstCycle = False
)

output_hydro_params = extract_goodness(
    water2_ktest,
    output_hydro_params,
    soil_short,
    isFirstCycle = False,
    isAGED = None
)
# Out:
# R2:  0.987094816986
# --------------------------------------------
# Sterile, Fresh Soil
# ksat high:  0.5376000000000001 cm/h | Error % 2.23130461905
# ksat med12:  0.5376000000000001 cm/h | Error % 3.03794067885
# ksat med30:  0.07680000000000001 cm/h | Error % -1.32673504375
# ksat low:  2.6880000000000006 cm/h | Error % 2.71814968991
# --------------------------------------------
# Sterile, Aged Soil
# ksat high:  0.038400000000000004 cm/h | Error % -3.96936053404
# ksat med12:  0.01344 cm/h | Error % 96.4892134055
# ksat med30:  0.01344 cm/h | Error % 0.668887214674
# ksat low:  0.01344 cm/h | Error % 772.613137848
# --------------------------------------------
# Living, Fresh Soil
# ksat high:  0.17920000000000003 cm/h | Error % 1.83525165621
# ksat med12:  0.5376000000000001 cm/h | Error % 1.25918043976
# ksat med30:  0.01344 cm/h | Error % 43.2893178308
# ksat low:  0.05376 cm/h | Error % -1.06637611809
# --------------------------------------------
# Living, Fresh Aged
# ksat high:  0.07680000000000001 cm/h | Error % 0.104102352786
# ksat med12:  0.17920000000000003 cm/h | Error % 2.93205693237
# ksat med30:  0.17920000000000003 cm/h | Error % -4.2848362011
# ksat low:  0.01344 cm/h | Error % 5.43538356862
# --------------------------------------------

# %% [markdown]
# ### Percolation - 2nd pulse

# %%
title = "Percolated Volume [mL] - " + str(soil_type) +  " 2nd Pulse"

# %%
extract_and_plothydro(
    water2_ktest,
    "Leached, 135mm/h", "Leached, 55mm/h - A", "Leached, 55mm/h - B", "Leached, 30mm/h",
    title,
    soil,
    isFirstCycle = False,
    isPercolation = True
)

# %% [markdown]
# ### Ponding - 2nd pulse

# %%
title = "Ponded Volume [mL] [mL] - " + str(soil_type) +  " 2nd Pulse"

# %%
extract_and_plothydro(
    water2_ktest,
    "Ponded, 135mm/h", "Ponded, 55mm/h - A", "Ponded, 55mm/h - B", "Ponded, 30mm/h",
    title,
    soil,
    isFirstCycle = False,
    isPercolation = False
)

# %%
hydro2 = extract(
    water2_ktest,
    isFirstCycle = False
)
percol_data2 = hydro2[0]
runoff_data2 = hydro2[1]
time_sizes2 = hydro2[2]

# %% [markdown]
# ## Transport - 2nd pulse

# %% [markdown]
# ### Computation transport - 2nd Pulse

# %% [markdown]
# #### Kd optimal (sterile)

# %%
x = 2

# %%
pest_sterile_2nd = pest_linear_x(
    Kd_pest_sterile,
    x,
    initial_condition,
    pest_dict_S_2nd,
    pb_i2, pb_f2,
    percol_data2, runoff_data2,
    time_sizes2,
    area, soil_height2,
    d, runoff_vel,
    soil = "Alteck",
    isFirstCycle = False,
    isLiving = False)

output_pesti_params = extract_goodness_pest(
        pest_sterile_2nd,
        output_pesti_params,
        soil_short,
        isLiving = False,
        isFirstCycle = False)
# Out:
# 2nd Pulse
# Sterile Crop
# --------------------------------------------
# Koc tested:  [  5.60868490e+01   1.40883795e+02   1.77362190e+02   3.53884093e+02
#    7.06091594e+02   2.23285767e+03   2.23285767e+04   2.23285767e+07]
# Best Kd (Fresh):  15.8489319246 cm3/g ( Num:  5 )
#  x factor:  2
#  R2:  0.0637662823726
#  Effective Koc (fresh) - [cm3/g]: 353.045797127
# --------------------------------------------
# Best Kd (Aged):  15.8489319246 cm3/g ( Num:  5 )
#  x factor: No factor considered.
#  R2:  0.983634831605
#  Effective Koc (aged) [cm3/g]: 706.091594253
# --------------------------------------------
# --------------------------------------------
# Scenario - modality - Predicted error prcnt (%) | Predicted | Observed |
# --------------------------------------------
# (A) 135 mm/h - Fresh  -37.6666070838 | 3.02316955643 | 4.85
# (A) 135 mm/h - Aged  -86.147487633 | 0.102508591516 | 0.74
# (B) 55 mm/h - Fresh  -1.85328646355 | 6.30101900904 | 6.42
# (B) 55 mm/h - Aged  No obs | 0.116087077985 | nan
# (C) 55 mm/h - Fresh  39.1355216151 | 6.73415924617 | 4.84
# (C) 55 mm/h - Aged  -44.2448605083 | 0.680423213632 | 0.94
# (D) 30 mm/h - Fresh  74.0969117225 | 17.0839117046 | 8.61
# (D) 30 mm/h - Aged  No obs | 1.49652954366 | nan

# %% [markdown]
# #### Kd optimal (living)

# %%
x = 2

# %%
pest_living_2nd = pest_linear_x(
    Kd_pest_living,
    x,
    initial_condition,
    pest_dict_L_2nd,          
    pb_i1, pb_f1,
    percol_data2, runoff_data2,
    time_sizes1,
    area, soil_height1, 
    d, runoff_vel,
    soil = "Alteck",
    KFILM = True,
    isFirstCycle = False,
    isLiving = True)

output_pesti_params = extract_goodness_pest(
        pest_living_2nd,
        output_pesti_params,
        soil_short,
        isLiving = True,
        isFirstCycle = False)
# Out:
# 2nd Pulse
# Living Crop
# --------------------------------------------
# Koc tested:  [  3.93931226e+01   9.89510501e+01   1.24571992e+02   2.48553800e+02
#    4.95930031e+02   1.56826846e+03   1.56826846e+04   1.56826846e+07]
# Best Kd (Fresh):  50.1187233627 cm3/g ( Num:  6 )
#  x factor:  2
#  R2:  0.898415812074
#  Effective Koc (fresh) - [cm3/g]: 784.134228718
# --------------------------------------------
# Best Kd (Aged):  1.25892541179 cm3/g ( Num:  1 )
#  x factor: No factor considered.
#  R2:  1.0
#  Effective Koc (aged) [cm3/g]: 39.393122592
# --------------------------------------------
# --------------------------------------------
# Scenario - modality - Predicted error prcnt (%) | Predicted | Observed |
# --------------------------------------------
# (A) 135 mm/h - Fresh  -51.9098406737 | 0.283731940025 | 0.59
# (A) 135 mm/h - Aged  No obs | 34.4280763759 | nan
# (B) 55 mm/h - Fresh  -5.04009412644 | 1.03506297402 | 1.09
# (B) 55 mm/h - Aged  No obs | 87.2755796706 | nan
# (C) 55 mm/h - Fresh  No obs | 0.393459984859 | nan
# (C) 55 mm/h - Aged  No obs | 117.306873989 | nan
# (D) 30 mm/h - Fresh  54.566104336 | 2.46123870189 | 0.76
# (D) 30 mm/h - Aged  No obs | 112.577463832 | nan

# %% [markdown]
# #### Time series

# %%
data_stack = pest_sterile_2nd['Data_stack']
sterile2 = extract_pest(data_stack)

data_stack = pest_living_2nd['Data_stack']
living2 = extract_pest(data_stack)

mass_percol_sterile2 = sterile2[0]
mass_pond_sterile2 = sterile2[1]

mass_percol_living2 = living2[0]
mass_pond_living2 = living2[1]

# %% [markdown]
# ## Plotting transport

# %% [markdown]
# ### Sterile (2nd Pulse)

# %%
pestiplot_condition(
    mass_percol_sterile2,
    pest_dict_S_2nd,
    pesticide,
    soil_type,
    cycle = '2nd pulse',
    LEACH = True,
    STERILE = True
)

# %%
pestiplot_condition(
    mass_pond_sterile2,
    pest_dict_S_2nd,
    pesticide,
    soil_type,
    cycle = '2nd pulse',
    LEACH = False,
    STERILE = True
)

# %% [markdown]
# ### Living (2nd Pulse)

# %%
pestiplot_condition(
    mass_percol_living2,
    pest_dict_L_2nd,
    pesticide,
    soil_type,
    cycle = '2nd pulse',
    LEACH = True,
    STERILE = False
)

# %%
pestiplot_condition(
    mass_pond_living2,
    pest_dict_L_2nd,
    pesticide,
    soil_type,
    cycle = '2nd pulse',
    LEACH = False,
    STERILE = False
)

# %% [markdown]
# END NOTEBOOK

# %% [markdown]
# ### Max values

# %%
initial_condition = 'max'

# %% [markdown]
# #### 1st Pulse

# %%
Kd1_SF = output_pesti_params[soil_short]['Kd1']['SF']*10**3  # Convert back to mm3/g (model units)
Kd1_SA = output_pesti_params[soil_short]['Kd1']['SA']*10**3
Kd1_choice_sterile = [Kd1_SF, Kd1_SA]

Kd1_LF = output_pesti_params[soil_short]['Kd1']['LF']*10**3
Kd1_LA = output_pesti_params[soil_short]['Kd1']['LA']*10**3
Kd1_choice_living = [Kd1_LF, Kd1_LA]

# %%
max_sterile_1st = pest_Kd_choice(
    Kd1_choice_sterile,
    x,
    initial_condition,
    pest_dict_S_1st,          
    pb_i1, pb_f1,
    percol_data1, runoff_data1,
    time_sizes1,
    area, soil_height1, 
    d, runoff_vel,
    soil,
    isFirstCycle = True,
    isLiving = False,
    KFILM = True)

output_pesti_params = extract_goodness_maxmin(
        max_sterile_1st,
        initial_condition,
        output_pesti_params,
        soil_short,
        isLiving = False,
        isFirstCycle = True)
# Out:
# 1st Pulse
# Sterile Crop
# --------------------------------------------
# Koc tested:  [ 140.88379489   56.08684896]
# Best Kd (Fresh):  3.16227766017 cm3/g ( Num:  1 )
#  x factor:  2
#  R2:  0.491316507701
#  Effective Koc (fresh) - [cm3/g]: 70.4418974465
# --------------------------------------------
# Best Kd (Aged):  1.25892541179 cm3/g ( Num:  2 )
#  x factor: No factor considered.
#  R2:  -0.41123945477
#  Effective Koc (aged) [cm3/g]: 56.0868489617
# --------------------------------------------
# --------------------------------------------
# Scenario - modality - Predicted error prcnt (%) | Predicted | Observed |
# --------------------------------------------
# (A) 135 mm/h - Fresh  379.59478124 | 41.2451511866 | 8.6
# (A) 135 mm/h - Aged  246.370618784 | 48.4918866297 | 14.0
# (B) 55 mm/h - Fresh  266.200964201 | 33.6904887065 | 9.2
# (B) 55 mm/h - Aged  252.620688083 | 49.3668963316 | 14.0
# (C) 55 mm/h - Fresh  -64.3025782502 | 119.800547392 | 335.6
# (C) 55 mm/h - Aged  -46.5526535082 | 148.583623247 | 278.0
# (D) 30 mm/h - Fresh  391.364583685 | 118.565964285 | 20.5
# (D) 30 mm/h - Aged  514.805189363 | 148.672235965 | 21.6

# %%
max_living_1st = pest_Kd_choice(
    Kd1_choice_living,
    x,
    initial_condition,
    pest_dict_L_1st,          
    pb_i1, pb_f1,
    percol_data1, runoff_data1,
    time_sizes1,
    area, soil_height1, 
    d, runoff_vel,
    soil,
    isFirstCycle = True,
    isLiving = False,
    KFILM = True)

output_pesti_params = extract_goodness_maxmin(
        max_living_1st,
        initial_condition,
        output_pesti_params,
        soil_short,
        isLiving = True,
        isFirstCycle = True)
# Out:
# 1st Pulse
# Sterile Crop
# --------------------------------------------
# Koc tested:  [ 706.09159425   56.08684896]
# Best Kd (Fresh):  15.8489319246 cm3/g ( Num:  1 )
#  x factor:  2
#  R2:  0.721950465644
#  Effective Koc (fresh) - [cm3/g]: 353.045797127
# --------------------------------------------
# Best Kd (Aged):  1.25892541179 cm3/g ( Num:  2 )
#  x factor: No factor considered.
#  R2:  1.0
#  Effective Koc (aged) [cm3/g]: 56.0868489617
# --------------------------------------------
# --------------------------------------------
# Scenario - modality - Predicted error prcnt (%) | Predicted | Observed |
# --------------------------------------------
# (A) 135 mm/h - Fresh  337.236361158 | 3.06065452811 | 0.7
# (A) 135 mm/h - Aged  No obs | 45.5700979978 | nan
# (B) 55 mm/h - Fresh  481.437759909 | 2.32575103963 | 0.4
# (B) 55 mm/h - Aged  No obs | 46.3923856141 | nan
# (C) 55 mm/h - Fresh  -38.23632925 | 24.7054683 | 40.0
# (C) 55 mm/h - Aged  No obs | 139.630992787 | nan
# (D) 30 mm/h - Fresh  635.698874032 | 33.4367520901 | 1.5
# (D) 30 mm/h - Aged  No obs | 139.71426631 | nan

# %% [markdown]
# #### 2ndPulse Pulse

# %%
Kd2_SF = output_pesti_params[soil_short]['Kd2']['SF']*10**3
Kd2_SA = output_pesti_params[soil_short]['Kd2']['SA']*10**3
Kd2_choice_sterile = [Kd2_SF, Kd2_SA]

Kd2_LF = output_pesti_params[soil_short]['Kd2']['LF']*10**3
Kd2_LA = output_pesti_params[soil_short]['Kd2']['LA']*10**3
Kd2_choice_living = [Kd2_LF, Kd2_LA]

# %%
max_sterile_2nd = pest_Kd_choice(
    Kd2_choice_sterile,
    x,
    initial_condition,
    pest_dict_S_2nd,          
    pb_i2, pb_f2,
    percol_data2, runoff_data2,
    time_sizes2,
    area, soil_height2, 
    d, runoff_vel,
    soil,
    isFirstCycle = False,
    isLiving = False)

output_pesti_params = extract_goodness_maxmin(
        max_sterile_2nd,
        initial_condition,
        output_pesti_params,
        soil_short,
        isLiving = False,
        isFirstCycle = False)
# Out:
# 2nd Pulse
# Sterile Crop
# --------------------------------------------
# Koc tested:  [ 706.09159425  706.09159425]
# Best Kd (Fresh):  15.8489319246 cm3/g ( Num:  1 )
#  x factor:  2
#  R2:  -0.175244497969
#  Effective Koc (fresh) - [cm3/g]: 353.045797127
# --------------------------------------------
# Best Kd (Aged):  15.8489319246 cm3/g ( Num:  2 )
#  x factor: No factor considered.
#  R2:  0.984757325448
#  Effective Koc (aged) [cm3/g]: 706.091594253
# --------------------------------------------
# --------------------------------------------
# Scenario - modality - Predicted error prcnt (%) | Predicted | Observed |
# --------------------------------------------
# (A) 135 mm/h - Fresh  -31.7301294424 | 3.31108872204 | 4.85
# (A) 135 mm/h - Aged  -85.4450396487 | 0.107706706599 | 0.74
# (B) 55 mm/h - Fresh  3.1576076925 | 6.62271841386 | 6.42
# (B) 55 mm/h - Aged  No obs | 0.121974251443 | nan
# (C) 55 mm/h - Fresh  51.591994277 | 7.33705252301 | 4.84
# (C) 55 mm/h - Aged  -39.7814737578 | 0.714929806038 | 0.94
# (D) 30 mm/h - Fresh  83.0717503713 | 18.0402907233 | 8.61
# (D) 30 mm/h - Aged  No obs | 1.57241716126 | nan

# %%
max_living_2nd = pest_Kd_choice(
    Kd2_choice_living,
    x,
    initial_condition,
    pest_dict_L_2nd,          
    pb_i2, pb_f2,
    percol_data2, runoff_data2,
    time_sizes2,
    area, soil_height2, 
    d, runoff_vel,
    soil,
    isFirstCycle = False,
    isLiving = True)

output_pesti_params = extract_goodness_maxmin(
        max_living_2nd,
        initial_condition,
        output_pesti_params,
        soil_short,
        isLiving = True,
        isFirstCycle = False)
# Out:
# 2nd Pulse
# Living Crop
# --------------------------------------------
# Koc tested:  [ 1568.26845744    39.39312259]
# Best Kd (Fresh):  50.1187233627 cm3/g ( Num:  1 )
#  x factor:  2
#  R2:  0.899804465244
#  Effective Koc (fresh) - [cm3/g]: 784.134228718
# --------------------------------------------
# Best Kd (Aged):  1.25892541179 cm3/g ( Num:  2 )
#  x factor: No factor considered.
#  R2:  1.0
#  Effective Koc (aged) [cm3/g]: 39.393122592
# --------------------------------------------
# --------------------------------------------
# Scenario - modality - Predicted error prcnt (%) | Predicted | Observed |
# --------------------------------------------
# (A) 135 mm/h - Fresh  -49.4434500057 | 0.298283644966 | 0.59
# (A) 135 mm/h - Aged  No obs | 35.1410244879 | nan
# (B) 55 mm/h - Fresh  -4.12015884614 | 1.04509026858 | 1.09
# (B) 55 mm/h - Aged  No obs | 90.5159639173 | nan
# (C) 55 mm/h - Fresh  No obs | 0.396396705512 | nan
# (C) 55 mm/h - Aged  No obs | 123.972061695 | nan
# (D) 30 mm/h - Fresh  55.5142357662 | 2.51516837274 | 0.76
# (D) 30 mm/h - Aged  No obs | 118.26929795 | nan

# %% [markdown]
# ### Min values

# %%
initial_condition = 'min'

# %% [markdown]
# #### 1st Pulse

# %%
min_sterile_1st = pest_Kd_choice(
    Kd1_choice_sterile,
    x,
    initial_condition,
    pest_dict_S_1st,          
    pb_i1, pb_f1,
    percol_data1, runoff_data1,
    time_sizes1,
    area, soil_height1, 
    d, runoff_vel,
    soil,
    isFirstCycle = True,
    isLiving = False,
    KFILM = True)

output_pesti_params = extract_goodness_maxmin(
        min_sterile_1st,
        initial_condition,
        output_pesti_params,
        soil_short,
        isLiving = False,
        isFirstCycle = True)
# Out:
# 1st Pulse
# Sterile Crop
# --------------------------------------------
# Koc tested:  [ 140.88379489   56.08684896]
# Best Kd (Fresh):  3.16227766017 cm3/g ( Num:  1 )
#  x factor:  2
#  R2:  0.461477971368
#  Effective Koc (fresh) - [cm3/g]: 70.4418974465
# --------------------------------------------
# Best Kd (Aged):  1.25892541179 cm3/g ( Num:  2 )
#  x factor: No factor considered.
#  R2:  -0.4382765879
#  Effective Koc (aged) [cm3/g]: 56.0868489617
# --------------------------------------------
# --------------------------------------------
# Scenario - modality - Predicted error prcnt (%) | Predicted | Observed |
# --------------------------------------------
# (A) 135 mm/h - Fresh  334.082183779 | 37.331067805 | 8.6
# (A) 135 mm/h - Aged  213.314908471 | 43.8640871859 | 14.0
# (B) 55 mm/h - Fresh  231.449216006 | 30.4933278726 | 9.2
# (B) 55 mm/h - Aged  218.968505468 | 44.6555907656 | 14.0
# (C) 55 mm/h - Fresh  -67.6901930659 | 108.431712071 | 335.6
# (C) 55 mm/h - Aged  -51.6533748363 | 134.403617955 | 278.0
# (D) 30 mm/h - Fresh  344.735055219 | 107.314288462 | 20.5
# (D) 30 mm/h - Aged  456.131557316 | 134.483773962 | 21.6

# %%
min_living_1st = pest_Kd_choice(
    Kd1_choice_living,
    x,
    initial_condition,
    pest_dict_L_1st,          
    pb_i1, pb_f1,
    percol_data1, runoff_data1,
    time_sizes1,
    area, soil_height1, 
    d, runoff_vel,
    soil,
    isFirstCycle = True,
    isLiving = False,
    KFILM = True)

output_pesti_params = extract_goodness_maxmin(
        min_living_1st,
        initial_condition,
        output_pesti_params,
        soil_short,
        isLiving = True,
        isFirstCycle = True)
# Out:
# 1st Pulse
# Sterile Crop
# --------------------------------------------
# Koc tested:  [ 706.09159425   56.08684896]
# Best Kd (Fresh):  15.8489319246 cm3/g ( Num:  1 )
#  x factor:  2
#  R2:  0.675159382308
#  Effective Koc (fresh) - [cm3/g]: 353.045797127
# --------------------------------------------
# Best Kd (Aged):  1.25892541179 cm3/g ( Num:  2 )
#  x factor: No factor considered.
#  R2:  1.0
#  Effective Koc (aged) [cm3/g]: 56.0868489617
# --------------------------------------------
# --------------------------------------------
# Scenario - modality - Predicted error prcnt (%) | Predicted | Observed |
# --------------------------------------------
# (A) 135 mm/h - Fresh  295.757208102 | 2.77030045672 | 0.7
# (A) 135 mm/h - Aged  No obs | 41.2560476688 | nan
# (B) 55 mm/h - Fresh  426.278701838 | 2.10511480735 | 0.4
# (B) 55 mm/h - Aged  No obs | 42.0004905949 | nan
# (C) 55 mm/h - Fresh  -44.0956423811 | 22.3617430475 | 40.0
# (C) 55 mm/h - Aged  No obs | 126.412343786 | nan
# (D) 30 mm/h - Fresh  565.905579352 | 30.2647191101 | 1.5
# (D) 30 mm/h - Aged  No obs | 126.487733934 | nan

# %% [markdown]
# #### 2nd Pulse

# %%
min_sterile_2nd = pest_Kd_choice(
    Kd2_choice_sterile,
    x,
    initial_condition,
    pest_dict_S_2nd,          
    pb_i2, pb_f2,
    percol_data2, runoff_data2,
    time_sizes2,
    area, soil_height2, 
    d, runoff_vel,
    soil,
    isFirstCycle = False,
    isLiving = False)

output_pesti_params = extract_goodness_maxmin(
        min_sterile_2nd,
        initial_condition,
        output_pesti_params,
        soil_short,
        isLiving = False,
        isFirstCycle = False)
# Out:
# 2nd Pulse
# Sterile Crop
# --------------------------------------------
# Koc tested:  [ 706.09159425  706.09159425]
# Best Kd (Fresh):  15.8489319246 cm3/g ( Num:  1 )
#  x factor:  2
#  R2:  0.277563478987
#  Effective Koc (fresh) - [cm3/g]: 353.045797127
# --------------------------------------------
# Best Kd (Aged):  15.8489319246 cm3/g ( Num:  2 )
#  x factor: No factor considered.
#  R2:  0.982411367069
#  Effective Koc (aged) [cm3/g]: 706.091594253
# --------------------------------------------
# --------------------------------------------
# Scenario - modality - Predicted error prcnt (%) | Predicted | Observed |
# --------------------------------------------
# (A) 135 mm/h - Fresh  -38.3593449035 | 2.98957177218 | 4.85
# (A) 135 mm/h - Aged  -86.8499356172 | 0.0973104764328 | 0.74
# (B) 55 mm/h - Fresh  -6.86418061959 | 5.97931960422 | 6.42
# (B) 55 mm/h - Aged  No obs | 0.110199904527 | nan
# (C) 55 mm/h - Fresh  26.6790489531 | 6.13126596933 | 4.84
# (C) 55 mm/h - Aged  -48.7082472588 | 0.645916621227 | 0.94
# (D) 30 mm/h - Fresh  65.1220730737 | 16.2885227295 | 8.61
# (D) 30 mm/h - Aged  No obs | 1.42064192606 | nan

# %%
min_living_2nd = pest_Kd_choice(
    Kd2_choice_living,
    x,
    initial_condition,
    pest_dict_L_2nd,          
    pb_i2, pb_f2,
    percol_data2, runoff_data2,
    time_sizes2,
    area, soil_height2, 
    d, runoff_vel,
    soil,
    isFirstCycle = False,
    isLiving = True)

output_pesti_params = extract_goodness_maxmin(
        min_living_2nd,
        initial_condition,
        output_pesti_params,
        soil_short,
        isLiving = True,
        isFirstCycle = False)
# Out:
# 2nd Pulse
# Living Crop
# --------------------------------------------
# Koc tested:  [ 1568.26845744    39.39312259]
# Best Kd (Fresh):  50.1187233627 cm3/g ( Num:  1 )
#  x factor:  2
#  R2:  0.917244977087
#  Effective Koc (fresh) - [cm3/g]: 784.134228718
# --------------------------------------------
# Best Kd (Aged):  1.25892541179 cm3/g ( Num:  2 )
#  x factor: No factor considered.
#  R2:  1.0
#  Effective Koc (aged) [cm3/g]: 39.393122592
# --------------------------------------------
# --------------------------------------------
# Scenario - modality - Predicted error prcnt (%) | Predicted | Observed |
# --------------------------------------------
# (A) 135 mm/h - Fresh  -54.2639995776 | 0.269842402492 | 0.59
# (A) 135 mm/h - Aged  No obs | 31.7899396155 | nan
# (B) 55 mm/h - Fresh  -13.2606625294 | 0.94545877843 | 1.09
# (B) 55 mm/h - Aged  No obs | 81.8842668676 | nan
# (C) 55 mm/h - Fresh  No obs | 0.35770994593 | nan
# (C) 55 mm/h - Aged  No obs | 112.149956147 | nan
# (D) 30 mm/h - Fresh  40.6790561209 | 2.27534793753 | 0.76
# (D) 30 mm/h - Aged  No obs | 106.991013921 | nan

# %% [markdown]
# ### Hydrology summary

# %%
import pprint

# %% [markdown]
# ### R-squared

# %%
# 1st pulse
output_hydro_params[soil_short][0]['R1_FA']
# Out:
# [0.97929313769194559, 0.97879165664847734]

# %%
# 2nd pulse 
output_hydro_params[soil_short][0]['R2_ALL']
# Out:
# [0.98709481698576096]

# %% [markdown]
# ### Percent error

# %%
# 1st pulse
pprint.pprint(output_hydro_params[soil_short][0]['Err1'][0])
# Out:
# {'Aged': [-9.9497695760673803,
#           -19.863856215843292,
#           -4.3503947697446481,
#           -15.643875894555064],
#  'Fresh': [-1.6576800420983793,
#            29.76210753442875,
#            0.19339757059332816,
#            -4.4427680131527749]}

# %%
# 2nd pulse
pprint.pprint(output_hydro_params[soil_short][0]['Err2'][0])
# Out:
# {'LA': [0.1041023527855152,
#         2.9320569323726215,
#         -4.2848362010996981,
#         5.4353835686236112],
#  'LF': [1.8352516562050032,
#         1.2591804397577877,
#         43.289317830834683,
#         -1.0663761180911517],
#  'SA': [-3.9693605340439162,
#         96.489213405488485,
#         0.66888721467447454,
#         772.61313784789968],
#  'SF': [2.2313046190469246,
#         3.0379406788452177,
#         -1.3267350437542793,
#         2.7181496899109967]}

# %% [markdown]
# ## Transport

# %% [markdown]
# ### Summary tables
#
# 0. High rainfall intensity (135 mm/h) at 6 min.
# 1. Medium rainfall intensity (55 mm/h) at 12 min.
# 2. Medium rainfall intensity (55 mm/h) at 30 min.
# 3. Low rainfall intensity (30 mm/h) at 30 min.
#
#     a) LA : Living Aged
#
#     b) LF : Living Fresh
#
#     c) SA : Sterile Aged
#
#     d) SF : Sterile Fresh
#
#
# To compute max and min simualtions, the optimal Kd values obtained from the mean scenario were used. That is, the model has not been fitted to consider these extreme uncertainty scenarios.
#
# - max: initial calculated concentration + measurement error
#
# - min: initial calculated concentraion - measurement error

# %%
import pandas as pd

# %% [markdown]
# ### Percent error

# %%
pd.DataFrame.from_dict(output_pesti_params[soil_short]['Err1'], orient='columns')
# Out:
#        LA   LAmax   LAmin          LF       LFmax       LFmin          SA  \
# 0  No obs  No obs  No obs  207.362444  337.236361  295.757208  229.842764
# 1  No obs  No obs  No obs  445.006177  481.437760  426.278702  235.794597
# 2  No obs  No obs  No obs  -45.495762  -38.236329  -44.095642  -49.103014
# 3  No obs  No obs  No obs  558.660239  635.698874  565.905579  485.468373
#
#         SAmax       SAmin          SF       SFmax       SFmin
# 0  246.370619  213.314908  266.287396  379.594781  334.082184
# 1  252.620688  218.968505  248.825090  266.200964  231.449216
# 2  -46.552654  -51.653375  -65.996386  -64.302578  -67.690193
# 3  514.805189  456.131557  368.049819  391.364584  344.735055

# %%
pd.DataFrame.from_dict(output_pesti_params[soil_short]['Err2'], orient='columns')
# Out:
#        LA   LAmax   LAmin       LF    LFmax    LFmin       SA    SAmax  \
# 0  No obs  No obs  No obs -51.9098 -49.4435  -54.264 -86.1475  -85.445
# 1  No obs  No obs  No obs -5.04009 -4.12016 -13.2607   No obs   No obs
# 2  No obs  No obs  No obs   No obs   No obs   No obs -44.2449 -39.7815
# 3  No obs  No obs  No obs  54.5661  55.5142  40.6791   No obs   No obs
#
#      SAmin         SF      SFmax      SFmin
# 0 -86.8499 -37.666607 -31.730129 -38.359345
# 1   No obs  -1.853286   3.157608  -6.864181
# 2 -48.7082  39.135522  51.591994  26.679049
# 3   No obs  74.096912  83.071750  65.122073

# %% [markdown]
# ### R-squared & Sorption parameters

# %%
# 1st and 2nd Pulse
df = pd.DataFrame.from_dict(output_pesti_params[soil_short], orient='columns') 
df2 = df[['R1', 'R2', 'Kd1', 'Kd2', 'Koc1', 'Koc2']].dropna(axis=0)
df2
# Out:
#           R1        R2        Kd1        Kd2        Koc1        Koc2
# LA  1.000000  1.000000   1.258925   1.258925   39.393123   39.393123
# LF  0.661580  0.898416  15.848932  50.118723  247.965015  784.134229
# SA -0.420226  0.983635   1.258925  15.848932   56.086849  706.091594
# SF  0.480853  0.063766   3.162278  15.848932   70.441897  353.045797

# %%
path = '..\ModelParameters\\' + str(soil_short) + str(pesticide) + '.csv'
df2.to_csv(path, sep=';')
