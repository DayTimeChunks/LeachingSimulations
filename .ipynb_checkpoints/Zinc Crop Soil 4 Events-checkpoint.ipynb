# %% [markdown]
# START NOTEBOOK

# %% [markdown]
# ## Set-up

# %%
from hydroplots import *
from leach_hydrology import *
import numpy as np

import mpld3
mpld3.enable_notebook()

# Plot graphs within this document
# %matplotlib inline

# Plot graphs outside (for interaction)
# %matplotlib

from pestmob import *
from mixinglayer import *

# %% [markdown]
# ### Pesticide, soil type and runoff calibration parameter.

# %%
# Soil and pesticide
pesticide = 'Zinc'
initial_condition = 'mean'
soil_type = 'Crop Soil'
soil = 'Alteck'
soil_short = 'Crop'

pesti_obs = choose_pesticide(
    pesticide,
    soil)

# Kd ranges to test
Kd_pest_sterile = pesti_obs[0]
Kd_pest_living = pesti_obs[1]

# Initial concentrations and mass out observed
pest_dict_S_1st = pesti_obs[2]
pest_dict_L_1st = pesti_obs[3]
pest_dict_S_2nd = pesti_obs[4]
pest_dict_L_2nd = pesti_obs[5]

# Assumed (used to calculate Reynolds number)
runoff_vel = 10.0  # mm/min

# %% [markdown]
# ### Microcosm

# %%
d = (14.93 * 2)  # Diameter of falcon tube (mm)
area = ((d / 2) ** 2) * 3.1416  # (mm2)
soil_height1 = 20  # Mixing layer depth in mm
soil_height2 = 20  # mm

# %% [markdown]
# ### Soil hydrological characteristics

# %%
if soil == 'Alteck':
    kSat = 2.24  # mm/min (13.45 cm/h - Crop Soil) 
    psi = 1100  # soil suction Alteck (mm)
    eff_height = 0.80
elif soil == 'Rouff': 
    kSat = 17.62*10/60  # mm/min (17.62 cm/h - Vine Soil) 
    psi = 1100  # soil suction Alteck (mm)
    eff_height = 0.76
    
# Soil characteristics (Equivalent for Alteck and Rouffach)
# Initial bulk density options:
pb_i0 = 0.99/10**3  # bulk density (g/cm^3) -> g/mm^3  (M. Trautmann)
pb_i1 = 2.61/10**3 # inital 1st pulse, calc. from experiment cond.
pb_i2 = 3.59/10**3 # initial 2nd pulse, calc. from experiment cond.

# Final bulk density options (1st and 2nd pulses)
pb_f1 = 3.59/10**3 # final1, calculated from experimental conditions.
pb_f2 = 3.76/10**3 # final2, calculated from experimental conditions.

# %% [markdown]
# ### Store results

# %%
output_hydro_params = {
    soil_short : [{'R1_FA':[],
              'R2_ALL':[],
              'Err1':[{'Fresh':[], 'Aged':[]}],
              'Err2':[{'SF':[], 'SA':[], 'LF':[], 'LA':[]}],
              'Ksat2':[{'SF':[], 'SA':[], 'LF':[], 'LA':[]}]
             }]
    }

# %%
output_pesti_params = {
    soil_short: {'R1': {'SF': None, 'SA': None, 'LF': None, 'LA': None},
                 'R2': {'SF': None, 'SA': None, 'LF': None, 'LA': None},
                 'Err1': {'SF': [], 'SA': [], 'LF': [], 'LA': [],
                          'SFmax': [], 'SAmax': [], 'LFmax': [], 'LAmax': [],
                          'SFmin': [], 'SAmin': [], 'LFmin': [], 'LAmin': []},
                 'Err2': {'SF': [], 'SA': [], 'LF': [], 'LA': [],
                          'SFmax': [], 'SAmax': [], 'LFmax': [], 'LAmax': [],
                          'SFmin': [], 'SAmin': [], 'LFmin': [], 'LAmin': []},
                 'Koc1': {'SF': None, 'SA': None, 'LF': None, 'LA': None},
                 'Koc2': {'SF': None, 'SA': None, 'LF': None, 'LA': None},
                 'Kd1': {'SF': None, 'SA': None, 'LF': None, 'LA': None},
                 'Kd2': {'SF': None, 'SA': None, 'LF': None, 'LA': None}
                 }
}

# %% [markdown]
# ## Hydrology - 1st pulse

# %% [markdown]
# #### Computation

# %%
water_data = leachsim(kSat = kSat,
                      soil_height=soil_height1,
                      eff_height=eff_height,
                      soil = 'Alteck',
                      psi=psi)
# Out:
# Mass balance True
# Mass balance 0.0
# Mass balance 0.0

# %%
water_eval = leachsim2(
    kSat = [kSat],
    soil_height=soil_height1,
    eff_height = eff_height,
    soil = 'Alteck',
    isAGED = False,
    isFirstCycle=True 
)

output_hydro_params = extract_goodness(
    water_eval,
    output_hydro_params,
    soil_short,
    isFirstCycle = True,
    isAGED = False)
# Out:
# FRESH
# --------------------------------------------
# ksat high:  13.440000000000001 cm/h
# ksat med12:  13.440000000000001 cm/h
# ksat med30:  13.440000000000001 cm/h
# ksat low:  13.440000000000001 cm/h
# --------------------------------------------
# R2:  0.979293137692
# --------------------------------------------
# Simulation error percent (%), by modality
# --------------------------------------------
# 135 mm/h - 6min  -1.6576800421
# 55 mm/h - 12min  29.7621075344
# 55 mm/h - 30min  0.193397570593
# 30 mm/h - 30min  -4.44276801315
# --------------------------------------------
# Mass balance:  True True True True

# %%
water_eval = leachsim2(
    kSat = [kSat],
    soil_height=soil_height1,
    eff_height = eff_height,
    soil = 'Alteck',
    isAGED = True,
    isFirstCycle=True 
)

output_hydro_params = extract_goodness(
    water_eval,
    output_hydro_params,
    soil_short,
    isFirstCycle = True,
    isAGED = True)
# Out:
# AGED
# --------------------------------------------
# ksat high:  13.440000000000001 cm/h
# ksat med12:  13.440000000000001 cm/h
# ksat med30:  13.440000000000001 cm/h
# ksat low:  13.440000000000001 cm/h
# --------------------------------------------
# R2:  0.978791656648
# --------------------------------------------
# Simulation error percent (%), by modality
# --------------------------------------------
# 135 mm/h - 6min  -9.94976957607
# 55 mm/h - 12min  -19.8638562158
# 55 mm/h - 30min  -4.35039476974
# 30 mm/h - 30min  -15.6438758946
# --------------------------------------------
# Mass balance:  True True True True

# %%
title = "Percolated Volume [mL] - " + str(soil_type) + "1st Pulse"

# %%
extract_and_plothydro(
    water_data,
    "Percolated at 135mm/h", "Percolated at 55mm/h", "Percolated at 30mm/h", "NA",
    title,
    soil,
    isFirstCycle = True,
    isPercolation = True
)

# %%
hydro1 = extract(
    water_data, 
    isFirstCycle = True
)

percol_data1 = hydro1[0]
runoff_data1 = hydro1[1]
time_sizes1 = hydro1[2]

# %% [markdown]
# ## Transport - 1st pulse

# %% [markdown]
# ### Computation transport - 1st pulse

# %% [markdown]
# #### Test factor X (Sterile)

# %%
x = 2

# %%
pest_sterile_1st = pest_linear_x(
    Kd_pest_sterile,
    x,
    initial_condition,
    pest_dict_S_1st,          
    pb_i1, pb_f1,
    percol_data1, runoff_data1,
    time_sizes1,
    area, soil_height1, 
    d, runoff_vel,
    soil,
    isFirstCycle = True,
    isLiving = False,
    KFILM = True)

output_pesti_params = extract_goodness_pest(
        pest_sterile_1st,
        output_pesti_params,
        soil_short,
        isLiving = False,
        isFirstCycle = True)
# Out:
# 1st Pulse
# Sterile Crop
# --------------------------------------------
# Koc tested:  [  1.40883795e+02   2.81100127e+02   4.45513677e+02   7.06091594e+02
#    1.40883795e+03   1.40883795e+05   1.40883795e+07   3.53884093e+08]
# Best Kd (Fresh):  3.16227766017 cm3/g ( Num:  1 )
#  x factor:  2
#  R2:  0.442302447799
#  Effective Koc (fresh) - [cm3/g]: 70.4418974465
# --------------------------------------------
# Best Kd (Aged):  3.16227766017 cm3/g ( Num:  1 )
#  x factor: No factor considered.
#  R2:  0.459496338544
#  Effective Koc (aged) [cm3/g]: 140.883794893
# --------------------------------------------
# --------------------------------------------
# Scenario - modality - Predicted error prcnt (%) | Predicted | Observed |
# --------------------------------------------
# (A) 135 mm/h - Fresh  513.277475447 | 103.030615875 | 16.8
# (A) 135 mm/h - Aged  18.8269847443 | 19.8441064523 | 16.7
# (B) 55 mm/h - Fresh  375.474729942 | 84.1590271997 | 17.7
# (B) 55 mm/h - Aged  24.2211949077 | 20.24805477 | 16.3
# (C) 55 mm/h - Fresh  -42.8233797771 | 299.262430247 | 523.4
# (C) 55 mm/h - Aged  -57.1549092496 | 122.15135373 | 285.1
# (D) 30 mm/h - Fresh  578.230315365 | 296.178434815 | 37.1
# (D) 30 mm/h - Aged  238.796672308 | 127.426847729 | 23.2

# %% [markdown]
# #### Test factor X (Living)

# %%
x = 2

# %%
pest_living_1st = pest_linear_x(
    Kd_pest_living,
    x,
    initial_condition,
    pest_dict_L_1st,          
    pb_i1, pb_f1,
    percol_data1, percol_data1,
    time_sizes1,
    area, soil_height1, 
    d, runoff_vel,
    soil,
    KFILM = True,
    isFirstCycle = True,
    isLiving = True)


output_pesti_params = extract_goodness_pest(
        pest_living_1st,
        output_pesti_params,
        soil_short,
        isLiving = True,
        isFirstCycle = True)
# Out:
# 1st Pulse
# Living Crop
# --------------------------------------------
# Koc tested:  [  9.89510501e+01   1.97433301e+02   3.12910695e+02   4.95930031e+02
#    9.89510501e+02   9.89510501e+04   9.89510501e+06   2.48553800e+08]
# Best Kd (Fresh):  31.6227766017 cm3/g ( Num:  5 )
#  x factor:  2
#  R2:  0.869596537545
#  Effective Koc (fresh) - [cm3/g]: 494.755250668
# --------------------------------------------
# Best Kd (Aged):  6.3095734448 cm3/g ( Num:  2 )
#  x factor: No factor considered.
#  R2:  0.805966067331
#  Effective Koc (aged) [cm3/g]: 197.433301358
# --------------------------------------------
# --------------------------------------------
# Scenario - modality - Predicted error prcnt (%) | Predicted | Observed |
# --------------------------------------------
# (A) 135 mm/h - Fresh  0.375887399962 | 0.9033829866 | 0.9
# (A) 135 mm/h - Aged  51.7575994538 | 5.31151598088 | 3.5
# (B) 55 mm/h - Fresh  14.4572428459 | 0.915657942767 | 0.8
# (B) 55 mm/h - Aged  68.1485984422 | 5.38075515015 | 3.2
# (C) 55 mm/h - Fresh  -31.8014331257 | 11.7301535024 | 17.2
# (C) 55 mm/h - Aged  -14.9246075821 | 48.0675967161 | 56.5
# (D) 30 mm/h - Fresh  162.819946208 | 21.6009184136 | 1.7
# (D) 30 mm/h - Aged  422.663168613 | 60.4387707333 | 4.5

# %% [markdown]
# #### Time series

# %%
data_stack = pest_sterile_1st['Data_stack']
sterile1 = extract_pest(data_stack)

mass_percol_sterile1 = sterile1[0]
mass_pond_sterile1 = sterile1[1]

# %%
data_stack = pest_living_1st['Data_stack']
living1 = extract_pest(data_stack)

mass_percol_living1 = living1[0]
mass_pond_living1 = living1[1]

# %% [markdown]
# ## Plotting transport

# %% [markdown]
# ### Sterile (1st Pulse, Crop Soil)

# %%
pestiplot_condition(
    mass_percol_sterile1,
    pest_dict_S_1st,
    pesticide,
    soil_type,
    cycle = '1st pulse',
    LEACH = True,
    STERILE = True
)

# %% [markdown]
# ### Living (1st Pulse, Crop Soil)

# %%
pestiplot_condition(
    mass_percol_living1,
    pest_dict_L_1st,
    pesticide,
    soil_type,
    cycle = '1st pulse',
    LEACH = True,
    STERILE = False
)

# %% [markdown]
# # Hydrology - 2nd pulse

# %% [markdown]
# ### Inverse Ksat determination
#
# Based on hisotric rainfall pattern, fresh and aged.

# %%
water2_ktest = leachsim3(
    soil,
    kSat = [ kSat/5, kSat/10, kSat/15,
        kSat/25, kSat/50,  kSat/75, 
        kSat/100, kSat/125, kSat/150, 
        kSat/175, kSat/200, kSat/250,
        kSat/350, kSat/500, kSat/700, kSat/1000],
    soil_height=soil_height2,
    isFirstCycle = False
)

output_hydro_params = extract_goodness(
    water2_ktest,
    output_hydro_params,
    soil_short,
    isFirstCycle = False,
    isAGED = None
)
# Out:
# R2:  0.987094816986
# --------------------------------------------
# Sterile, Fresh Soil
# ksat high:  0.5376000000000001 cm/h | Error % 2.23130461905
# ksat med12:  0.5376000000000001 cm/h | Error % 3.03794067885
# ksat med30:  0.07680000000000001 cm/h | Error % -1.32673504375
# ksat low:  2.6880000000000006 cm/h | Error % 2.71814968991
# --------------------------------------------
# Sterile, Aged Soil
# ksat high:  0.038400000000000004 cm/h | Error % -3.96936053404
# ksat med12:  0.01344 cm/h | Error % 96.4892134055
# ksat med30:  0.01344 cm/h | Error % 0.668887214674
# ksat low:  0.01344 cm/h | Error % 772.613137848
# --------------------------------------------
# Living, Fresh Soil
# ksat high:  0.17920000000000003 cm/h | Error % 1.83525165621
# ksat med12:  0.5376000000000001 cm/h | Error % 1.25918043976
# ksat med30:  0.01344 cm/h | Error % 43.2893178308
# ksat low:  0.05376 cm/h | Error % -1.06637611809
# --------------------------------------------
# Living, Fresh Aged
# ksat high:  0.07680000000000001 cm/h | Error % 0.104102352786
# ksat med12:  0.17920000000000003 cm/h | Error % 2.93205693237
# ksat med30:  0.17920000000000003 cm/h | Error % -4.2848362011
# ksat low:  0.01344 cm/h | Error % 5.43538356862
# --------------------------------------------

# %% [markdown]
# ### Percolation - 2nd pulse

# %%
title = "Percolated Volume [mL] - " + str(soil_type) +  " 2nd Pulse"

# %%
extract_and_plothydro(
    water2_ktest,
    "Leached, 135mm/h", "Leached, 55mm/h - A", "Leached, 55mm/h - B", "Leached, 30mm/h",
    title,
    soil,
    isFirstCycle = False,
    isPercolation = True
)

# %% [markdown]
# ### Ponding - 2nd pulse

# %%
title = "Ponded Volume [mL] [mL] - " + str(soil_type) +  " 2nd Pulse"

# %%
extract_and_plothydro(
    water2_ktest,
    "Ponded, 135mm/h", "Ponded, 55mm/h - A", "Ponded, 55mm/h - B", "Ponded, 30mm/h",
    title,
    soil,
    isFirstCycle = False,
    isPercolation = False
)

# %%
hydro2 = extract(
    water2_ktest,
    isFirstCycle = False
)
percol_data2 = hydro2[0]
runoff_data2 = hydro2[1]
time_sizes2 = hydro2[2]

# %% [markdown]
# ## Transport - 2nd pulse

# %% [markdown]
# ### Computation transport - 2nd Pulse

# %% [markdown]
# #### Kd optimal (sterile)

# %%
x = 2

# %%
pest_sterile_2nd = pest_linear_x(
    Kd_pest_sterile,
    x,
    initial_condition,
    pest_dict_S_2nd,
    pb_i2, pb_f2,
    percol_data2, runoff_data2,
    time_sizes2,
    area, soil_height2,
    d, runoff_vel,
    soil = "Alteck",
    isFirstCycle = False,
    isLiving = False)

output_pesti_params = extract_goodness_pest(
        pest_sterile_2nd,
        output_pesti_params,
        soil_short,
        isLiving = False,
        isFirstCycle = False)
# Out:
# 2nd Pulse
# Sterile Crop
# --------------------------------------------
# Koc tested:  [  1.40883795e+02   2.81100127e+02   4.45513677e+02   7.06091594e+02
#    1.40883795e+03   1.40883795e+05   1.40883795e+07   3.53884093e+08]
# Best Kd (Fresh):  3162.27766017 cm3/g ( Num:  6 )
#  x factor:  2
#  R2:  -4.14807932945
#  Effective Koc (fresh) - [cm3/g]: 70441.8974465
# --------------------------------------------
# Best Kd (Aged):  31.6227766017 cm3/g ( Num:  5 )
#  x factor: No factor considered.
#  R2:  0.990311582046
#  Effective Koc (aged) [cm3/g]: 1408.83794893
# --------------------------------------------
# --------------------------------------------
# Scenario - modality - Predicted error prcnt (%) | Predicted | Observed |
# --------------------------------------------
# (A) 135 mm/h - Fresh  -99.9910986167 | 0.000222534583473 | 2.5
# (A) 135 mm/h - Aged  -85.5664279031 | 0.0577342883874 | 0.4
# (B) 55 mm/h - Fresh  -99.9859592661 | 0.000505466420571 | 3.6
# (B) 55 mm/h - Aged  No obs | 0.065420972497 | nan
# (C) 55 mm/h - Fresh  -99.9460183795 | 0.000701761065853 | 1.3
# (C) 55 mm/h - Aged  73.4899528205 | 0.38879346306 | 0.2
# (D) 30 mm/h - Fresh  -99.9590534615 | 0.00232668889275 | 4.1
# (D) 30 mm/h - Aged  No obs | 0.87276209395 | nan

# %% [markdown]
# #### Kd optimal (living)

# %%
x = 2

# %%
pest_living_2nd = pest_linear_x(
    Kd_pest_living,
    x,
    initial_condition,
    pest_dict_L_2nd,          
    pb_i1, pb_f1,
    percol_data2, runoff_data2,
    time_sizes1,
    area, soil_height1, 
    d, runoff_vel,
    soil = "Alteck",
    KFILM = True,
    isFirstCycle = False,
    isLiving = True)

output_pesti_params = extract_goodness_pest(
        pest_living_2nd,
        output_pesti_params,
        soil_short,
        isLiving = True,
        isFirstCycle = False)
# Out:
# 2nd Pulse
# Living Crop
# --------------------------------------------
# Koc tested:  [  9.89510501e+01   1.97433301e+02   3.12910695e+02   4.95930031e+02
#    9.89510501e+02   9.89510501e+04   9.89510501e+06   2.48553800e+08]
# Best Kd (Fresh):  3.16227766017 cm3/g ( Num:  1 )
#  x factor:  2
#  R2:  1.0
#  Effective Koc (fresh) - [cm3/g]: 49.4755250668
# --------------------------------------------
# Best Kd (Aged):  3162.27766017 cm3/g ( Num:  6 )
#  x factor: No factor considered.
#  R2:  -1.51766098194
#  Effective Koc (aged) [cm3/g]: 98951.0501336
# --------------------------------------------
# --------------------------------------------
# Scenario - modality - Predicted error prcnt (%) | Predicted | Observed |
# --------------------------------------------
# (A) 135 mm/h - Fresh  No obs | 96.2708836482 | nan
# (A) 135 mm/h - Aged  -99.9940220733 | 1.91293653526e-05 | 0.32
# (B) 55 mm/h - Fresh  No obs | 187.531394292 | nan
# (B) 55 mm/h - Aged  -99.9925985213 | 7.32746394098e-05 | 0.99
# (C) 55 mm/h - Fresh  No obs | 102.4693423 | nan
# (C) 55 mm/h - Aged  -99.9389336075 | 0.000280588920603 | 0.45
# (D) 30 mm/h - Fresh  No obs | 219.168841752 | nan
# (D) 30 mm/h - Aged  -99.915958934 | 0.000185862822654 | 0.05

# %% [markdown]
# #### Time series

# %%
data_stack = pest_sterile_2nd['Data_stack']
sterile2 = extract_pest(data_stack)

data_stack = pest_living_2nd['Data_stack']
living2 = extract_pest(data_stack)

mass_percol_sterile2 = sterile2[0]
mass_pond_sterile2 = sterile2[1]

mass_percol_living2 = living2[0]
mass_pond_living2 = living2[1]

# %% [markdown]
# ## Plotting transport

# %% [markdown]
# ### Sterile (2nd Pulse)

# %%
pestiplot_condition(
    mass_percol_sterile2,
    pest_dict_S_2nd,
    pesticide,
    soil_type,
    cycle = '2nd pulse',
    LEACH = True,
    STERILE = True
)

# %%
pestiplot_condition(
    mass_pond_sterile2,
    pest_dict_S_2nd,
    pesticide,
    soil_type,
    cycle = '2nd pulse',
    LEACH = False,
    STERILE = True
)

# %% [markdown]
# ### Living (2nd Pulse)

# %%
pestiplot_condition(
    mass_percol_living2,
    pest_dict_L_2nd,
    pesticide,
    soil_type,
    cycle = '2nd pulse',
    LEACH = True,
    STERILE = False
)

# %%
pestiplot_condition(
    mass_pond_living2,
    pest_dict_L_2nd,
    pesticide,
    soil_type,
    cycle = '2nd pulse',
    LEACH = False,
    STERILE = False
)

# %% [markdown]
# END NOTEBOOK

# %% [markdown]
# ### Max values

# %%
initial_condition = 'max'

# %% [markdown]
# #### 1st Pulse

# %%
Kd1_SF = output_pesti_params[soil_short]['Kd1']['SF']*10**3  # Convert back to mm3/g (model units)
Kd1_SA = output_pesti_params[soil_short]['Kd1']['SA']*10**3
Kd1_choice_sterile = [Kd1_SF, Kd1_SA]

Kd1_LF = output_pesti_params[soil_short]['Kd1']['LF']*10**3
Kd1_LA = output_pesti_params[soil_short]['Kd1']['LA']*10**3
Kd1_choice_living = [Kd1_LF, Kd1_LA]

# %%
max_sterile_1st = pest_Kd_choice(
    Kd1_choice_sterile,
    x,
    initial_condition,
    pest_dict_S_1st,          
    pb_i1, pb_f1,
    percol_data1, runoff_data1,
    time_sizes1,
    area, soil_height1, 
    d, runoff_vel,
    soil,
    isFirstCycle = True,
    isLiving = False,
    KFILM = True)

output_pesti_params = extract_goodness_maxmin(
        max_sterile_1st,
        initial_condition,
        output_pesti_params,
        soil_short,
        isLiving = False,
        isFirstCycle = True)
# Out:
# 1st Pulse
# Sterile Crop
# --------------------------------------------
# Koc tested:  [ 140.88379489  140.88379489]
# Best Kd (Fresh):  3.16227766017 cm3/g ( Num:  1 )
#  x factor:  2
#  R2:  0.439400510016
#  Effective Koc (fresh) - [cm3/g]: 70.4418974465
# --------------------------------------------
# Best Kd (Aged):  3.16227766017 cm3/g ( Num:  2 )
#  x factor: No factor considered.
#  R2:  0.48664671347
#  Effective Koc (aged) [cm3/g]: 140.883794893
# --------------------------------------------
# --------------------------------------------
# Scenario - modality - Predicted error prcnt (%) | Predicted | Observed |
# --------------------------------------------
# (A) 135 mm/h - Fresh  543.880932073 | 108.171996588 | 16.8
# (A) 135 mm/h - Aged  24.7817092088 | 20.8385454379 | 16.7
# (B) 55 mm/h - Fresh  399.201624956 | 88.3586876171 | 17.7
# (B) 55 mm/h - Aged  30.4462370554 | 21.26273664 | 16.3
# (C) 55 mm/h - Fresh  -39.9701815315 | 314.196069864 | 523.4
# (C) 55 mm/h - Aged  -55.0078320463 | 128.272670836 | 285.1
# (D) 30 mm/h - Fresh  612.075015145 | 310.958178481 | 37.1
# (D) 30 mm/h - Aged  255.774641054 | 133.812533348 | 23.2

# %%
max_living_1st = pest_Kd_choice(
    Kd1_choice_living,
    x,
    initial_condition,
    pest_dict_L_1st,          
    pb_i1, pb_f1,
    percol_data1, runoff_data1,
    time_sizes1,
    area, soil_height1, 
    d, runoff_vel,
    soil,
    isFirstCycle = True,
    isLiving = False,
    KFILM = True)

output_pesti_params = extract_goodness_maxmin(
        max_living_1st,
        initial_condition,
        output_pesti_params,
        soil_short,
        isLiving = True,
        isFirstCycle = True)
# Out:
# 1st Pulse
# Sterile Crop
# --------------------------------------------
# Koc tested:  [ 1408.83794893   281.10012674]
# Best Kd (Fresh):  31.6227766017 cm3/g ( Num:  1 )
#  x factor:  2
#  R2:  0.9109262711
#  Effective Koc (fresh) - [cm3/g]: 704.418974465
# --------------------------------------------
# Best Kd (Aged):  6.3095734448 cm3/g ( Num:  2 )
#  x factor: No factor considered.
#  R2:  0.784794310763
#  Effective Koc (aged) [cm3/g]: 281.10012674
# --------------------------------------------
# --------------------------------------------
# Scenario - modality - Predicted error prcnt (%) | Predicted | Observed |
# --------------------------------------------
# (A) 135 mm/h - Fresh  44.4441223493 | 1.29999710114 | 0.9
# (A) 135 mm/h - Aged  60.6123253231 | 5.62143138631 | 3.5
# (B) 55 mm/h - Fresh  22.1498834532 | 0.977199067625 | 0.8
# (B) 55 mm/h - Aged  79.3971500035 | 5.74070880011 | 3.2
# (C) 55 mm/h - Fresh  -22.2191876738 | 13.3782997201 | 17.2
# (C) 55 mm/h - Aged  -3.87525015971 | 54.3104836598 | 56.5
# (D) 30 mm/h - Fresh  194.049281686 | 25.0247246307 | 1.7
# (D) 30 mm/h - Aged  483.431853986 | 67.1455309139 | 4.5

# %% [markdown]
# #### 2ndPulse Pulse

# %%
Kd2_SF = output_pesti_params[soil_short]['Kd2']['SF']*10**3
Kd2_SA = output_pesti_params[soil_short]['Kd2']['SA']*10**3
Kd2_choice_sterile = [Kd2_SF, Kd2_SA]

Kd2_LF = output_pesti_params[soil_short]['Kd2']['LF']*10**3
Kd2_LA = output_pesti_params[soil_short]['Kd2']['LA']*10**3
Kd2_choice_living = [Kd2_LF, Kd2_LA]

# %%
max_sterile_2nd = pest_Kd_choice(
    Kd2_choice_sterile,
    x,
    initial_condition,
    pest_dict_S_2nd,          
    pb_i2, pb_f2,
    percol_data2, runoff_data2,
    time_sizes2,
    area, soil_height2, 
    d, runoff_vel,
    soil,
    isFirstCycle = False,
    isLiving = False)

output_pesti_params = extract_goodness_maxmin(
        max_sterile_2nd,
        initial_condition,
        output_pesti_params,
        soil_short,
        isLiving = False,
        isFirstCycle = False)
# Out:
# 2nd Pulse
# Sterile Crop
# --------------------------------------------
# Koc tested:  [ 140883.794893      1408.83794893]
# Best Kd (Fresh):  3162.27766017 cm3/g ( Num:  1 )
#  x factor:  2
#  R2:  -4.14792538641
#  Effective Koc (fresh) - [cm3/g]: 70441.8974465
# --------------------------------------------
# Best Kd (Aged):  31.6227766017 cm3/g ( Num:  2 )
#  x factor: No factor considered.
#  R2:  0.989974387323
#  Effective Koc (aged) [cm3/g]: 1408.83794893
# --------------------------------------------
# --------------------------------------------
# Scenario - modality - Predicted error prcnt (%) | Predicted | Observed |
# --------------------------------------------
# (A) 135 mm/h - Fresh  -99.9902065868 | 0.000244835331148 | 2.5
# (A) 135 mm/h - Aged  -84.8328496511 | 0.0606686013957 | 0.4
# (B) 55 mm/h - Fresh  -99.9852500463 | 0.000530998334057 | 3.6
# (B) 55 mm/h - Aged  No obs | 0.0687454410168 | nan
# (C) 55 mm/h - Fresh  -99.942235256 | 0.000750941672551 | 1.3
# (C) 55 mm/h - Aged  84.3091261807 | 0.408550607891 | 0.2
# (D) 30 mm/h - Fresh  -99.9569587706 | 0.00247461594515 | 4.1
# (D) 30 mm/h - Aged  No obs | 0.917119740626 | nan

# %%
max_living_2nd = pest_Kd_choice(
    Kd2_choice_living,
    x,
    initial_condition,
    pest_dict_L_2nd,          
    pb_i2, pb_f2,
    percol_data2, runoff_data2,
    time_sizes2,
    area, soil_height2, 
    d, runoff_vel,
    soil,
    isFirstCycle = False,
    isLiving = True)

output_pesti_params = extract_goodness_maxmin(
        max_living_2nd,
        initial_condition,
        output_pesti_params,
        soil_short,
        isLiving = True,
        isFirstCycle = False)
# Out:
# 2nd Pulse
# Living Crop
# --------------------------------------------
# Koc tested:  [    98.95105013  98951.05013356]
# Best Kd (Fresh):  3.16227766017 cm3/g ( Num:  1 )
#  x factor:  2
#  R2:  1.0
#  Effective Koc (fresh) - [cm3/g]: 49.4755250668
# --------------------------------------------
# Best Kd (Aged):  3162.27766017 cm3/g ( Num:  2 )
#  x factor: No factor considered.
#  R2:  -1.51765680917
#  Effective Koc (aged) [cm3/g]: 98951.0501336
# --------------------------------------------
# --------------------------------------------
# Scenario - modality - Predicted error prcnt (%) | Predicted | Observed |
# --------------------------------------------
# (A) 135 mm/h - Fresh  No obs | 83.9218584304 | nan
# (A) 135 mm/h - Aged  -99.9940002284 | 1.91992690391e-05 | 0.32
# (B) 55 mm/h - Fresh  No obs | 194.862875919 | nan
# (B) 55 mm/h - Aged  -99.9925514496 | 7.37406489237e-05 | 0.99
# (C) 55 mm/h - Fresh  No obs | 105.088246962 | nan
# (C) 55 mm/h - Aged  -99.9386485519 | 0.00028281605054 | 0.45
# (D) 30 mm/h - Fresh  No obs | 235.112556601 | nan
# (D) 30 mm/h - Aged  -99.9157169228 | 0.000186567558747 | 0.05

# %% [markdown]
# ### Min values

# %%
initial_condition = 'min'

# %% [markdown]
# #### 1st Pulse

# %%
min_sterile_1st = pest_Kd_choice(
    Kd1_choice_sterile,
    x,
    initial_condition,
    pest_dict_S_1st,          
    pb_i1, pb_f1,
    percol_data1, runoff_data1,
    time_sizes1,
    area, soil_height1, 
    d, runoff_vel,
    soil,
    isFirstCycle = True,
    isLiving = False,
    KFILM = True)

output_pesti_params = extract_goodness_maxmin(
        min_sterile_1st,
        initial_condition,
        output_pesti_params,
        soil_short,
        isLiving = False,
        isFirstCycle = True)
# Out:
# 1st Pulse
# Sterile Crop
# --------------------------------------------
# Koc tested:  [ 140.88379489  140.88379489]
# Best Kd (Fresh):  3.16227766017 cm3/g ( Num:  1 )
#  x factor:  2
#  R2:  0.440822191916
#  Effective Koc (fresh) - [cm3/g]: 70.4418974465
# --------------------------------------------
# Best Kd (Aged):  3.16227766017 cm3/g ( Num:  2 )
#  x factor: No factor considered.
#  R2:  0.430340377897
#  Effective Koc (aged) [cm3/g]: 140.883794893
# --------------------------------------------
# --------------------------------------------
# Scenario - modality - Predicted error prcnt (%) | Predicted | Observed |
# --------------------------------------------
# (A) 135 mm/h - Fresh  482.674018822 | 97.889235162 | 16.8
# (A) 135 mm/h - Aged  12.8722602798 | 18.8496674667 | 16.7
# (B) 55 mm/h - Fresh  351.747834928 | 79.9593667822 | 17.7
# (B) 55 mm/h - Aged  17.9961527599 | 19.2333728999 | 16.3
# (C) 55 mm/h - Fresh  -45.6765780226 | 284.328790629 | 523.4
# (C) 55 mm/h - Aged  -59.3019864528 | 116.030036623 | 285.1
# (D) 30 mm/h - Fresh  544.385615585 | 281.398691148 | 37.1
# (D) 30 mm/h - Aged  221.818703563 | 121.041162111 | 23.2

# %%
min_living_1st = pest_Kd_choice(
    Kd1_choice_living,
    x,
    initial_condition,
    pest_dict_L_1st,          
    pb_i1, pb_f1,
    percol_data1, runoff_data1,
    time_sizes1,
    area, soil_height1, 
    d, runoff_vel,
    soil,
    isFirstCycle = True,
    isLiving = False,
    KFILM = True)

output_pesti_params = extract_goodness_maxmin(
        min_living_1st,
        initial_condition,
        output_pesti_params,
        soil_short,
        isLiving = True,
        isFirstCycle = True)
# Out:
# 1st Pulse
# Sterile Crop
# --------------------------------------------
# Koc tested:  [ 1408.83794893   281.10012674]
# Best Kd (Fresh):  31.6227766017 cm3/g ( Num:  1 )
#  x factor:  2
#  R2:  0.881947485472
#  Effective Koc (fresh) - [cm3/g]: 704.418974465
# --------------------------------------------
# Best Kd (Aged):  6.3095734448 cm3/g ( Num:  2 )
#  x factor: No factor considered.
#  R2:  0.810119267408
#  Effective Koc (aged) [cm3/g]: 281.10012674
# --------------------------------------------
# --------------------------------------------
# Scenario - modality - Predicted error prcnt (%) | Predicted | Observed |
# --------------------------------------------
# (A) 135 mm/h - Fresh  30.6677593533 | 1.17600983418 | 0.9
# (A) 135 mm/h - Aged  45.3501673265 | 5.08725585643 | 3.5
# (B) 55 mm/h - Fresh  10.4998342369 | 0.883998673895 | 0.8
# (B) 55 mm/h - Aged  62.3494650308 | 5.19518288098 | 3.2
# (C) 55 mm/h - Fresh  -29.6375352486 | 12.1023439372 | 17.2
# (C) 55 mm/h - Aged  -13.0097567744 | 49.1494874225 | 56.5
# (D) 30 mm/h - Fresh  166.004321619 | 22.6379906828 | 1.7
# (D) 30 mm/h - Aged  427.989710956 | 60.7650386353 | 4.5

# %% [markdown]
# #### 2nd Pulse

# %%
min_sterile_2nd = pest_Kd_choice(
    Kd2_choice_sterile,
    x,
    initial_condition,
    pest_dict_S_2nd,          
    pb_i2, pb_f2,
    percol_data2, runoff_data2,
    time_sizes2,
    area, soil_height2, 
    d, runoff_vel,
    soil,
    isFirstCycle = False,
    isLiving = False)

output_pesti_params = extract_goodness_maxmin(
        min_sterile_2nd,
        initial_condition,
        output_pesti_params,
        soil_short,
        isLiving = False,
        isFirstCycle = False)
# Out:
# 2nd Pulse
# Sterile Crop
# --------------------------------------------
# Koc tested:  [ 140883.794893      1408.83794893]
# Best Kd (Fresh):  3162.27766017 cm3/g ( Num:  1 )
#  x factor:  2
#  R2:  -4.14821889141
#  Effective Koc (fresh) - [cm3/g]: 70441.8974465
# --------------------------------------------
# Best Kd (Aged):  31.6227766017 cm3/g ( Num:  2 )
#  x factor: No factor considered.
#  R2:  0.990582185813
#  Effective Koc (aged) [cm3/g]: 1408.83794893
# --------------------------------------------
# --------------------------------------------
# Scenario - modality - Predicted error prcnt (%) | Predicted | Observed |
# --------------------------------------------
# (A) 135 mm/h - Fresh  -99.991148116 | 0.000221297099454 | 2.5
# (A) 135 mm/h - Aged  -86.3000061552 | 0.0547999753792 | 0.4
# (B) 55 mm/h - Fresh  -99.9866684859 | 0.000479934507086 | 3.6
# (B) 55 mm/h - Aged  No obs | 0.0620965039773 | nan
# (C) 55 mm/h - Fresh  -99.9498015031 | 0.000652580459154 | 1.3
# (C) 55 mm/h - Aged  62.6707794602 | 0.369036318228 | 0.2
# (D) 30 mm/h - Fresh  -99.9611481525 | 0.00223670876403 | 4.1
# (D) 30 mm/h - Aged  No obs | 0.828404447274 | nan

# %%
min_living_2nd = pest_Kd_choice(
    Kd2_choice_living,
    x,
    initial_condition,
    pest_dict_L_2nd,          
    pb_i2, pb_f2,
    percol_data2, runoff_data2,
    time_sizes2,
    area, soil_height2, 
    d, runoff_vel,
    soil,
    isFirstCycle = False,
    isLiving = True)

output_pesti_params = extract_goodness_maxmin(
        min_living_2nd,
        initial_condition,
        output_pesti_params,
        soil_short,
        isLiving = True,
        isFirstCycle = False)
# Out:
# 2nd Pulse
# Living Crop
# --------------------------------------------
# Koc tested:  [    98.95105013  98951.05013356]
# Best Kd (Fresh):  3.16227766017 cm3/g ( Num:  1 )
#  x factor:  2
#  R2:  1.0
#  Effective Koc (fresh) - [cm3/g]: 49.4755250668
# --------------------------------------------
# Best Kd (Aged):  3162.27766017 cm3/g ( Num:  2 )
#  x factor: No factor considered.
#  R2:  -1.51773523578
#  Effective Koc (aged) [cm3/g]: 98951.0501336
# --------------------------------------------
# --------------------------------------------
# Scenario - modality - Predicted error prcnt (%) | Predicted | Observed |
# --------------------------------------------
# (A) 135 mm/h - Fresh  No obs | 75.9154365506 | nan
# (A) 135 mm/h - Aged  -99.9945710874 | 1.73725204729e-05 | 0.32
# (B) 55 mm/h - Fresh  No obs | 176.272315337 | nan
# (B) 55 mm/h - Aged  -99.9932600768 | 6.67252400139e-05 | 0.99
# (C) 55 mm/h - Fresh  No obs | 95.002709228 | nan
# (C) 55 mm/h - Aged  -99.9447339074 | 0.000255909991674 | 0.45
# (D) 30 mm/h - Fresh  No obs | 212.682043829 | nan
# (D) 30 mm/h - Aged  -99.9237983507 | 0.000168816256875 | 0.05

# %% [markdown]
# ### Hydrology summary

# %%
import pprint

# %% [markdown]
# ### R-squared

# %%
# 1st pulse
output_hydro_params[soil_short][0]['R1_FA']
# Out:
# [0.97929313769194559, 0.97879165664847734]

# %%
# 2nd pulse 
output_hydro_params[soil_short][0]['R2_ALL']
# Out:
# [0.98709481698576096]

# %% [markdown]
# ### Percent error

# %%
# 1st pulse
pprint.pprint(output_hydro_params[soil_short][0]['Err1'][0])
# Out:
# {'Aged': [-9.9497695760673803,
#           -19.863856215843292,
#           -4.3503947697446481,
#           -15.643875894555064],
#  'Fresh': [-1.6576800420983793,
#            29.76210753442875,
#            0.19339757059332816,
#            -4.4427680131527749]}

# %%
# 2nd pulse
pprint.pprint(output_hydro_params[soil_short][0]['Err2'][0])
# Out:
# {'LA': [0.1041023527855152,
#         2.9320569323726215,
#         -4.2848362010996981,
#         5.4353835686236112],
#  'LF': [1.8352516562050032,
#         1.2591804397577877,
#         43.289317830834683,
#         -1.0663761180911517],
#  'SA': [-3.9693605340439162,
#         96.489213405488485,
#         0.66888721467447454,
#         772.61313784789968],
#  'SF': [2.2313046190469246,
#         3.0379406788452177,
#         -1.3267350437542793,
#         2.7181496899109967]}

# %% [markdown]
# ## Transport

# %% [markdown]
# ### Summary tables
#
# 0. High rainfall intensity (135 mm/h) at 6 min.
# 1. Medium rainfall intensity (55 mm/h) at 12 min.
# 2. Medium rainfall intensity (55 mm/h) at 30 min.
# 3. Low rainfall intensity (30 mm/h) at 30 min.
#
#     a) LA : Living Aged
#
#     b) LF : Living Fresh
#
#     c) SA : Sterile Aged
#
#     d) SF : Sterile Fresh
#
#
# To compute max and min simualtions, the optimal Kd values obtained from the mean scenario were used. That is, the model has not been fitted to consider these extreme uncertainty scenarios.
#
# - max: initial calculated concentration + measurement error
#
# - min: initial calculated concentraion - measurement error

# %%
import pandas as pd

# %% [markdown]
# ### Percent error

# %%
pd.DataFrame.from_dict(output_pesti_params[soil_short]['Err1'], orient='columns')
# Out:
#            LA       LAmax       LAmin          LF       LFmax       LFmin  \
# 0   51.757599   60.612325   45.350167    0.375887   44.444122   30.667759
# 1   68.148598   79.397150   62.349465   14.457243   22.149883   10.499834
# 2  -14.924608   -3.875250  -13.009757  -31.801433  -22.219188  -29.637535
# 3  422.663169  483.431854  427.989711  162.819946  194.049282  166.004322
#
#            SA       SAmax       SAmin          SF       SFmax       SFmin
# 0   18.826985   24.781709   12.872260  513.277475  543.880932  482.674019
# 1   24.221195   30.446237   17.996153  375.474730  399.201625  351.747835
# 2  -57.154909  -55.007832  -59.301986  -42.823380  -39.970182  -45.676578
# 3  238.796672  255.774641  221.818704  578.230315  612.075015  544.385616

# %%
pd.DataFrame.from_dict(output_pesti_params[soil_short]['Err2'], orient='columns')
# Out:
#           LA      LAmax      LAmin      LF   LFmax   LFmin       SA    SAmax  \
# 0 -99.994022 -99.994000 -99.994571  No obs  No obs  No obs -85.5664 -84.8328
# 1 -99.992599 -99.992551 -99.993260  No obs  No obs  No obs   No obs   No obs
# 2 -99.938934 -99.938649 -99.944734  No obs  No obs  No obs    73.49  84.3091
# 3 -99.915959 -99.915717 -99.923798  No obs  No obs  No obs   No obs   No obs
#
#      SAmin         SF      SFmax      SFmin
# 0    -86.3 -99.991099 -99.990207 -99.991148
# 1   No obs -99.985959 -99.985250 -99.986668
# 2  62.6708 -99.946018 -99.942235 -99.949802
# 3   No obs -99.959053 -99.956959 -99.961148

# %% [markdown]
# ### R-squared & Sorption parameters

# %%
# 1st and 2nd Pulse
df = pd.DataFrame.from_dict(output_pesti_params[soil_short], orient='columns') 
df2 = df[['R1', 'R2', 'Kd1', 'Kd2', 'Koc1', 'Koc2']].dropna(axis=0)
df2
# Out:
#           R1        R2        Kd1          Kd2        Koc1          Koc2
# LA  0.805966 -1.517661   6.309573  3162.277660  197.433301  98951.050134
# LF  0.869597  1.000000  31.622777     3.162278  494.755251     49.475525
# SA  0.459496  0.990312   3.162278    31.622777  140.883795   1408.837949
# SF  0.442302 -4.148079   3.162278  3162.277660   70.441897  70441.897447

# %%
path = '..\ModelParameters\\' + str(soil_short) + str(pesticide) + '.csv'
df2.to_csv(path, sep=';')
