# %% [markdown]
# START NOTEBOOK

# %% [markdown]
# ## Set-up

# %%
from hydroplots import *
from leach_hydrology import *
import numpy as np

import mpld3
mpld3.enable_notebook()

# Plot graphs within this document
# %matplotlib inline

# Plot graphs outside (for interaction)
# %matplotlib

from pestmob import *
from mixinglayer import *

# %% [markdown]
# ### Pesticide, soil type and runoff calibration parameter.

# %%
# Soil and pesticide
pesticide = 'S-metolachlor'
initial_condition = 'mean'
soil_type = 'Crop Soil'
soil = 'Alteck'
soil_short = 'Crop'

pesti_obs = choose_pesticide(
    pesticide,
    soil)

# Kd ranges to test
Kd_pest_sterile = pesti_obs[0]
Kd_pest_living = pesti_obs[1]

# Initial concentrations and mass out observed
pest_dict_S_1st = pesti_obs[2]
pest_dict_L_1st = pesti_obs[3]
pest_dict_S_2nd = pesti_obs[4]
pest_dict_L_2nd = pesti_obs[5]

# Assumed (used to calculate Reynolds number)
runoff_vel = 10.0  # mm/min

# %% [markdown]
# ### Microcosm

# %%
d = (14.93 * 2)  # Diameter of falcon tube (mm)
area = ((d / 2) ** 2) * 3.1416  # (mm2)
soil_height1 = 20  # Mixing layer depth in mm
soil_height2 = 20  # mm

# %% [markdown]
# ### Soil hydrological characteristics

# %%
if soil == 'Alteck':
    kSat = 2.24  # mm/min (13.45 cm/h - Crop Soil) 
    psi = 1100  # soil suction Alteck (mm)
    eff_height = 0.80
elif soil == 'Rouff': 
    kSat = 17.62*10/60  # mm/min (17.62 cm/h - Vine Soil) 
    psi = 1100  # soil suction Alteck (mm)
    eff_height = 0.76
    
# Soil characteristics (Equivalent for Alteck and Rouffach)
# Initial bulk density options:
pb_i0 = 0.99/10**3  # bulk density (g/cm^3) -> g/mm^3  (M. Trautmann)
pb_i1 = 2.61/10**3 # inital 1st pulse, calc. from experiment cond.
pb_i2 = 3.59/10**3 # initial 2nd pulse, calc. from experiment cond.

# Final bulk density options (1st and 2nd pulses)
pb_f1 = 3.59/10**3 # final1, calculated from experimental conditions.
pb_f2 = 3.76/10**3 # final2, calculated from experimental conditions.

# %% [markdown]
# ### Store results

# %%
output_hydro_params = {
    soil_short : [{'R1_FA':[],
              'R2_ALL':[],
              'Err1':[{'Fresh':[], 'Aged':[]}],
              'Err2':[{'SF':[], 'SA':[], 'LF':[], 'LA':[]}],
              'Ksat2':[{'SF':[], 'SA':[], 'LF':[], 'LA':[]}]
             }]
    }

# %%
output_pesti_params = {
    soil_short: {'R1': {'SF': None, 'SA': None, 'LF': None, 'LA': None},
                 'R2': {'SF': None, 'SA': None, 'LF': None, 'LA': None},
                 'Err1': {'SF': [], 'SA': [], 'LF': [], 'LA': [],
                          'SFmax': [], 'SAmax': [], 'LFmax': [], 'LAmax': [],
                          'SFmin': [], 'SAmin': [], 'LFmin': [], 'LAmin': []},
                 'Err2': {'SF': [], 'SA': [], 'LF': [], 'LA': [],
                          'SFmax': [], 'SAmax': [], 'LFmax': [], 'LAmax': [],
                          'SFmin': [], 'SAmin': [], 'LFmin': [], 'LAmin': []},
                 'Koc1': {'SF': None, 'SA': None, 'LF': None, 'LA': None},
                 'Koc2': {'SF': None, 'SA': None, 'LF': None, 'LA': None},
                 'Kd1': {'SF': None, 'SA': None, 'LF': None, 'LA': None},
                 'Kd2': {'SF': None, 'SA': None, 'LF': None, 'LA': None}
                 }
}

# %% [markdown]
# ## Hydrology - 1st pulse

# %% [markdown]
# #### Computation

# %%
water_data = leachsim(kSat = kSat,
                      soil_height=soil_height1,
                      eff_height=eff_height,
                      soil = 'Alteck',
                      psi=psi)
# Out:
# Mass balance True
# Mass balance 0.0
# Mass balance 0.0

# %%
water_eval = leachsim2(
    kSat = [kSat],
    soil_height=soil_height1,
    eff_height = eff_height,
    soil = 'Alteck',
    isAGED = False,
    isFirstCycle=True 
)

output_hydro_params = extract_goodness(
    water_eval,
    output_hydro_params,
    soil_short,
    isFirstCycle = True,
    isAGED = False)
# Out:
# FRESH
# --------------------------------------------
# ksat high:  13.440000000000001 cm/h
# ksat med12:  13.440000000000001 cm/h
# ksat med30:  13.440000000000001 cm/h
# ksat low:  13.440000000000001 cm/h
# --------------------------------------------
# R2:  0.979293137692
# --------------------------------------------
# Simulation error percent (%), by modality
# --------------------------------------------
# 135 mm/h - 6min  -1.6576800421
# 55 mm/h - 12min  29.7621075344
# 55 mm/h - 30min  0.193397570593
# 30 mm/h - 30min  -4.44276801315
# --------------------------------------------
# Mass balance:  True True True True

# %%
water_eval = leachsim2(
    kSat = [kSat],
    soil_height=soil_height1,
    eff_height = eff_height,
    soil = 'Alteck',
    isAGED = True,
    isFirstCycle=True 
)

output_hydro_params = extract_goodness(
    water_eval,
    output_hydro_params,
    soil_short,
    isFirstCycle = True,
    isAGED = True)
# Out:
# AGED
# --------------------------------------------
# ksat high:  13.440000000000001 cm/h
# ksat med12:  13.440000000000001 cm/h
# ksat med30:  13.440000000000001 cm/h
# ksat low:  13.440000000000001 cm/h
# --------------------------------------------
# R2:  0.978791656648
# --------------------------------------------
# Simulation error percent (%), by modality
# --------------------------------------------
# 135 mm/h - 6min  -9.94976957607
# 55 mm/h - 12min  -19.8638562158
# 55 mm/h - 30min  -4.35039476974
# 30 mm/h - 30min  -15.6438758946
# --------------------------------------------
# Mass balance:  True True True True

# %%
title = "Percolated Volume [mL] - " + str(soil_type) + "1st Pulse"

# %%
extract_and_plothydro(
    water_data,
    "Percolated at 135mm/h", "Percolated at 55mm/h", "Percolated at 30mm/h", "NA",
    title,
    soil,
    isFirstCycle = True,
    isPercolation = True
)

# %%
hydro1 = extract(
    water_data, 
    isFirstCycle = True
)

percol_data1 = hydro1[0]
runoff_data1 = hydro1[1]
time_sizes1 = hydro1[2]


# Cummulative leaching
cum_leach_135mmh = water_data[:, 7]
cum_leach_55mmh = water_data[:, 8]
cum_leach_30mmh = water_data[:, 9]

# %%
print ("Modelled percolation for 1st pulse, Crop soil (mL):") 

print("135 mm/h at 6 min", cum_leach_135mmh[5]/1000)
 
print("55 mm/h at 12 min", cum_leach_55mmh[11]/1000)

print("55 mm/h at 30 min:" , cum_leach_55mmh[-1]/1000)

print("30 mm/h at 30 min:", cum_leach_30mmh[-1]/1000)
# Out:
# Modelled percolation for 1st pulse, Crop soil (mL):
# 135 mm/h at 6 min 14.1806301853
# 55 mm/h at 12 min 9.66383686699
# 55 mm/h at 30 min: 44.4536495882
# 30 mm/h at 30 min: 17.8570898629

# %% [markdown]
# ## Transport - 1st pulse

# %% [markdown]
# ### Computation transport - 1st pulse

# %% [markdown]
# #### Test factor X (Sterile)

# %%
x = 2

# %%
pest_sterile_1st = pest_linear_x(
    Kd_pest_sterile,
    x,
    initial_condition,
    pest_dict_S_1st,          
    pb_i1, pb_f1,
    percol_data1, runoff_data1,
    time_sizes1,
    area, soil_height1, 
    d, runoff_vel,
    soil,
    isFirstCycle = True,
    isLiving = False,
    KFILM = True)

output_pesti_params = extract_goodness_pest(
        pest_sterile_1st,
        output_pesti_params,
        soil_short,
        isLiving = False,
        isFirstCycle = True)
# Out:
# 1st Pulse
# Sterile Crop
# --------------------------------------------
# Koc tested:  [ 369.  300.  250.  225.  200.  150.  125.  100.   75.   50.   30.]
# Best Kd (Fresh):  5.6115 cm3/g ( Num:  3 )
#  x factor:  2
#  R2:  0.698184328832
#  Effective Koc (fresh) - [cm3/g]: 125.0
# --------------------------------------------
# Best Kd (Aged):  3.3669 cm3/g ( Num:  6 )
#  x factor: No factor considered.
#  R2:  0.377682633172
#  Effective Koc (aged) [cm3/g]: 150.0
# --------------------------------------------
# --------------------------------------------
# Scenario - modality - Predicted error prcnt (%) | Predicted | Observed |
# --------------------------------------------
# (A) 135 mm/h - Fresh  -24.8363754061 | 49.3825013582 | 65.7
# (A) 135 mm/h - Aged  -63.0828063974 | 28.6846594292 | 77.7
# (B) 55 mm/h - Fresh  -36.6326192903 | 50.3770676642 | 79.5
# (B) 55 mm/h - Aged  73.2045892765 | 29.2715755877 | 16.9
# (C) 55 mm/h - Fresh  -15.1212113381 | 277.893154079 | 327.4
# (C) 55 mm/h - Aged  20.5292171427 | 184.891819097 | 153.4
# (D) 30 mm/h - Fresh  165.580192461 | 285.980411839 | 70.9
# (D) 30 mm/h - Aged  4.57692360478 | 194.573751813 | 110.7

# %% [markdown]
# #### Test factor X (Living)

# %%
x = 2

# %%
pest_living_1st = pest_linear_x(
    Kd_pest_living,
    x,
    initial_condition,
    pest_dict_L_1st,          
    pb_i1, pb_f1,
    percol_data1, percol_data1,
    time_sizes1,
    area, soil_height1, 
    d, runoff_vel,
    soil,
    KFILM = True,
    isFirstCycle = True,
    isLiving = True)


output_pesti_params = extract_goodness_pest(
        pest_living_1st,
        output_pesti_params,
        soil_short,
        isLiving = True,
        isFirstCycle = True)
# Out:
# 1st Pulse
# Living Crop
# --------------------------------------------
# Koc tested:  [ 369.  300.  250.  225.  200.  150.  125.  100.   75.   50.   30.]
# Best Kd (Fresh):  3.99475 cm3/g ( Num:  7 )
#  x factor:  2
#  R2:  0.886630467601
#  Effective Koc (fresh) - [cm3/g]: 62.5
# --------------------------------------------
# Best Kd (Aged):  2.39685 cm3/g ( Num:  9 )
#  x factor: No factor considered.
#  R2:  -0.174336579209
#  Effective Koc (aged) [cm3/g]: 75.0
# --------------------------------------------
# --------------------------------------------
# Scenario - modality - Predicted error prcnt (%) | Predicted | Observed |
# --------------------------------------------
# (A) 135 mm/h - Fresh  13.2416870302 | 60.5843025611 | 53.5
# (A) 135 mm/h - Aged  -59.9365680209 | 35.7365813253 | 89.2
# (B) 55 mm/h - Fresh  24.0384327668 | 61.2749857868 | 49.4
# (B) 55 mm/h - Aged  -48.7126995272 | 36.1575468333 | 70.5
# (C) 55 mm/h - Fresh  -10.7265165325 | 251.483402928 | 281.7
# (C) 55 mm/h - Aged  46.1435581106 | 170.111101641 | 116.4
# (D) 30 mm/h - Fresh  36.3809340997 | 258.41341647 | 142.7
# (D) 30 mm/h - Aged  -3.34808635145 | 176.492519737 | 127.2

# %% [markdown]
# #### Time series

# %%
data_stack = pest_sterile_1st['Data_stack']
sterile1 = extract_pest(data_stack)

mass_percol_sterile1 = sterile1[0]
mass_pond_sterile1 = sterile1[1]

# %%
data_stack = pest_living_1st['Data_stack']
living1 = extract_pest(data_stack)

mass_percol_living1 = living1[0]
mass_pond_living1 = living1[1]

# %% [markdown]
# ## Plotting transport

# %% [markdown]
# ### Sterile (1st Pulse, Crop Soil)

# %%
pestiplot_condition(
    mass_percol_sterile1,
    pest_dict_S_1st,
    pesticide,
    soil_type,
    cycle = '1st pulse',
    LEACH = True,
    STERILE = True
)

# %% [markdown]
# ### Living (1st Pulse, Crop Soil)

# %%
pestiplot_condition(
    mass_percol_living1,
    pest_dict_L_1st,
    pesticide,
    soil_type,
    cycle = '1st pulse',
    LEACH = True,
    STERILE = False
)

# %% [markdown]
# # Hydrology - 2nd pulse

# %% [markdown]
# ### Inverse Ksat determination
#
# Based on hisotric rainfall pattern, fresh and aged.

# %%
water2_ktest = leachsim3(
    soil,
    kSat = [ kSat/5, kSat/10, kSat/15,
        kSat/25, kSat/50,  kSat/75, 
        kSat/100, kSat/125, kSat/150, 
        kSat/175, kSat/200, kSat/250,
        kSat/350, kSat/500, kSat/700, kSat/1000],
    soil_height=soil_height2,
    isFirstCycle = False
)

output_hydro_params = extract_goodness(
    water2_ktest,
    output_hydro_params,
    soil_short,
    isFirstCycle = False,
    isAGED = None
)
# Out:
# R2:  0.987094816986
# --------------------------------------------
# Sterile, Fresh Soil
# ksat high:  0.5376000000000001 cm/h | Error % 2.23130461905
# ksat med12:  0.5376000000000001 cm/h | Error % 3.03794067885
# ksat med30:  0.07680000000000001 cm/h | Error % -1.32673504375
# ksat low:  2.6880000000000006 cm/h | Error % 2.71814968991
# --------------------------------------------
# Sterile, Aged Soil
# ksat high:  0.038400000000000004 cm/h | Error % -3.96936053404
# ksat med12:  0.01344 cm/h | Error % 96.4892134055
# ksat med30:  0.01344 cm/h | Error % 0.668887214674
# ksat low:  0.01344 cm/h | Error % 772.613137848
# --------------------------------------------
# Living, Fresh Soil
# ksat high:  0.17920000000000003 cm/h | Error % 1.83525165621
# ksat med12:  0.5376000000000001 cm/h | Error % 1.25918043976
# ksat med30:  0.01344 cm/h | Error % 43.2893178308
# ksat low:  0.05376 cm/h | Error % -1.06637611809
# --------------------------------------------
# Living, Fresh Aged
# ksat high:  0.07680000000000001 cm/h | Error % 0.104102352786
# ksat med12:  0.17920000000000003 cm/h | Error % 2.93205693237
# ksat med30:  0.17920000000000003 cm/h | Error % -4.2848362011
# ksat low:  0.01344 cm/h | Error % 5.43538356862
# --------------------------------------------

# %% [markdown]
# ### Percolation - 2nd pulse

# %%
title = "Percolated Volume [mL] - " + str(soil_type) +  " 2nd Pulse"

# %%
extract_and_plothydro(
    water2_ktest,
    "Leached, 135mm/h", "Leached, 55mm/h - A", "Leached, 55mm/h - B", "Leached, 30mm/h",
    title,
    soil,
    isFirstCycle = False,
    isPercolation = True
)

# %%
# Cummulative percolation (2nd pulse)
cum_leach_135mmh_SF = water2_ktest[0][:, 2]
cum_leach_135mmh_SA = water2_ktest[0][:, 4]
cum_leach_135mmh_LF = water2_ktest[0][:, 6]
cum_leach_135mmh_LA = water2_ktest[0][:, 8]

cum_leach_55mmhA_SF = water2_ktest[0][:, 10]
cum_leach_55mmhA_SA = water2_ktest[0][:, 12]
cum_leach_55mmhA_LF = water2_ktest[0][:, 14]
cum_leach_55mmhA_LA = water2_ktest[0][:, 16]

cum_leach_55mmhB_SF = water2_ktest[0][:, 18]
cum_leach_55mmhB_SA = water2_ktest[0][:, 20]
cum_leach_55mmhB_LF = water2_ktest[0][:, 22]
cum_leach_55mmhB_LA = water2_ktest[0][:, 24]

cum_leach_30mmh_SF = water2_ktest[0][:, 26]
cum_leach_30mmh_SA = water2_ktest[0][:, 28]
cum_leach_30mmh_LF = water2_ktest[0][:, 30]
cum_leach_30mmh_LA = water2_ktest[0][:, 32]

# %%
print ("Modelled percolation for 2nd pulse, Crop soil (mL):") 
print ("-----")
print("For 135 mm/h at 6 min:")
print("Fresh", cum_leach_135mmh_LF[5]/1000)
print("Aged", cum_leach_135mmh_LA[5]/1000)
print ("-----")
print ("-----")
print("A")
print("For 55 mm/h at 12 min:")
print("Fresh", cum_leach_55mmhA_LF[11]/1000)
print("Aged", cum_leach_55mmhA_LA[11]/1000)
print ("-----")
print("For 55 mm/h at 30 min:")
print("Fresh", cum_leach_55mmhA_LF[-1]/1000)
print("Aged", cum_leach_55mmhA_LA[-1]/1000)
print ("-----")
print ("-----")
print("B")
print("For 55 mm/h at 12 min:")
print("Fresh", cum_leach_55mmhB_LF[11]/1000)
print("Aged", cum_leach_55mmhB_LA[11]/1000)
print ("-----")
print("For 55 mm/h at 30 min:")
print("Fresh", cum_leach_55mmhB_LF[-1]/1000)
print("Aged", cum_leach_55mmhB_LA[-1]/1000)
print ("-----")
print ("-----")
print("For 30 mm/h at 30 min:")
print("Fresh", cum_leach_30mmh_LF[-1]/1000)
print("Aged", cum_leach_30mmh_LA[-1]/1000)
# Out:
# Modelled percolation for 2nd pulse, Crop soil (mL):
# -----
# For 135 mm/h at 6 min:
# Fresh 8.39631649905
# Aged 5.47469335767
# -----
# -----
# A
# For 55 mm/h at 12 min:
# Fresh 19.2392442836
# Aged 11.7414597343
# -----
# For 55 mm/h at 30 min:
# Fresh 34.1365106484
# Aged 19.4215638864
# -----
# -----
# B
# For 55 mm/h at 12 min:
# Fresh 1.63086047127
# Aged 11.7414597343
# -----
# For 55 mm/h at 30 min:
# Fresh 3.54354482996
# Aged 19.4215638864
# -----
# -----
# For 30 mm/h at 30 min:
# Fresh 9.27502723893
# Aged 3.5689877338

# %% [markdown]
# ### Ponding - 2nd pulse

# %%
title = "Ponded Volume [mL] [mL] - " + str(soil_type) +  " 2nd Pulse"

# %%
extract_and_plothydro(
    water2_ktest,
    "Ponded, 135mm/h", "Ponded, 55mm/h - A", "Ponded, 55mm/h - B", "Ponded, 30mm/h",
    title,
    soil,
    isFirstCycle = False,
    isPercolation = False
)

# %%
# Ponding cumulative
cum_roff_135mmh_SF = water2_ktest[0][:, 1]
cum_roff_135mmh_SA = water2_ktest[0][:, 3]
cum_roff_135mmh_LF = water2_ktest[0][:, 5]
cum_roff_135mmh_LA = water2_ktest[0][:, 7]

#A
cum_roff_55mmhA_SF = water2_ktest[0][:, 9]
cum_roff_55mmhA_SA = water2_ktest[0][:, 11]
cum_roff_55mmhA_LF = water2_ktest[0][:, 13]
cum_roff_55mmhA_LA = water2_ktest[0][:, 15]
#B
cum_roff_55mmhB_SF = water2_ktest[0][:, 17]
cum_roff_55mmhB_SA = water2_ktest[0][:, 19]
cum_roff_55mmhB_LF = water2_ktest[0][:, 21]
cum_roff_55mmhB_LA = water2_ktest[0][:, 23]

cum_roff_30mmh_SF = water2_ktest[0][:, 25]
cum_roff_30mmh_SA = water2_ktest[0][:, 27]
cum_roff_30mmh_LF = water2_ktest[0][:, 29]
cum_roff_30mmh_LA = water2_ktest[0][:, 31]

# %%
print ("Modelled ponding for 2nd pulse, Crop soil (mL):") 
print ("-----")
print("For 135 mm/h at 6 min:")
print("Fresh", cum_roff_135mmh_LF[5]/1000)
print("Aged", cum_roff_135mmh_LA[5]/1000)
print ("-----")
print ("-----")
print("A")
print("For 55 mm/h at 12 min:")
print("Fresh", cum_roff_55mmhA_LF[11]/1000)
print("Aged", cum_roff_55mmhA_LA[11]/1000)
print ("-----")
print("For 55 mm/h at 30 min:")
print("Fresh", cum_roff_55mmhA_LF[-1]/1000)
print("Aged", cum_roff_55mmhA_LA[-1]/1000)
print ("-----")
print ("-----")
print("B")
print("For 55 mm/h at 12 min:")
print("Fresh", cum_roff_55mmhB_LF[11]/1000)
print("Aged", cum_roff_55mmhB_LA[11]/1000)
print ("-----")
print("For 55 mm/h at 30 min:")
print("Fresh", cum_roff_55mmhB_LF[-1]/1000)
print("Aged", cum_roff_55mmhB_LA[-1]/1000)
print ("-----")
print ("-----")
print("For 30 mm/h at 30 min:")
print("Fresh", cum_roff_30mmh_LF[-1]/1000)
print("Aged", cum_roff_30mmh_LA[-1]/1000)
# Out:
# Modelled ponding for 2nd pulse, Crop soil (mL):
# -----
# For 135 mm/h at 6 min:
# Fresh 19.9649438715
# Aged 22.8865670128
# -----
# -----
# A
# For 55 mm/h at 12 min:
# Fresh 3.95396419723
# Aged 11.4517487465
# -----
# For 55 mm/h at 30 min:
# Fresh 23.8465105536
# Aged 38.5614573155
# -----
# -----
# B
# For 55 mm/h at 12 min:
# Fresh 19.9737461901
# Aged 11.4517487465
# -----
# For 55 mm/h at 30 min:
# Fresh 52.8508745526
# Aged 38.5614573155
# -----
# -----
# For 30 mm/h at 30 min:
# Fresh 21.1870672331
# Aged 26.3922311709

# %%
hydro2 = extract(
    water2_ktest,
    isFirstCycle = False
)
percol_data2 = hydro2[0]
runoff_data2 = hydro2[1]
time_sizes2 = hydro2[2]

# %% [markdown]
# ## Transport - 2nd pulse

# %% [markdown]
# ### Computation transport - 2nd Pulse

# %% [markdown]
# #### Kd optimal (sterile)

# %%
x = 2

# %%
pest_sterile_2nd = pest_linear_x(
    Kd_pest_sterile,
    x,
    initial_condition,
    pest_dict_S_2nd,
    pb_i2, pb_f2,
    percol_data2, runoff_data2,
    time_sizes2,
    area, soil_height2,
    d, runoff_vel,
    soil = "Alteck",
    isFirstCycle = False,
    isLiving = False)

output_pesti_params = extract_goodness_pest(
        pest_sterile_2nd,
        output_pesti_params,
        soil_short,
        isLiving = False,
        isFirstCycle = False)
# Out:
# 2nd Pulse
# Sterile Crop
# --------------------------------------------
# Koc tested:  [ 369.  300.  250.  225.  200.  150.  125.  100.   75.   50.   30.]
# Best Kd (Fresh):  8.282574 cm3/g ( Num:  1 )
#  x factor:  2
#  R2:  0.366019809448
#  Effective Koc (fresh) - [cm3/g]: 184.5
# --------------------------------------------
# Best Kd (Aged):  3.3669 cm3/g ( Num:  6 )
#  x factor: No factor considered.
#  R2:  0.972031203157
#  Effective Koc (aged) [cm3/g]: 150.0
# --------------------------------------------
# --------------------------------------------
# Scenario - modality - Predicted error prcnt (%) | Predicted | Observed |
# --------------------------------------------
# (A) 135 mm/h - Fresh  1268.10394014 | 32.8344945633 | 2.4
# (A) 135 mm/h - Aged  -68.1383308995 | 5.35276040889 | 16.8
# (B) 55 mm/h - Fresh  -25.6334107178 | 61.3524361578 | 82.5
# (B) 55 mm/h - Aged  No obs | 6.13598981751 | nan
# (C) 55 mm/h - Fresh  109.176091726 | 79.2777387643 | 37.9
# (C) 55 mm/h - Aged  29.6263340111 | 32.677807791 | 24.3
# (D) 30 mm/h - Fresh  14.829369646 | 121.729491844 | 102.7
# (D) 30 mm/h - Aged  No obs | 61.844326428 | nan

# %% [markdown]
# #### Kd optimal (living)

# %%
x = 2

# %%
pest_living_2nd = pest_linear_x(
    Kd_pest_living,
    x,
    initial_condition,
    pest_dict_L_2nd,          
    pb_i1, pb_f1,
    percol_data2, runoff_data2,
    time_sizes1,
    area, soil_height1, 
    d, runoff_vel,
    soil = "Alteck",
    KFILM = True,
    isFirstCycle = False,
    isLiving = True)

output_pesti_params = extract_goodness_pest(
        pest_living_2nd,
        output_pesti_params,
        soil_short,
        isLiving = True,
        isFirstCycle = False)
# Out:
# 2nd Pulse
# Living Crop
# --------------------------------------------
# Koc tested:  [ 369.  300.  250.  225.  200.  150.  125.  100.   75.   50.   30.]
# Best Kd (Fresh):  7.9895 cm3/g ( Num:  3 )
#  x factor:  2
#  R2:  -0.284545557463
#  Effective Koc (fresh) - [cm3/g]: 125.0
# --------------------------------------------
# Best Kd (Aged):  3.99475 cm3/g ( Num:  7 )
#  x factor: No factor considered.
#  R2:  0.469937394961
#  Effective Koc (aged) [cm3/g]: 125.0
# --------------------------------------------
# --------------------------------------------
# Scenario - modality - Predicted error prcnt (%) | Predicted | Observed |
# --------------------------------------------
# (A) 135 mm/h - Fresh  -66.2601353778 | 14.7443208399 | 43.7
# (A) 135 mm/h - Aged  -59.621303458 | 8.03536061186 | 19.9
# (B) 55 mm/h - Fresh  -33.0096147634 | 44.749577338 | 66.8
# (B) 55 mm/h - Aged  -30.0685674782 | 26.5040129258 | 37.9
# (C) 55 mm/h - Fresh  11.9610210937 | 18.8094515437 | 16.8
# (C) 55 mm/h - Aged  25.3064852503 | 59.1097915944 | 46.4
# (D) 30 mm/h - Fresh  106.468392095 | 73.4577663761 | 22.7
# (D) 30 mm/h - Aged  -3.36598332702 | 48.6469724454 | 16.7

# %% [markdown]
# #### Time series

# %%
data_stack = pest_sterile_2nd['Data_stack']
sterile2 = extract_pest(data_stack)

data_stack = pest_living_2nd['Data_stack']
living2 = extract_pest(data_stack)

mass_percol_sterile2 = sterile2[0]
mass_pond_sterile2 = sterile2[1]

mass_percol_living2 = living2[0]
mass_pond_living2 = living2[1]

# %% [markdown]
# ## Plotting transport

# %% [markdown]
# ### Sterile (2nd Pulse)

# %%
pestiplot_condition(
    mass_percol_sterile2,
    pest_dict_S_2nd,
    pesticide,
    soil_type,
    cycle = '2nd pulse',
    LEACH = True,
    STERILE = True
)

# %%
pestiplot_condition(
    mass_pond_sterile2,
    pest_dict_S_2nd,
    pesticide,
    soil_type,
    cycle = '2nd pulse',
    LEACH = False,
    STERILE = True
)

# %% [markdown]
# ### Living (2nd Pulse)

# %%
pestiplot_condition(
    mass_percol_living2,
    pest_dict_L_2nd,
    pesticide,
    soil_type,
    cycle = '2nd pulse',
    LEACH = True,
    STERILE = False
)

# %%
pestiplot_condition(
    mass_pond_living2,
    pest_dict_L_2nd,
    pesticide,
    soil_type,
    cycle = '2nd pulse',
    LEACH = False,
    STERILE = False
)

# %% [markdown]
# END NOTEBOOK

# %% [markdown]
# ### Max values

# %%
initial_condition = 'max'

# %% [markdown]
# #### 1st Pulse

# %%
Kd1_SF = output_pesti_params[soil_short]['Kd1']['SF']*10**3  # Convert back to mm3/g (model units)
Kd1_SA = output_pesti_params[soil_short]['Kd1']['SA']*10**3
Kd1_choice_sterile = [Kd1_SF, Kd1_SA]

Kd1_LF = output_pesti_params[soil_short]['Kd1']['LF']*10**3
Kd1_LA = output_pesti_params[soil_short]['Kd1']['LA']*10**3
Kd1_choice_living = [Kd1_LF, Kd1_LA]

# %%
max_sterile_1st = pest_Kd_choice(
    Kd1_choice_sterile,
    x,
    initial_condition,
    pest_dict_S_1st,          
    pb_i1, pb_f1,
    percol_data1, runoff_data1,
    time_sizes1,
    area, soil_height1, 
    d, runoff_vel,
    soil,
    isFirstCycle = True,
    isLiving = False,
    KFILM = True)

output_pesti_params = extract_goodness_maxmin(
        max_sterile_1st,
        initial_condition,
        output_pesti_params,
        soil_short,
        isLiving = False,
        isFirstCycle = True)
# Out:
# 1st Pulse
# Sterile Crop
# --------------------------------------------
# Koc tested:  [ 250.  150.]
# Best Kd (Fresh):  5.6115 cm3/g ( Num:  1 )
#  x factor:  2
#  R2:  0.425725882118
#  Effective Koc (fresh) - [cm3/g]: 125.0
# --------------------------------------------
# Best Kd (Aged):  3.3669 cm3/g ( Num:  2 )
#  x factor: No factor considered.
#  R2:  -1.7118365358
#  Effective Koc (aged) [cm3/g]: 150.0
# --------------------------------------------
# --------------------------------------------
# Scenario - modality - Predicted error prcnt (%) | Predicted | Observed |
# --------------------------------------------
# (A) 135 mm/h - Fresh  28.5126211856 | 84.4327921189 | 65.7
# (A) 135 mm/h - Aged  -50.8153380146 | 38.2164823626 | 77.7
# (B) 55 mm/h - Fresh  -16.3501808649 | 66.5016062124 | 79.5
# (B) 55 mm/h - Aged  130.759934506 | 38.9984289315 | 16.9
# (C) 55 mm/h - Fresh  12.0465330973 | 366.840349361 | 327.4
# (C) 55 mm/h - Aged  60.5807003735 | 246.330794373 | 153.4
# (D) 30 mm/h - Fresh  250.58629245 | 374.777836389 | 70.9
# (D) 30 mm/h - Aged  39.3275094078 | 259.230003157 | 110.7

# %%
max_living_1st = pest_Kd_choice(
    Kd1_choice_living,
    x,
    initial_condition,
    pest_dict_L_1st,          
    pb_i1, pb_f1,
    percol_data1, runoff_data1,
    time_sizes1,
    area, soil_height1, 
    d, runoff_vel,
    soil,
    isFirstCycle = True,
    isLiving = False,
    KFILM = True)

output_pesti_params = extract_goodness_maxmin(
        max_living_1st,
        initial_condition,
        output_pesti_params,
        soil_short,
        isLiving = True,
        isFirstCycle = True)
# Out:
# 1st Pulse
# Sterile Crop
# --------------------------------------------
# Koc tested:  [ 177.97157623  106.78294574]
# Best Kd (Fresh):  3.99475 cm3/g ( Num:  1 )
#  x factor:  2
#  R2:  0.331409107909
#  Effective Koc (fresh) - [cm3/g]: 88.9857881137
# --------------------------------------------
# Best Kd (Aged):  2.39685 cm3/g ( Num:  2 )
#  x factor: No factor considered.
#  R2:  -11.5715247822
#  Effective Koc (aged) [cm3/g]: 106.782945736
# --------------------------------------------
# --------------------------------------------
# Scenario - modality - Predicted error prcnt (%) | Predicted | Observed |
# --------------------------------------------
# (A) 135 mm/h - Fresh  92.3099002193 | 102.885796617 | 53.5
# (A) 135 mm/h - Aged  -46.1345872175 | 48.047948202 | 89.2
# (B) 55 mm/h - Fresh  67.3238685655 | 82.6579910713 | 49.4
# (B) 55 mm/h - Aged  -30.4959923546 | 49.00032539 | 70.5
# (C) 55 mm/h - Fresh  24.6720719358 | 351.201226643 | 281.7
# (C) 55 mm/h - Aged  105.876364518 | 239.640088299 | 116.4
# (D) 30 mm/h - Fresh  91.2274636058 | 350.279824142 | 142.7
# (D) 30 mm/h - Aged  36.3507114964 | 243.543442942 | 127.2

# %% [markdown]
# #### 2ndPulse Pulse

# %%
Kd2_SF = output_pesti_params[soil_short]['Kd2']['SF']*10**3
Kd2_SA = output_pesti_params[soil_short]['Kd2']['SA']*10**3
Kd2_choice_sterile = [Kd2_SF, Kd2_SA]

Kd2_LF = output_pesti_params[soil_short]['Kd2']['LF']*10**3
Kd2_LA = output_pesti_params[soil_short]['Kd2']['LA']*10**3
Kd2_choice_living = [Kd2_LF, Kd2_LA]

# %%
max_sterile_2nd = pest_Kd_choice(
    Kd2_choice_sterile,
    x,
    initial_condition,
    pest_dict_S_2nd,          
    pb_i2, pb_f2,
    percol_data2, runoff_data2,
    time_sizes2,
    area, soil_height2, 
    d, runoff_vel,
    soil,
    isFirstCycle = False,
    isLiving = False)

output_pesti_params = extract_goodness_maxmin(
        max_sterile_2nd,
        initial_condition,
        output_pesti_params,
        soil_short,
        isLiving = False,
        isFirstCycle = False)
# Out:
# 2nd Pulse
# Sterile Crop
# --------------------------------------------
# Koc tested:  [ 369.  150.]
# Best Kd (Fresh):  8.282574 cm3/g ( Num:  1 )
#  x factor:  2
#  R2:  -1.48717189919
#  Effective Koc (fresh) - [cm3/g]: 184.5
# --------------------------------------------
# Best Kd (Aged):  3.3669 cm3/g ( Num:  2 )
#  x factor: No factor considered.
#  R2:  0.911754326974
#  Effective Koc (aged) [cm3/g]: 150.0
# --------------------------------------------
# --------------------------------------------
# Scenario - modality - Predicted error prcnt (%) | Predicted | Observed |
# --------------------------------------------
# (A) 135 mm/h - Fresh  1882.12761928 | 47.5710628628 | 2.4
# (A) 135 mm/h - Aged  -53.1898480381 | 7.8641055296 | 16.8
# (B) 55 mm/h - Fresh  7.85424582426 | 88.979752805 | 82.5
# (B) 55 mm/h - Aged  No obs | 8.96700585029 | nan
# (C) 55 mm/h - Fresh  209.01707154 | 117.117470114 | 37.9
# (C) 55 mm/h - Aged  91.7542766221 | 47.7546577408 | 24.3
# (D) 30 mm/h - Fresh  66.4498777497 | 176.363345493 | 102.7
# (D) 30 mm/h - Aged  No obs | 90.8597195251 | nan

# %%
max_living_2nd = pest_Kd_choice(
    Kd2_choice_living,
    x,
    initial_condition,
    pest_dict_L_2nd,          
    pb_i2, pb_f2,
    percol_data2, runoff_data2,
    time_sizes2,
    area, soil_height2, 
    d, runoff_vel,
    soil,
    isFirstCycle = False,
    isLiving = True)

output_pesti_params = extract_goodness_maxmin(
        max_living_2nd,
        initial_condition,
        output_pesti_params,
        soil_short,
        isLiving = True,
        isFirstCycle = False)
# Out:
# 2nd Pulse
# Living Crop
# --------------------------------------------
# Koc tested:  [ 250.  125.]
# Best Kd (Fresh):  7.9895 cm3/g ( Num:  1 )
#  x factor:  2
#  R2:  -0.744309697797
#  Effective Koc (fresh) - [cm3/g]: 125.0
# --------------------------------------------
# Best Kd (Aged):  3.99475 cm3/g ( Num:  2 )
#  x factor: No factor considered.
#  R2:  -1.07831927899
#  Effective Koc (aged) [cm3/g]: 125.0
# --------------------------------------------
# --------------------------------------------
# Scenario - modality - Predicted error prcnt (%) | Predicted | Observed |
# --------------------------------------------
# (A) 135 mm/h - Fresh  -50.6372594606 | 21.5715176157 | 43.7
# (A) 135 mm/h - Aged  -42.5687476751 | 11.4288192126 | 19.9
# (B) 55 mm/h - Fresh  -4.68900975285 | 63.6677414851 | 66.8
# (B) 55 mm/h - Aged  0.105051268655 | 37.9398144308 | 37.9
# (C) 55 mm/h - Fresh  62.1495137619 | 27.241118312 | 16.8
# (C) 55 mm/h - Aged  83.191005137 | 86.3156081886 | 46.4
# (D) 30 mm/h - Fresh  196.464350871 | 106.284210659 | 22.7
# (D) 30 mm/h - Aged  38.4459701553 | 70.4663978403 | 16.7

# %% [markdown]
# ### Min values

# %%
initial_condition = 'min'

# %% [markdown]
# #### 1st Pulse

# %%
min_sterile_1st = pest_Kd_choice(
    Kd1_choice_sterile,
    x,
    initial_condition,
    pest_dict_S_1st,          
    pb_i1, pb_f1,
    percol_data1, runoff_data1,
    time_sizes1,
    area, soil_height1, 
    d, runoff_vel,
    soil,
    isFirstCycle = True,
    isLiving = False,
    KFILM = True)

output_pesti_params = extract_goodness_maxmin(
        min_sterile_1st,
        initial_condition,
        output_pesti_params,
        soil_short,
        isLiving = False,
        isFirstCycle = True)
# Out:
# 1st Pulse
# Sterile Crop
# --------------------------------------------
# Koc tested:  [ 250.  150.]
# Best Kd (Fresh):  5.6115 cm3/g ( Num:  1 )
#  x factor:  2
#  R2:  0.573675959121
#  Effective Koc (fresh) - [cm3/g]: 125.0
# --------------------------------------------
# Best Kd (Aged):  3.3669 cm3/g ( Num:  2 )
#  x factor: No factor considered.
#  R2:  -0.174376446783
#  Effective Koc (aged) [cm3/g]: 150.0
# --------------------------------------------
# --------------------------------------------
# Scenario - modality - Predicted error prcnt (%) | Predicted | Observed |
# --------------------------------------------
# (A) 135 mm/h - Fresh  -33.8078799951 | 43.4882228432 | 65.7
# (A) 135 mm/h - Aged  -75.3502747802 | 19.1528364958 | 77.7
# (B) 55 mm/h - Fresh  -56.9150577158 | 34.252529116 | 79.5
# (B) 55 mm/h - Aged  15.6492440468 | 19.5447222439 | 16.9
# (C) 55 mm/h - Fresh  -42.2889557735 | 188.945958798 | 327.4
# (C) 55 mm/h - Aged  -19.5222660882 | 123.452843821 | 153.4
# (D) 30 mm/h - Fresh  80.5740924729 | 193.034266149 | 70.9
# (D) 30 mm/h - Aged  -30.1736621982 | 129.917500469 | 110.7

# %%
min_living_1st = pest_Kd_choice(
    Kd1_choice_living,
    x,
    initial_condition,
    pest_dict_L_1st,          
    pb_i1, pb_f1,
    percol_data1, runoff_data1,
    time_sizes1,
    area, soil_height1, 
    d, runoff_vel,
    soil,
    isFirstCycle = True,
    isLiving = False,
    KFILM = True)

output_pesti_params = extract_goodness_maxmin(
        min_living_1st,
        initial_condition,
        output_pesti_params,
        soil_short,
        isLiving = True,
        isFirstCycle = True)
# Out:
# 1st Pulse
# Sterile Crop
# --------------------------------------------
# Koc tested:  [ 177.97157623  106.78294574]
# Best Kd (Fresh):  3.99475 cm3/g ( Num:  1 )
#  x factor:  2
#  R2:  0.712491358402
#  Effective Koc (fresh) - [cm3/g]: 88.9857881137
# --------------------------------------------
# Best Kd (Aged):  2.39685 cm3/g ( Num:  2 )
#  x factor: No factor considered.
#  R2:  -4.18219042062
#  Effective Koc (aged) [cm3/g]: 106.782945736
# --------------------------------------------
# --------------------------------------------
# Scenario - modality - Predicted error prcnt (%) | Predicted | Observed |
# --------------------------------------------
# (A) 135 mm/h - Fresh  -2.67654918567 | 52.0680461857 | 53.5
# (A) 135 mm/h - Aged  -73.1053548929 | 23.9900234355 | 89.2
# (B) 55 mm/h - Fresh  -15.3213834866 | 41.8312365576 | 49.4
# (B) 55 mm/h - Aged  -65.2971076878 | 24.4655390801 | 70.5
# (C) 55 mm/h - Fresh  -36.906439829 | 177.734559002 | 281.7
# (C) 55 mm/h - Aged  2.7927100829 | 119.650714536 | 116.4
# (D) 30 mm/h - Fresh  -3.22434452224 | 177.268259186 | 142.7
# (D) 30 mm/h - Aged  -31.9209896228 | 121.599633749 | 127.2

# %% [markdown]
# #### 2nd Pulse

# %%
min_sterile_2nd = pest_Kd_choice(
    Kd2_choice_sterile,
    x,
    initial_condition,
    pest_dict_S_2nd,          
    pb_i2, pb_f2,
    percol_data2, runoff_data2,
    time_sizes2,
    area, soil_height2, 
    d, runoff_vel,
    soil,
    isFirstCycle = False,
    isLiving = False)

output_pesti_params = extract_goodness_maxmin(
        min_sterile_2nd,
        initial_condition,
        output_pesti_params,
        soil_short,
        isLiving = False,
        isFirstCycle = False)
# Out:
# 2nd Pulse
# Sterile Crop
# --------------------------------------------
# Koc tested:  [ 369.  150.]
# Best Kd (Fresh):  8.282574 cm3/g ( Num:  1 )
#  x factor:  2
#  R2:  0.223066178047
#  Effective Koc (fresh) - [cm3/g]: 184.5
# --------------------------------------------
# Best Kd (Aged):  3.3669 cm3/g ( Num:  2 )
#  x factor: No factor considered.
#  R2:  0.960659553417
#  Effective Koc (aged) [cm3/g]: 150.0
# --------------------------------------------
# --------------------------------------------
# Scenario - modality - Predicted error prcnt (%) | Predicted | Observed |
# --------------------------------------------
# (A) 135 mm/h - Fresh  654.080260994 | 18.0979262639 | 2.4
# (A) 135 mm/h - Aged  -83.0868137608 | 2.84141528818 | 16.8
# (B) 55 mm/h - Fresh  -59.1210672599 | 33.7251195106 | 82.5
# (B) 55 mm/h - Aged  No obs | 3.30497378473 | nan
# (C) 55 mm/h - Fresh  9.33511191238 | 41.4380074148 | 37.9
# (C) 55 mm/h - Aged  -32.5016085999 | 17.6009578412 | 24.3
# (D) 30 mm/h - Fresh  -36.7911384576 | 67.0956381949 | 102.7
# (D) 30 mm/h - Aged  No obs | 32.8289333309 | nan

# %%
min_living_2nd = pest_Kd_choice(
    Kd2_choice_living,
    x,
    initial_condition,
    pest_dict_L_2nd,          
    pb_i2, pb_f2,
    percol_data2, runoff_data2,
    time_sizes2,
    area, soil_height2, 
    d, runoff_vel,
    soil,
    isFirstCycle = False,
    isLiving = True)

output_pesti_params = extract_goodness_maxmin(
        min_living_2nd,
        initial_condition,
        output_pesti_params,
        soil_short,
        isLiving = True,
        isFirstCycle = False)
# Out:
# 2nd Pulse
# Living Crop
# --------------------------------------------
# Koc tested:  [ 250.  125.]
# Best Kd (Fresh):  7.9895 cm3/g ( Num:  1 )
#  x factor:  2
#  R2:  -1.15746576952
#  Effective Koc (fresh) - [cm3/g]: 125.0
# --------------------------------------------
# Best Kd (Aged):  3.99475 cm3/g ( Num:  2 )
#  x factor: No factor considered.
#  R2:  -0.566867434488
#  Effective Koc (aged) [cm3/g]: 125.0
# --------------------------------------------
# --------------------------------------------
# Scenario - modality - Predicted error prcnt (%) | Predicted | Observed |
# --------------------------------------------
# (A) 135 mm/h - Fresh  -81.8047900367 | 7.95130675396 | 43.7
# (A) 135 mm/h - Aged  -79.7705765057 | 4.02565527538 | 19.9
# (B) 55 mm/h - Fresh  -64.8001121244 | 23.5135251009 | 66.8
# (B) 55 mm/h - Aged  -64.407439967 | 13.4895802525 | 37.9
# (C) 55 mm/h - Fresh  -45.932618313 | 9.08332012342 | 16.8
# (C) 55 mm/h - Aged  -36.3598761781 | 30.6896947487 | 46.4
# (D) 30 mm/h - Fresh  5.24236017901 | 39.1765835445 | 22.7
# (D) 30 mm/h - Aged  -52.2094621055 | 24.8208866484 | 16.7

# %% [markdown]
# ### Hydrology summary

# %%
import pprint

# %% [markdown]
# ### R-squared

# %%
# 1st pulse
output_hydro_params[soil_short][0]['R1_FA']
# Out:
# [0.97929313769194559, 0.97879165664847734]

# %%
# 2nd pulse 
output_hydro_params[soil_short][0]['R2_ALL']
# Out:
# [0.98709481698576096]

# %% [markdown]
# ### Percent error

# %%
# 1st pulse
pprint.pprint(output_hydro_params[soil_short][0]['Err1'][0])
# Out:
# {'Aged': [-9.9497695760673803,
#           -19.863856215843292,
#           -4.3503947697446481,
#           -15.643875894555064],
#  'Fresh': [-1.6576800420983793,
#            29.76210753442875,
#            0.19339757059332816,
#            -4.4427680131527749]}

# %%
# 2nd pulse
pprint.pprint(output_hydro_params[soil_short][0]['Err2'][0])
# Out:
# {'LA': [0.1041023527855152,
#         2.9320569323726215,
#         -4.2848362010996981,
#         5.4353835686236112],
#  'LF': [1.8352516562050032,
#         1.2591804397577877,
#         43.289317830834683,
#         -1.0663761180911517],
#  'SA': [-3.9693605340439162,
#         96.489213405488485,
#         0.66888721467447454,
#         772.61313784789968],
#  'SF': [2.2313046190469246,
#         3.0379406788452177,
#         -1.3267350437542793,
#         2.7181496899109967]}

# %% [markdown]
# ## Transport

# %% [markdown]
# ### Summary tables
#
# 0. High rainfall intensity (135 mm/h) at 6 min.
# 1. Medium rainfall intensity (55 mm/h) at 12 min.
# 2. Medium rainfall intensity (55 mm/h) at 30 min.
# 3. Low rainfall intensity (30 mm/h) at 30 min.
#
#     a) LA : Living Aged
#
#     b) LF : Living Fresh
#
#     c) SA : Sterile Aged
#
#     d) SF : Sterile Fresh
#
#
# To compute max and min simualtions, the optimal Kd values obtained from the mean scenario were used. That is, the model has not been fitted to consider these extreme uncertainty scenarios.
#
# - max: initial calculated concentration + measurement error
#
# - min: initial calculated concentraion - measurement error

# %%
import pandas as pd

# %% [markdown]
# ### Percent error

# %%
pd.DataFrame.from_dict(output_pesti_params[soil_short]['Err1'], orient='columns')
# Out:
#           LA       LAmax      LAmin         LF      LFmax      LFmin  \
# 0 -59.936568  -46.134587 -73.105355  13.241687  92.309900  -2.676549
# 1 -48.712700  -30.495992 -65.297108  24.038433  67.323869 -15.321383
# 2  46.143558  105.876365   2.792710 -10.726517  24.672072 -36.906440
# 3  -3.348086   36.350711 -31.920990  36.380934  91.227464  -3.224345
#
#           SA       SAmax      SAmin          SF       SFmax      SFmin
# 0 -63.082806  -50.815338 -75.350275  -24.836375   28.512621 -33.807880
# 1  73.204589  130.759935  15.649244  -36.632619  -16.350181 -56.915058
# 2  20.529217   60.580700 -19.522266  -15.121211   12.046533 -42.288956
# 3   4.576924   39.327509 -30.173662  165.580192  250.586292  80.574092

# %%
pd.DataFrame.from_dict(output_pesti_params[soil_short]['Err2'], orient='columns')
# Out:
#           LA      LAmax      LAmin          LF       LFmax      LFmin  \
# 0 -59.621303 -42.568748 -79.770577  -66.260135  -50.637259 -81.804790
# 1 -30.068567   0.105051 -64.407440  -33.009615   -4.689010 -64.800112
# 2  25.306485  83.191005 -36.359876   11.961021   62.149514 -45.932618
# 3  -3.365983  38.445970 -52.209462  106.468392  196.464351   5.242360
#
#         SA    SAmax    SAmin           SF        SFmax       SFmin
# 0 -68.1383 -53.1898 -83.0868  1268.103940  1882.127619  654.080261
# 1   No obs   No obs   No obs   -25.633411     7.854246  -59.121067
# 2  29.6263  91.7543 -32.5016   109.176092   209.017072    9.335112
# 3   No obs   No obs   No obs    14.829370    66.449878  -36.791138

# %% [markdown]
# ### R-squared & Sorption parameters

# %%
# 1st and 2nd Pulse
df = pd.DataFrame.from_dict(output_pesti_params[soil_short], orient='columns') 
df2 = df[['R1', 'R2', 'Kd1', 'Kd2', 'Koc1', 'Koc2']].dropna(axis=0)
df2
# Out:
#           R1        R2      Kd1       Kd2   Koc1   Koc2
# LA -3.478842  0.469937  2.39685  3.994750   75.0  125.0
# LF  0.899683 -0.284546  3.99475  7.989500   62.5  125.0
# SA  0.229710  0.972031  3.36690  3.366900  150.0  150.0
# SF  0.703867  0.366020  5.61150  8.282574  125.0  184.5

# %%
path = '..\ModelParameters\\' + str(soil_short) + str(pesticide) + '.csv'
df2.to_csv(path, sep=';')
