# %% [markdown]
# START NOTEBOOK

# %% [markdown]
# ## Set-up

# %%
from hydroplots import *
from leach_hydrology import *
import numpy as np

import mpld3
mpld3.enable_notebook()

# Plot graphs within this document
# %matplotlib inline

# Plot graphs outside (for interaction)
# %matplotlib

from pestmob import *
from mixinglayer import *

# %% [markdown]
# ### Pesticide, soil type and runoff calibration parameter.

# %%
# Soil and pesticide
pesticide = 'Cupper'
initial_condition = 'mean'
soil_type = 'Vine Soil'
soil = 'Rouff'
soil_short = 'Vine'

pesti_obs = choose_pesticide(
    pesticide,
    soil)

# Kd ranges to test
Kd_pest_sterile = pesti_obs[0]
Kd_pest_living = pesti_obs[1]

# Initial concentrations and mass out observed
pest_dict_S_1st = pesti_obs[2]
pest_dict_L_1st = pesti_obs[3]
pest_dict_S_2nd = pesti_obs[4]
pest_dict_L_2nd = pesti_obs[5]

# Assumed (used to calculate Reynolds number)
runoff_vel = 10.0  # mm/min

# %% [markdown]
# ### Microcosm

# %%
d = (14.93 * 2)  # Diameter of falcon tube (mm)
area = ((d / 2) ** 2) * 3.1416  # (mm2)
soil_height1 = 20  # Mixing layer depth in mm
soil_height2 = 20  # mm

# %% [markdown]
# ### Soil hydrological characteristics

# %%
if soil == 'Alteck':
    kSat = 2.24  # mm/min (13.45 cm/h - Crop Soil) 
    psi = 1100  # soil suction Alteck (mm)
    eff_height = 0.80
elif soil == 'Rouff': 
    kSat = 17.62*10/60  # mm/min (17.62 cm/h - Vine Soil) 
    psi = 1100  # soil suction Alteck (mm)
    eff_height = 0.76
    
# Soil characteristics (Equivalent for Alteck and Rouffach)
# Initial bulk density options:
pb_i0 = 0.99/10**3  # bulk density (g/cm^3) -> g/mm^3  (M. Trautmann)
pb_i1 = 2.61/10**3 # inital 1st pulse, calc. from experiment cond.
pb_i2 = 3.59/10**3 # initial 2nd pulse, calc. from experiment cond.

# Final bulk density options (1st and 2nd pulses)
pb_f1 = 3.59/10**3 # final1, calculated from experimental conditions.
pb_f2 = 3.76/10**3 # final2, calculated from experimental conditions.

# %% [markdown]
# ### Store results

# %%
output_hydro_params = {
    soil_short : [{'R1_FA':[],
              'R2_ALL':[],
              'Err1':[{'Fresh':[], 'Aged':[]}],
              'Err2':[{'SF':[], 'SA':[], 'LF':[], 'LA':[]}],
              'Ksat2':[{'SF':[], 'SA':[], 'LF':[], 'LA':[]}]
             }]
    }

# %%
output_pesti_params = {
    soil_short: {'R1': {'SF': None, 'SA': None, 'LF': None, 'LA': None},
                 'R2': {'SF': None, 'SA': None, 'LF': None, 'LA': None},
                 'Err1': {'SF': [], 'SA': [], 'LF': [], 'LA': [],
                          'SFmax': [], 'SAmax': [], 'LFmax': [], 'LAmax': [],
                          'SFmin': [], 'SAmin': [], 'LFmin': [], 'LAmin': []},
                 'Err2': {'SF': [], 'SA': [], 'LF': [], 'LA': [],
                          'SFmax': [], 'SAmax': [], 'LFmax': [], 'LAmax': [],
                          'SFmin': [], 'SAmin': [], 'LFmin': [], 'LAmin': []},
                 'Koc1': {'SF': None, 'SA': None, 'LF': None, 'LA': None},
                 'Koc2': {'SF': None, 'SA': None, 'LF': None, 'LA': None},
                 'Kd1': {'SF': None, 'SA': None, 'LF': None, 'LA': None},
                 'Kd2': {'SF': None, 'SA': None, 'LF': None, 'LA': None}
                 }
}

# %% [markdown]
# ## Hydrology - 1st pulse

# %% [markdown]
# #### Computation

# %%
water_data = leachsim(kSat = kSat,
                      soil_height=soil_height1,
                      eff_height=eff_height,
                      soil = 'Alteck',
                      psi=psi)
# Out:
# Mass balance True
# Mass balance 0.0
# Mass balance 0.0

# %%
water_eval = leachsim2(
    kSat = [kSat],
    soil_height=soil_height1,
    eff_height = eff_height,
    soil = 'Alteck',
    isAGED = False,
    isFirstCycle=True 
)

output_hydro_params = extract_goodness(
    water_eval,
    output_hydro_params,
    soil_short,
    isFirstCycle = True,
    isAGED = False)
# Out:
# FRESH
# --------------------------------------------
# ksat high:  17.62 cm/h
# ksat med12:  17.62 cm/h
# ksat med30:  17.62 cm/h
# ksat low:  17.62 cm/h
# --------------------------------------------
# R2:  0.971670449532
# --------------------------------------------
# Simulation error percent (%), by modality
# --------------------------------------------
# 135 mm/h - 6min  -1.6576800421
# 55 mm/h - 12min  55.7145290413
# 55 mm/h - 30min  4.54963224758
# 30 mm/h - 30min  1.17824563313
# --------------------------------------------
# Mass balance:  True True True True

# %%
water_eval = leachsim2(
    kSat = [kSat],
    soil_height=soil_height1,
    eff_height = eff_height,
    soil = 'Alteck',
    isAGED = True,
    isFirstCycle=True 
)

output_hydro_params = extract_goodness(
    water_eval,
    output_hydro_params,
    soil_short,
    isFirstCycle = True,
    isAGED = True)
# Out:
# AGED
# --------------------------------------------
# ksat high:  17.62 cm/h
# ksat med12:  17.62 cm/h
# ksat med30:  17.62 cm/h
# ksat low:  17.62 cm/h
# --------------------------------------------
# R2:  0.989501541182
# --------------------------------------------
# Simulation error percent (%), by modality
# --------------------------------------------
# 135 mm/h - 6min  -9.94976957607
# 55 mm/h - 12min  -3.83662745901
# 55 mm/h - 30min  -0.191716281473
# 30 mm/h - 30min  -10.6817509472
# --------------------------------------------
# Mass balance:  True True True True

# %%
title = "Percolated Volume [mL] - " + str(soil_type) + "1st Pulse"

# %%
extract_and_plothydro(
    water_data,
    "Percolated at 135mm/h", "Percolated at 55mm/h", "Percolated at 30mm/h", "NA",
    title,
    soil,
    isFirstCycle = True,
    isPercolation = True
)

# %%
hydro1 = extract(
    water_data, 
    isFirstCycle = True
)

percol_data1 = hydro1[0]
runoff_data1 = hydro1[1]
time_sizes1 = hydro1[2]

# %% [markdown]
# ## Transport - 1st pulse

# %% [markdown]
# ### Computation transport - 1st pulse

# %% [markdown]
# #### Test factor X (Sterile)

# %%
x = 2

# %%
pest_sterile_1st = pest_linear_x(
    Kd_pest_sterile,
    x,
    initial_condition,
    pest_dict_S_1st,          
    pb_i1, pb_f1,
    percol_data1, runoff_data1,
    time_sizes1,
    area, soil_height1, 
    d, runoff_vel,
    soil,
    isFirstCycle = True,
    isLiving = False,
    KFILM = True)

output_pesti_params = extract_goodness_pest(
        pest_sterile_1st,
        output_pesti_params,
        soil_short,
        isLiving = False,
        isFirstCycle = True)
# Out:
# 1st Pulse
# Sterile Vine
# --------------------------------------------
# Koc tested:  [  6.14889817e+01   1.54453339e+02   1.94445233e+02   3.87969246e+02
#    7.74100416e+02   2.44792045e+03   2.44792045e+04   2.44792045e+07]
# Best Kd (Fresh):  3.16227766017 cm3/g ( Num:  2 )
#  x factor:  2
#  R2:  -0.86484381315
#  Effective Koc (fresh) - [cm3/g]: 77.2266694385
# --------------------------------------------
# Best Kd (Aged):  3.16227766017 cm3/g ( Num:  2 )
#  x factor: No factor considered.
#  R2:  0.550692607399
#  Effective Koc (aged) [cm3/g]: 154.453338877
# --------------------------------------------
# --------------------------------------------
# Scenario - modality - Predicted error prcnt (%) | Predicted | Observed |
# --------------------------------------------
# (A) 135 mm/h - Fresh  285.850443338 | 90.2890037412 | 23.4
# (A) 135 mm/h - Aged  -27.8590831585 | 27.774252984 | 38.5
# (B) 55 mm/h - Fresh  327.637618013 | 121.021445898 | 28.3
# (B) 55 mm/h - Aged  29.1757751432 | 38.3652052175 | 29.7
# (C) 55 mm/h - Fresh  -46.8534322074 | 324.77867578 | 611.1
# (C) 55 mm/h - Aged  -70.76402975 | 172.053684921 | 588.5
# (D) 30 mm/h - Fresh  486.248194322 | 325.199816872 | 48.4
# (D) 30 mm/h - Aged  126.046929706 | 177.528719311 | 51.8

# %% [markdown]
# #### Test factor X (Living)

# %%
x = 2

# %%
pest_living_1st = pest_linear_x(
    Kd_pest_living,
    x,
    initial_condition,
    pest_dict_L_1st,          
    pb_i1, pb_f1,
    percol_data1, percol_data1,
    time_sizes1,
    area, soil_height1, 
    d, runoff_vel,
    soil,
    KFILM = True,
    isFirstCycle = True,
    isLiving = True)


output_pesti_params = extract_goodness_pest(
        pest_living_1st,
        output_pesti_params,
        soil_short,
        isLiving = True,
        isFirstCycle = True)
# Out:
# 1st Pulse
# Living Vine
# --------------------------------------------
# Koc tested:  [  7.40805821e+01   1.86082009e+02   2.34263370e+02   4.67416873e+02
#    9.32619273e+02   2.94920109e+03   2.94920109e+04   2.94920109e+07]
# Best Kd (Fresh):  15.8489319246 cm3/g ( Num:  5 )
#  x factor:  2
#  R2:  -0.20475711135
#  Effective Koc (fresh) - [cm3/g]: 466.309636478
# --------------------------------------------
# Best Kd (Aged):  15.8489319246 cm3/g ( Num:  5 )
#  x factor: No factor considered.
#  R2:  0.835273128333
#  Effective Koc (aged) [cm3/g]: 932.619272956
# --------------------------------------------
# --------------------------------------------
# Scenario - modality - Predicted error prcnt (%) | Predicted | Observed |
# --------------------------------------------
# (A) 135 mm/h - Fresh  242.053557417 | 4.78874980383 | 1.4
# (A) 135 mm/h - Aged  97.875489113 | 1.18725293468 | 0.6
# (B) 55 mm/h - Fresh  566.288731257 | 6.66288731257 | 1.0
# (B) 55 mm/h - Aged  315.959821139 | 1.66383928456 | 0.4
# (C) 55 mm/h - Fresh  5.49401065755 | 49.898667041 | 47.3
# (C) 55 mm/h - Aged  -51.4962721224 | 16.1517413832 | 33.3
# (D) 30 mm/h - Fresh  781.837691475 | 65.9891722912 | 2.7
# (D) 30 mm/h - Aged  702.941976566 | 28.1914117959 | 0.8

# %% [markdown]
# #### Time series

# %%
data_stack = pest_sterile_1st['Data_stack']
sterile1 = extract_pest(data_stack)

mass_percol_sterile1 = sterile1[0]
mass_pond_sterile1 = sterile1[1]

# %%
data_stack = pest_living_1st['Data_stack']
living1 = extract_pest(data_stack)

mass_percol_living1 = living1[0]
mass_pond_living1 = living1[1]

# %% [markdown]
# ## Plotting transport

# %% [markdown]
# ### Sterile (1st Pulse, Crop Soil)

# %%
pestiplot_condition(
    mass_percol_sterile1,
    pest_dict_S_1st,
    pesticide,
    soil_type,
    cycle = '1st pulse',
    LEACH = True,
    STERILE = True
)

# %% [markdown]
# ### Living (1st Pulse, Crop Soil)

# %%
pestiplot_condition(
    mass_percol_living1,
    pest_dict_L_1st,
    pesticide,
    soil_type,
    cycle = '1st pulse',
    LEACH = True,
    STERILE = False
)

# %% [markdown]
# # Hydrology - 2nd pulse

# %% [markdown]
# ### Inverse Ksat determination
#
# Based on hisotric rainfall pattern, fresh and aged.

# %%
water2_ktest = leachsim3(
    soil,
    kSat = [ kSat/5, kSat/10, kSat/15,
        kSat/25, kSat/50,  kSat/75, 
        kSat/100, kSat/125, kSat/150, 
        kSat/175, kSat/200, kSat/250,
        kSat/350, kSat/500, kSat/700, kSat/1000],
    soil_height=soil_height2,
    isFirstCycle = False
)

output_hydro_params = extract_goodness(
    water2_ktest,
    output_hydro_params,
    soil_short,
    isFirstCycle = False,
    isAGED = None
)
# Out:
# R2:  0.984388324547
# --------------------------------------------
# Sterile, Fresh Soil
# ksat high:  0.35240000000000005 cm/h | Error % -12.5148211298
# ksat med12:  0.01762 cm/h | Error % 128.69226691
# ksat med30:  0.01762 cm/h | Error % 363.760286176
# ksat low:  0.07048 cm/h | Error % 4.76959385113
# --------------------------------------------
# Sterile, Aged Soil
# ksat high:  0.14096 cm/h | Error % -0.626720468252
# ksat med12:  0.35240000000000005 cm/h | Error % -0.702170472638
# ksat med30:  1.1746666666666667 cm/h | Error % -5.73433335983
# ksat low:  0.7048000000000001 cm/h | Error % 9.70860633442
# --------------------------------------------
# Living, Fresh Soil
# ksat high:  0.01762 cm/h | Error % inf
# ksat med12:  0.03524 cm/h | Error % 3.53388184937
# ksat med30:  0.17620000000000002 cm/h | Error % 2.28902480468
# ksat low:  0.35240000000000005 cm/h | Error % -9.70964935858
# --------------------------------------------
# Living, Fresh Aged
# ksat high:  0.11746666666666668 cm/h | Error % 2.32506552889
# ksat med12:  0.23493333333333336 cm/h | Error % 1.77596424015
# ksat med30:  0.35240000000000005 cm/h | Error % -6.81514797032
# ksat low:  0.025171428571428574 cm/h | Error % -4.08530151711
# --------------------------------------------

# %% [markdown]
# ### Percolation - 2nd pulse

# %%
title = "Percolated Volume [mL] - " + str(soil_type) +  " 2nd Pulse"

# %%
extract_and_plothydro(
    water2_ktest,
    "Leached, 135mm/h", "Leached, 55mm/h - A", "Leached, 55mm/h - B", "Leached, 30mm/h",
    title,
    soil,
    isFirstCycle = False,
    isPercolation = True
)

# %% [markdown]
# ### Ponding - 2nd pulse

# %%
title = "Ponded Volume [mL] [mL] - " + str(soil_type) +  " 2nd Pulse"

# %%
extract_and_plothydro(
    water2_ktest,
    "Ponded, 135mm/h", "Ponded, 55mm/h - A", "Ponded, 55mm/h - B", "Ponded, 30mm/h",
    title,
    soil,
    isFirstCycle = False,
    isPercolation = False
)

# %%
hydro2 = extract(
    water2_ktest,
    isFirstCycle = False
)
percol_data2 = hydro2[0]
runoff_data2 = hydro2[1]
time_sizes2 = hydro2[2]

# %% [markdown]
# ## Transport - 2nd pulse

# %% [markdown]
# ### Computation transport - 2nd Pulse

# %% [markdown]
# #### Kd optimal (sterile)

# %%
x = 2

# %%
pest_sterile_2nd = pest_linear_x(
    Kd_pest_sterile,
    x,
    initial_condition,
    pest_dict_S_2nd,
    pb_i2, pb_f2,
    percol_data2, runoff_data2,
    time_sizes2,
    area, soil_height2,
    d, runoff_vel,
    soil = "Alteck",
    isFirstCycle = False,
    isLiving = False)

output_pesti_params = extract_goodness_pest(
        pest_sterile_2nd,
        output_pesti_params,
        soil_short,
        isLiving = False,
        isFirstCycle = False)
# Out:
# 2nd Pulse
# Sterile Crop
# --------------------------------------------
# Koc tested:  [  5.60868490e+01   1.40883795e+02   1.77362190e+02   3.53884093e+02
#    7.06091594e+02   2.23285767e+03   2.23285767e+04   2.23285767e+07]
# Best Kd (Fresh):  15.8489319246 cm3/g ( Num:  5 )
#  x factor:  2
#  R2:  0.984896310566
#  Effective Koc (fresh) - [cm3/g]: 353.045797127
# --------------------------------------------
# Best Kd (Aged):  3.16227766017 cm3/g ( Num:  2 )
#  x factor: No factor considered.
#  R2:  0.306452090422
#  Effective Koc (aged) [cm3/g]: 140.883794893
# --------------------------------------------
# --------------------------------------------
# Scenario - modality - Predicted error prcnt (%) | Predicted | Observed |
# --------------------------------------------
# (A) 135 mm/h - Fresh  -51.7854126027 | 7.90719233315 | 16.4
# (A) 135 mm/h - Aged  141.79613718 | 31.1917016963 | 12.9
# (B) 55 mm/h - Fresh  No obs | 2.1806501099 | nan
# (B) 55 mm/h - Aged  279.276548601 | 92.5434778587 | 24.4
# (C) 55 mm/h - Fresh  No obs | 8.87327887719 | nan
# (C) 55 mm/h - Aged  -61.2469093872 | 170.625417966 | 412.4
# (D) 30 mm/h - Fresh  114.637214716 | 48.5677999004 | 11.5
# (D) 30 mm/h - Aged  387.749770073 | 150.874871284 | 35.8

# %% [markdown]
# #### Kd optimal (living)

# %%
x = 2

# %%
pest_living_2nd = pest_linear_x(
    Kd_pest_living,
    x,
    initial_condition,
    pest_dict_L_2nd,          
    pb_i1, pb_f1,
    percol_data2, runoff_data2,
    time_sizes1,
    area, soil_height1, 
    d, runoff_vel,
    soil = "Alteck",
    KFILM = True,
    isFirstCycle = False,
    isLiving = True)

output_pesti_params = extract_goodness_pest(
        pest_living_2nd,
        output_pesti_params,
        soil_short,
        isLiving = True,
        isFirstCycle = False)
# Out:
# 2nd Pulse
# Living Crop
# --------------------------------------------
# Koc tested:  [  3.93931226e+01   9.89510501e+01   1.24571992e+02   2.48553800e+02
#    4.95930031e+02   1.56826846e+03   1.56826846e+04   1.56826846e+07]
# Best Kd (Fresh):  501.187233627 cm3/g ( Num:  7 )
#  x factor:  2
#  R2:  -0.801590294748
#  Effective Koc (fresh) - [cm3/g]: 7841.34228718
# --------------------------------------------
# Best Kd (Aged):  50.1187233627 cm3/g ( Num:  6 )
#  x factor: No factor considered.
#  R2:  0.984256611065
#  Effective Koc (aged) [cm3/g]: 1568.26845744
# --------------------------------------------
# --------------------------------------------
# Scenario - modality - Predicted error prcnt (%) | Predicted | Observed |
# --------------------------------------------
# (A) 135 mm/h - Fresh  No obs | 0.000571580787278 | nan
# (A) 135 mm/h - Aged  -54.2867379961 | 0.137139786012 | 0.3
# (B) 55 mm/h - Fresh  No obs | 0.00510968389941 | nan
# (B) 55 mm/h - Aged  No obs | 0.47302741014 | nan
# (C) 55 mm/h - Fresh  -96.5121668716 | 0.0662688294394 | 1.9
# (C) 55 mm/h - Aged  No obs | 1.73429528305 | nan
# (D) 30 mm/h - Fresh  -95.5176332138 | 0.0133072025366 | 1.7
# (D) 30 mm/h - Aged  53.9721158783 | 1.27354691058 | 0.3

# %% [markdown]
# #### Time series

# %%
data_stack = pest_sterile_2nd['Data_stack']
sterile2 = extract_pest(data_stack)

data_stack = pest_living_2nd['Data_stack']
living2 = extract_pest(data_stack)

mass_percol_sterile2 = sterile2[0]
mass_pond_sterile2 = sterile2[1]

mass_percol_living2 = living2[0]
mass_pond_living2 = living2[1]

# %% [markdown]
# ## Plotting transport

# %% [markdown]
# ### Sterile (2nd Pulse)

# %%
pestiplot_condition(
    mass_percol_sterile2,
    pest_dict_S_2nd,
    pesticide,
    soil_type,
    cycle = '2nd pulse',
    LEACH = True,
    STERILE = True
)

# %%
pestiplot_condition(
    mass_pond_sterile2,
    pest_dict_S_2nd,
    pesticide,
    soil_type,
    cycle = '2nd pulse',
    LEACH = False,
    STERILE = True
)

# %% [markdown]
# ### Living (2nd Pulse)

# %%
pestiplot_condition(
    mass_percol_living2,
    pest_dict_L_2nd,
    pesticide,
    soil_type,
    cycle = '2nd pulse',
    LEACH = True,
    STERILE = False
)

# %%
pestiplot_condition(
    mass_pond_living2,
    pest_dict_L_2nd,
    pesticide,
    soil_type,
    cycle = '2nd pulse',
    LEACH = False,
    STERILE = False
)

# %% [markdown]
# END NOTEBOOK

# %% [markdown]
# ### Max values

# %%
initial_condition = 'max'

# %% [markdown]
# #### 1st Pulse

# %%
Kd1_SF = output_pesti_params[soil_short]['Kd1']['SF']*10**3  # Convert back to mm3/g (model units)
Kd1_SA = output_pesti_params[soil_short]['Kd1']['SA']*10**3
Kd1_choice_sterile = [Kd1_SF, Kd1_SA]

Kd1_LF = output_pesti_params[soil_short]['Kd1']['LF']*10**3
Kd1_LA = output_pesti_params[soil_short]['Kd1']['LA']*10**3
Kd1_choice_living = [Kd1_LF, Kd1_LA]

# %%
max_sterile_1st = pest_Kd_choice(
    Kd1_choice_sterile,
    x,
    initial_condition,
    pest_dict_S_1st,          
    pb_i1, pb_f1,
    percol_data1, runoff_data1,
    time_sizes1,
    area, soil_height1, 
    d, runoff_vel,
    soil,
    isFirstCycle = True,
    isLiving = False,
    KFILM = True)

output_pesti_params = extract_goodness_maxmin(
        max_sterile_1st,
        initial_condition,
        output_pesti_params,
        soil_short,
        isLiving = False,
        isFirstCycle = True)
# Out:
# 1st Pulse
# Sterile Vine
# --------------------------------------------
# Koc tested:  [ 154.45333888  154.45333888]
# Best Kd (Fresh):  3.16227766017 cm3/g ( Num:  1 )
#  x factor:  2
#  R2:  -0.909103189833
#  Effective Koc (fresh) - [cm3/g]: 77.2266694385
# --------------------------------------------
# Best Kd (Aged):  3.16227766017 cm3/g ( Num:  2 )
#  x factor: No factor considered.
#  R2:  0.566530741105
#  Effective Koc (aged) [cm3/g]: 154.453338877
# --------------------------------------------
# --------------------------------------------
# Scenario - modality - Predicted error prcnt (%) | Predicted | Observed |
# --------------------------------------------
# (A) 135 mm/h - Fresh  406.38514262 | 118.494123373 | 23.4
# (A) 135 mm/h - Aged  -24.259596239 | 29.160055448 | 38.5
# (B) 55 mm/h - Fresh  349.049269124 | 127.080943162 | 28.3
# (B) 55 mm/h - Aged  35.6210288675 | 40.2794455736 | 29.7
# (C) 55 mm/h - Fresh  -44.1924039925 | 341.040219202 | 611.1
# (C) 55 mm/h - Aged  -69.3052945813 | 180.638341389 | 588.5
# (D) 30 mm/h - Fresh  515.601416004 | 337.173551485 | 48.4
# (D) 30 mm/h - Aged  137.325591003 | 186.386553824 | 51.8

# %%
max_living_1st = pest_Kd_choice(
    Kd1_choice_living,
    x,
    initial_condition,
    pest_dict_L_1st,          
    pb_i1, pb_f1,
    percol_data1, runoff_data1,
    time_sizes1,
    area, soil_height1, 
    d, runoff_vel,
    soil,
    isFirstCycle = True,
    isLiving = False,
    KFILM = True)

output_pesti_params = extract_goodness_maxmin(
        max_living_1st,
        initial_condition,
        output_pesti_params,
        soil_short,
        isLiving = True,
        isFirstCycle = True)
# Out:
# 1st Pulse
# Sterile Vine
# --------------------------------------------
# Koc tested:  [ 774.10041636  774.10041636]
# Best Kd (Fresh):  15.8489319246 cm3/g ( Num:  1 )
#  x factor:  2
#  R2:  -0.821892062856
#  Effective Koc (fresh) - [cm3/g]: 387.050208181
# --------------------------------------------
# Best Kd (Aged):  15.8489319246 cm3/g ( Num:  2 )
#  x factor: No factor considered.
#  R2:  0.869902191477
#  Effective Koc (aged) [cm3/g]: 774.100416363
# --------------------------------------------
# --------------------------------------------
# Scenario - modality - Predicted error prcnt (%) | Predicted | Observed |
# --------------------------------------------
# (A) 135 mm/h - Fresh  387.499482865 | 6.8249927601 | 1.4
# (A) 135 mm/h - Aged  109.643643007 | 1.25786185804 | 0.6
# (B) 55 mm/h - Fresh  615.427157618 | 7.15427157618 | 1.0
# (B) 55 mm/h - Aged  346.652747744 | 1.78661099098 | 0.4
# (C) 55 mm/h - Fresh  20.8905127197 | 57.1812125164 | 47.3
# (C) 55 mm/h - Aged  -43.9900807764 | 18.6513031014 | 33.3
# (D) 30 mm/h - Fresh  895.815383762 | 74.367889522 | 2.7
# (D) 30 mm/h - Aged  808.304038488 | 32.3756322628 | 0.8

# %% [markdown]
# #### 2ndPulse Pulse

# %%
Kd2_SF = output_pesti_params[soil_short]['Kd2']['SF']*10**3
Kd2_SA = output_pesti_params[soil_short]['Kd2']['SA']*10**3
Kd2_choice_sterile = [Kd2_SF, Kd2_SA]

Kd2_LF = output_pesti_params[soil_short]['Kd2']['LF']*10**3
Kd2_LA = output_pesti_params[soil_short]['Kd2']['LA']*10**3
Kd2_choice_living = [Kd2_LF, Kd2_LA]

# %%
max_sterile_2nd = pest_Kd_choice(
    Kd2_choice_sterile,
    x,
    initial_condition,
    pest_dict_S_2nd,          
    pb_i2, pb_f2,
    percol_data2, runoff_data2,
    time_sizes2,
    area, soil_height2, 
    d, runoff_vel,
    soil,
    isFirstCycle = False,
    isLiving = False)

output_pesti_params = extract_goodness_maxmin(
        max_sterile_2nd,
        initial_condition,
        output_pesti_params,
        soil_short,
        isLiving = False,
        isFirstCycle = False)
# Out:
# 2nd Pulse
# Sterile Vine
# --------------------------------------------
# Koc tested:  [ 774.10041636  154.45333888]
# Best Kd (Fresh):  15.8489319246 cm3/g ( Num:  1 )
#  x factor:  2
#  R2:  0.986869808967
#  Effective Koc (fresh) - [cm3/g]: 387.050208181
# --------------------------------------------
# Best Kd (Aged):  3.16227766017 cm3/g ( Num:  2 )
#  x factor: No factor considered.
#  R2:  0.306796103286
#  Effective Koc (aged) [cm3/g]: 154.453338877
# --------------------------------------------
# --------------------------------------------
# Scenario - modality - Predicted error prcnt (%) | Predicted | Observed |
# --------------------------------------------
# (A) 135 mm/h - Fresh  -52.2667503305 | 7.8282529458 | 16.4
# (A) 135 mm/h - Aged  130.832234471 | 29.7773582467 | 12.9
# (B) 55 mm/h - Fresh  No obs | 2.06451144067 | nan
# (B) 55 mm/h - Aged  261.397497714 | 88.1809894421 | 24.4
# (C) 55 mm/h - Fresh  No obs | 8.48904860965 | nan
# (C) 55 mm/h - Aged  -62.5675778267 | 161.623277815 | 412.4
# (D) 30 mm/h - Fresh  103.005203973 | 45.9977197841 | 11.5
# (D) 30 mm/h - Aged  364.950524755 | 142.701601405 | 35.8

# %%
max_living_2nd = pest_Kd_choice(
    Kd2_choice_living,
    x,
    initial_condition,
    pest_dict_L_2nd,          
    pb_i2, pb_f2,
    percol_data2, runoff_data2,
    time_sizes2,
    area, soil_height2, 
    d, runoff_vel,
    soil,
    isFirstCycle = False,
    isLiving = True)

output_pesti_params = extract_goodness_maxmin(
        max_living_2nd,
        initial_condition,
        output_pesti_params,
        soil_short,
        isLiving = True,
        isFirstCycle = False)
# Out:
# 2nd Pulse
# Living Vine
# --------------------------------------------
# Koc tested:  [ 29492.01092311   2949.20109231]
# Best Kd (Fresh):  501.187233627 cm3/g ( Num:  1 )
#  x factor:  2
#  R2:  -0.816663329611
#  Effective Koc (fresh) - [cm3/g]: 14746.0054616
# --------------------------------------------
# Best Kd (Aged):  50.1187233627 cm3/g ( Num:  2 )
#  x factor: No factor considered.
#  R2:  0.986756726846
#  Effective Koc (aged) [cm3/g]: 2949.20109231
# --------------------------------------------
# --------------------------------------------
# Scenario - modality - Predicted error prcnt (%) | Predicted | Observed |
# --------------------------------------------
# (A) 135 mm/h - Fresh  No obs | 0.000541689998065 | nan
# (A) 135 mm/h - Aged  -58.5833163422 | 0.124250050974 | 0.3
# (B) 55 mm/h - Fresh  No obs | 0.00462485197262 | nan
# (B) 55 mm/h - Aged  No obs | 0.426982348586 | nan
# (C) 55 mm/h - Fresh  -96.8750636505 | 0.0593737906398 | 1.9
# (C) 55 mm/h - Aged  No obs | 1.55904958073 | nan
# (D) 30 mm/h - Fresh  -95.9668347596 | 0.012072348619 | 1.7
# (D) 30 mm/h - Aged  38.6967131595 | 1.14629008955 | 0.3

# %% [markdown]
# ### Min values

# %%
initial_condition = 'min'

# %% [markdown]
# #### 1st Pulse

# %%
min_sterile_1st = pest_Kd_choice(
    Kd1_choice_sterile,
    x,
    initial_condition,
    pest_dict_S_1st,          
    pb_i1, pb_f1,
    percol_data1, runoff_data1,
    time_sizes1,
    area, soil_height1, 
    d, runoff_vel,
    soil,
    isFirstCycle = True,
    isLiving = False,
    KFILM = True)

output_pesti_params = extract_goodness_maxmin(
        min_sterile_1st,
        initial_condition,
        output_pesti_params,
        soil_short,
        isLiving = False,
        isFirstCycle = True)
# Out:
# 1st Pulse
# Sterile Vine
# --------------------------------------------
# Koc tested:  [ 154.45333888  154.45333888]
# Best Kd (Fresh):  3.16227766017 cm3/g ( Num:  1 )
#  x factor:  2
#  R2:  -0.92126586082
#  Effective Koc (fresh) - [cm3/g]: 77.2266694385
# --------------------------------------------
# Best Kd (Aged):  3.16227766017 cm3/g ( Num:  2 )
#  x factor: No factor considered.
#  R2:  0.534281530341
#  Effective Koc (aged) [cm3/g]: 154.453338877
# --------------------------------------------
# --------------------------------------------
# Scenario - modality - Predicted error prcnt (%) | Predicted | Observed |
# --------------------------------------------
# (A) 135 mm/h - Fresh  358.094040743 | 107.194005534 | 23.4
# (A) 135 mm/h - Aged  -31.458570078 | 26.38845052 | 38.5
# (B) 55 mm/h - Fresh  306.225966902 | 114.961948633 | 28.3
# (B) 55 mm/h - Aged  22.7305214188 | 36.4509648614 | 29.7
# (C) 55 mm/h - Fresh  -49.5144604224 | 308.517132359 | 611.1
# (C) 55 mm/h - Aged  -72.2227649186 | 163.469028454 | 588.5
# (D) 30 mm/h - Fresh  456.89497264 | 305.019206987 | 48.4
# (D) 30 mm/h - Aged  114.768268409 | 168.670884798 | 51.8

# %%
min_living_1st = pest_Kd_choice(
    Kd1_choice_living,
    x,
    initial_condition,
    pest_dict_L_1st,          
    pb_i1, pb_f1,
    percol_data1, runoff_data1,
    time_sizes1,
    area, soil_height1, 
    d, runoff_vel,
    soil,
    isFirstCycle = True,
    isLiving = False,
    KFILM = True)

output_pesti_params = extract_goodness_maxmin(
        min_living_1st,
        initial_condition,
        output_pesti_params,
        soil_short,
        isLiving = True,
        isFirstCycle = True)
# Out:
# 1st Pulse
# Sterile Vine
# --------------------------------------------
# Koc tested:  [ 774.10041636  774.10041636]
# Best Kd (Fresh):  15.8489319246 cm3/g ( Num:  1 )
#  x factor:  2
#  R2:  -0.311246895369
#  Effective Koc (fresh) - [cm3/g]: 387.050208181
# --------------------------------------------
# Best Kd (Aged):  15.8489319246 cm3/g ( Num:  2 )
#  x factor: No factor considered.
#  R2:  0.846702186506
#  Effective Koc (aged) [cm3/g]: 774.100416363
# --------------------------------------------
# --------------------------------------------
# Scenario - modality - Predicted error prcnt (%) | Predicted | Observed |
# --------------------------------------------
# (A) 135 mm/h - Fresh  340.971754443 | 6.1736045622 | 1.4
# (A) 135 mm/h - Aged  89.6761037859 | 1.13805662272 | 0.6
# (B) 55 mm/h - Fresh  547.145648272 | 6.47145648272 | 1.0
# (B) 55 mm/h - Aged  304.111241926 | 1.61644496771 | 0.4
# (C) 55 mm/h - Fresh  9.35252931198 | 51.7237463646 | 47.3
# (C) 55 mm/h - Aged  -49.3247536662 | 16.8748570292 | 33.3
# (D) 30 mm/h - Fresh  800.773174771 | 67.2700994964 | 2.7
# (D) 30 mm/h - Aged  721.792488446 | 29.2920104666 | 0.8

# %% [markdown]
# #### 2nd Pulse

# %%
min_sterile_2nd = pest_Kd_choice(
    Kd2_choice_sterile,
    x,
    initial_condition,
    pest_dict_S_2nd,          
    pb_i2, pb_f2,
    percol_data2, runoff_data2,
    time_sizes2,
    area, soil_height2, 
    d, runoff_vel,
    soil,
    isFirstCycle = False,
    isLiving = False)

output_pesti_params = extract_goodness_maxmin(
        min_sterile_2nd,
        initial_condition,
        output_pesti_params,
        soil_short,
        isLiving = False,
        isFirstCycle = False)
# Out:
# 2nd Pulse
# Sterile Vine
# --------------------------------------------
# Koc tested:  [ 774.10041636  154.45333888]
# Best Kd (Fresh):  15.8489319246 cm3/g ( Num:  1 )
#  x factor:  2
#  R2:  0.989221142196
#  Effective Koc (fresh) - [cm3/g]: 387.050208181
# --------------------------------------------
# Best Kd (Aged):  3.16227766017 cm3/g ( Num:  2 )
#  x factor: No factor considered.
#  R2:  0.264779936684
#  Effective Koc (aged) [cm3/g]: 154.453338877
# --------------------------------------------
# --------------------------------------------
# Scenario - modality - Predicted error prcnt (%) | Predicted | Observed |
# --------------------------------------------
# (A) 135 mm/h - Fresh  -56.8693152429 | 7.07343230017 | 16.4
# (A) 135 mm/h - Aged  108.478816909 | 26.8937673812 | 12.9
# (B) 55 mm/h - Fresh  No obs | 1.86519026935 | nan
# (B) 55 mm/h - Aged  226.474018613 | 79.6596605416 | 24.4
# (C) 55 mm/h - Fresh  No obs | 7.38621175013 | nan
# (C) 55 mm/h - Aged  -67.2852178167 | 146.004887537 | 412.4
# (D) 30 mm/h - Fresh  81.8142457758 | 41.5624992074 | 11.5
# (D) 30 mm/h - Aged  319.568778181 | 128.882610785 | 35.8

# %%
min_living_2nd = pest_Kd_choice(
    Kd2_choice_living,
    x,
    initial_condition,
    pest_dict_L_2nd,          
    pb_i2, pb_f2,
    percol_data2, runoff_data2,
    time_sizes2,
    area, soil_height2, 
    d, runoff_vel,
    soil,
    isFirstCycle = False,
    isLiving = True)

output_pesti_params = extract_goodness_maxmin(
        min_living_2nd,
        initial_condition,
        output_pesti_params,
        soil_short,
        isLiving = True,
        isFirstCycle = False)
# Out:
# 2nd Pulse
# Living Vine
# --------------------------------------------
# Koc tested:  [ 29492.01092311   2949.20109231]
# Best Kd (Fresh):  501.187233627 cm3/g ( Num:  1 )
#  x factor:  2
#  R2:  -0.82949802923
#  Effective Koc (fresh) - [cm3/g]: 14746.0054616
# --------------------------------------------
# Best Kd (Aged):  50.1187233627 cm3/g ( Num:  2 )
#  x factor: No factor considered.
#  R2:  0.98775124011
#  Effective Koc (aged) [cm3/g]: 2949.20109231
# --------------------------------------------
# --------------------------------------------
# Scenario - modality - Predicted error prcnt (%) | Predicted | Observed |
# --------------------------------------------
# (A) 135 mm/h - Fresh  No obs | 0.000489973050546 | nan
# (A) 135 mm/h - Aged  -62.5286384941 | 0.112414084518 | 0.3
# (B) 55 mm/h - Fresh  No obs | 0.0041833439002 | nan
# (B) 55 mm/h - Aged  No obs | 0.38631033848 | nan
# (C) 55 mm/h - Fresh  -97.1795623204 | 0.0535883159122 | 1.9
# (C) 55 mm/h - Aged  No obs | 1.41054301948 | nan
# (D) 30 mm/h - Fresh  -96.3520133942 | 0.0109197613049 | 1.7
# (D) 30 mm/h - Aged  25.4839163779 | 1.0370953573 | 0.3

# %% [markdown]
# ### Hydrology summary

# %%
import pprint

# %% [markdown]
# ### R-squared

# %%
# 1st pulse
output_hydro_params[soil_short][0]['R1_FA']
# Out:
# [0.97167044953232651, 0.98950154118247413]

# %%
# 2nd pulse 
output_hydro_params[soil_short][0]['R2_ALL']
# Out:
# [0.98438832454669278]

# %% [markdown]
# ### Percent error

# %%
# 1st pulse
pprint.pprint(output_hydro_params[soil_short][0]['Err1'][0])
# Out:
# {'Aged': [-9.9497695760673803,
#           -3.8366274590119529,
#           -0.19171628147268441,
#           -10.681750947175953],
#  'Fresh': [-1.6576800420983793,
#            55.714529041314499,
#            4.5496322475756381,
#            1.1782456331323563]}

# %%
# 2nd pulse
pprint.pprint(output_hydro_params[soil_short][0]['Err2'][0])
# Out:
# {'LA': [2.3250655288884485,
#         1.775964240154662,
#         -6.8151479703231335,
#         -4.0853015171098992],
#  'LF': [inf, 3.5338818493703803, 2.2890248046824371, -9.7096493585817267],
#  'SA': [-0.62672046825181538,
#         -0.70217047263768517,
#         -5.7343333598281507,
#         9.7086063344151547],
#  'SF': [-12.514821129777932,
#         128.69226690973363,
#         363.76028617624922,
#         4.7695938511324218]}

# %% [markdown]
# ## Transport

# %% [markdown]
# ### Summary tables
#
# 0. High rainfall intensity (135 mm/h) at 6 min.
# 1. Medium rainfall intensity (55 mm/h) at 12 min.
# 2. Medium rainfall intensity (55 mm/h) at 30 min.
# 3. Low rainfall intensity (30 mm/h) at 30 min.
#
#     a) LA : Living Aged
#
#     b) LF : Living Fresh
#
#     c) SA : Sterile Aged
#
#     d) SF : Sterile Fresh
#
#
# To compute max and min simualtions, the optimal Kd values obtained from the mean scenario were used. That is, the model has not been fitted to consider these extreme uncertainty scenarios.
#
# - max: initial calculated concentration + measurement error
#
# - min: initial calculated concentraion - measurement error

# %%
import pandas as pd

# %% [markdown]
# ### Percent error

# %%
pd.DataFrame.from_dict(output_pesti_params[soil_short]['Err1'], orient='columns')
# Out:
#            LA       LAmax       LAmin          LF       LFmax       LFmin  \
# 0   97.875489  109.643643   89.676104  242.053557  387.499483  340.971754
# 1  315.959821  346.652748  304.111242  566.288731  615.427158  547.145648
# 2  -51.496272  -43.990081  -49.324754    5.494011   20.890513    9.352529
# 3  702.941977  808.304038  721.792488  781.837691  895.815384  800.773175
#
#            SA       SAmax       SAmin          SF       SFmax       SFmin
# 0  -27.859083  -24.259596  -31.458570  285.850443  406.385143  358.094041
# 1   29.175775   35.621029   22.730521  327.637618  349.049269  306.225967
# 2  -70.764030  -69.305295  -72.222765  -46.853432  -44.192404  -49.514460
# 3  126.046930  137.325591  114.768268  486.248194  515.601416  456.894973

# %%
pd.DataFrame.from_dict(output_pesti_params[soil_short]['Err2'], orient='columns')
# Out:
#         LA    LAmax    LAmin       LF    LFmax    LFmin          SA  \
# 0 -54.2867 -58.5833 -62.5286   No obs   No obs   No obs  141.796137
# 1   No obs   No obs   No obs   No obs   No obs   No obs  279.276549
# 2   No obs   No obs   No obs -96.5122 -96.8751 -97.1796  -61.246909
# 3  53.9721  38.6967  25.4839 -95.5176 -95.9668  -96.352  387.749770
#
#         SAmax       SAmin       SF    SFmax    SFmin
# 0  130.832234  108.478817 -51.7854 -52.2668 -56.8693
# 1  261.397498  226.474019   No obs   No obs   No obs
# 2  -62.567578  -67.285218   No obs   No obs   No obs
# 3  364.950525  319.568778  114.637  103.005  81.8142

# %% [markdown]
# ### R-squared & Sorption parameters

# %%
# 1st and 2nd Pulse
df = pd.DataFrame.from_dict(output_pesti_params[soil_short], orient='columns') 
df2 = df[['R1', 'R2', 'Kd1', 'Kd2', 'Koc1', 'Koc2']].dropna(axis=0)
df2
# Out:
#           R1        R2        Kd1         Kd2        Koc1         Koc2
# LA  0.835273  0.984257  15.848932   50.118723  932.619273  1568.268457
# LF -0.204757 -0.801590  15.848932  501.187234  466.309636  7841.342287
# SA  0.550693  0.306452   3.162278    3.162278  154.453339   140.883795
# SF -0.864844  0.984896   3.162278   15.848932   77.226669   353.045797

# %%
path = '..\ModelParameters\\' + str(soil_short) + str(pesticide) + '.csv'
df2.to_csv(path, sep=';')
