# %% [markdown]
# START NOTEBOOK

# %% [markdown]
# ## Set-up

# %%
from hydroplots import *
from leach_hydrology import *
import numpy as np

import mpld3
mpld3.enable_notebook()

# Plot graphs within this document
# %matplotlib inline

# Plot graphs outside (for interaction)
# %matplotlib

from pestmob import *
from mixinglayer import *

# %% [markdown]
# ### Pesticide, soil type and runoff calibration parameter.

# %%
# Soil and pesticide
pesticide = 'Zinc'
soil_type = 'Vine Soil'
soil = 'Rouff'
soil_short = 'Vine'

pesti_obs = choose_pesticide(
    pesticide,
    soil)

# Kd ranges to test
Kd_pest_sterile = pesti_obs[0]
Kd_pest_living = pesti_obs[1]

# Initial concentrations and mass out observed
pest_dict_S_1st = pesti_obs[2]
pest_dict_L_1st = pesti_obs[3]
pest_dict_S_2nd = pesti_obs[4]
pest_dict_L_2nd = pesti_obs[5]

# Assumed (used to calculate Reynolds number)
runoff_vel = 10.0  # mm/min

# %% [markdown]
# ### Microcosm

# %%
d = (14.93 * 2)  # Diameter of falcon tube (mm)
area = ((d / 2) ** 2) * 3.1416  # (mm2)
soil_height1 = 20  # Mixing layer depth in mm
soil_height2 = 20  # mm
eff_height = 0.76

# %% [markdown]
# ### Soil hydrological characteristics

# %%
if soil == 'Alteck':
    kSat = 2.24  # mm/min (13.45 cm/h - Crop Soil) 
    psi = 1100  # soil suction Alteck (mm)
elif soil == 'Rouff': 
    kSat = 17.62*10/60  # mm/min (17.62 cm/h - Vine Soil) 
    psi = 1100  # soil suction Alteck (mm)
    
# Soil characteristics (Equivalent for Alteck and Rouffach)
# Initial bulk density options:
pb_i0 = 0.99/10**3  # bulk density (g/cm^3) -> g/mm^3  (M. Trautmann)
pb_i1 = 2.61/10**3 # inital 1st pulse, calc. from experiment cond.
pb_i2 = 3.59/10**3 # initial 2nd pulse, calc. from experiment cond.

# Final bulk density options (1st and 2nd pulses)
pb_f1 = 3.59/10**3 # final1, calculated from experimental conditions.
pb_f2 = 3.76/10**3 # final2, calculated from experimental conditions.

# %% [markdown]
# ### Store results

# %%
output_hydro_params = {
    soil_short : [{'R1_FA':[],
              'R2_ALL':[],
              'Err1':[{'Fresh':[], 'Aged':[]}],
              'Err2':[{'SF':[], 'SA':[], 'LF':[], 'LA':[]}],
              'Ksat2':[{'SF':[], 'SA':[], 'LF':[], 'LA':[]}]
             }]
    }

# %%
output_pesti_params = {
    soil_short: {'R1': {'SF': None, 'SA': None, 'LF': None, 'LA': None},
                 'R2': {'SF': None, 'SA': None, 'LF': None, 'LA': None},
                 'Err1': {'SF': [], 'SA': [], 'LF': [], 'LA': []},
                 'Err2': {'SF': [], 'SA': [], 'LF': [], 'LA': []},
                 'Koc1': {'SF': None, 'SA': None, 'LF': None, 'LA': None},
                 'Koc2': {'SF': None, 'SA': None, 'LF': None, 'LA': None},
                 'logKd1': {'SF': None, 'SA': None, 'LF': None, 'LA': None},
                 'logKd2': {'SF': None, 'SA': None, 'LF': None, 'LA': None}
                 }
}

# %% [markdown]
# ## Hydrology - 1st pulse

# %% [markdown]
# #### Computation

# %%
water_data = leachsim(kSat = kSat,
                      soil_height=soil_height1,
                      eff_height = eff_height,
                      soil = 'Alteck',
                      psi=psi)
# Out:
# Mass balance True
# Mass balance 0.0
# Mass balance 0.0

# %%
water_eval = leachsim2(
    kSat = [kSat],
    soil_height=soil_height1,
    eff_height = eff_height,
    soil = 'Alteck',
    isAGED = False,
    isFirstCycle=True 
)

output_hydro_params = extract_goodness(
    water_eval,
    output_hydro_params,
    soil_short,
    isFirstCycle = True,
    isAGED = False)
# Out:
# FRESH
# --------------------------------------------
# ksat high:  17.62 cm/h
# ksat med12:  17.62 cm/h
# ksat med30:  17.62 cm/h
# ksat low:  17.62 cm/h
# --------------------------------------------
# R2:  0.971670449532
# --------------------------------------------
# Simulation error percent (%), by modality
# --------------------------------------------
# 135 mm/h - 6min  -1.6576800421
# 55 mm/h - 12min  55.7145290413
# 55 mm/h - 30min  4.54963224758
# 30 mm/h - 30min  1.17824563313
# --------------------------------------------
# Mass balance:  True True True True

# %%
water_eval = leachsim2(
    kSat = [kSat],
    soil_height=soil_height1,
    eff_height = eff_height,
    soil = 'Alteck',
    isAGED = True,
    isFirstCycle=True 
)

output_hydro_params = extract_goodness(
    water_eval,
    output_hydro_params,
    soil_short,
    isFirstCycle = True,
    isAGED = True)
# Out:
# AGED
# --------------------------------------------
# ksat high:  17.62 cm/h
# ksat med12:  17.62 cm/h
# ksat med30:  17.62 cm/h
# ksat low:  17.62 cm/h
# --------------------------------------------
# R2:  0.989501541182
# --------------------------------------------
# Simulation error percent (%), by modality
# --------------------------------------------
# 135 mm/h - 6min  -9.94976957607
# 55 mm/h - 12min  -3.83662745901
# 55 mm/h - 30min  -0.191716281473
# 30 mm/h - 30min  -10.6817509472
# --------------------------------------------
# Mass balance:  True True True True

# %%
title = "Percolated Volume [mL] - " + str(soil_type) + "1st Pulse"

# %%
extract_and_plothydro(
    water_data,
    "Percolated at 135mm/h", "Percolated at 55mm/h", "Percolated at 30mm/h", "NA",
    title,
    soil,
    isFirstCycle = True,
    isPercolation = True
)

# %%
hydro1 = extract(
    water_data, 
    isFirstCycle = True
)

percol_data1 = hydro1[0]
runoff_data1 = hydro1[1]
time_sizes1 = hydro1[2]

# %% [markdown]
# ## Transport - 1st pulse

# %% [markdown]
# ### Computation transport - 1st pulse

# %% [markdown]
# #### Test factor X (Sterile)

# %%
x = 2

# %%
pest_sterile_1st = pest_linear_x(
    Kd_pest_sterile,
    x,
    pest_dict_S_1st,          
    pb_i1, pb_f1,
    percol_data1, runoff_data1,
    time_sizes1,
    area, soil_height1, 
    d, runoff_vel,
    soil,
    isFirstCycle = True,
    isLiving = False,
    KFILM = True)

output_pesti_params = extract_goodness_pest(
        pest_sterile_1st,
        output_pesti_params,
        soil_short,
        isLiving = False,
        isFirstCycle = True)
# Out:
# 1st Pulse
# --------------------------------------------
# Koc tested:  [  1.54453339e+02   3.08174926e+02   4.88424343e+02   7.74100416e+02
#    1.54453339e+03   1.54453339e+05   1.54453339e+07   3.87969246e+08]
# Best log Kd (Fresh):  1.5 cm3/g ( Num:  5 )
#  x factor:  2
#  R2:  -0.868204120372
#  Effective Koc (fresh) - [cm3/g]: 772.266694385
# --------------------------------------------
# Best log Kd (Aged):  1.5 cm3/g ( Num:  5 )
#  x factor: No factor considered.
#  R2:  0.988742661512
#  Effective Koc (aged) [cm3/g]: 1544.53338877
# --------------------------------------------
# --------------------------------------------
# Scenario - modality - Predicted error prcnt (%) | Predicted | Observed |
# --------------------------------------------
# (A) 135 mm/h - Fresh  46.0816946103 | 0.876490167662 | 0.6
# (A) 135 mm/h - Aged  -89.7041564708 | 0.2471002447 | 2.4
# (B) 55 mm/h - Fresh  55.6132114279 | 1.24490569142 | 0.8
# (B) 55 mm/h - Aged  No obs | < LD  | 0.352282215577 | nan
# (C) 55 mm/h - Fresh  -46.3336977551 | 12.9872451433 | 24.2
# (C) 55 mm/h - Aged  -0.596112940469 | 4.27436714356 | 4.3
# (D) 30 mm/h - Fresh  181.236032091 | 22.5219218836 | 1.8
# (D) 30 mm/h - Aged  No obs | < LD  | 9.45408692691 | nan

# %% [markdown]
# #### Test factor X (Living)

# %%
x = 2

# %%
pest_living_1st = pest_linear_x(
    Kd_pest_living,
    x,
    pest_dict_L_1st,          
    pb_i1, pb_f1,
    percol_data1, percol_data1,
    time_sizes1,
    area, soil_height1, 
    d, runoff_vel,
    soil,
    KFILM = True,
    isFirstCycle = True,
    isLiving = True)


output_pesti_params = extract_goodness_pest(
        pest_living_1st,
        output_pesti_params,
        soil_short,
        isLiving = True,
        isFirstCycle = True)
# Out:
# 1st Pulse
# --------------------------------------------
# Koc tested:  [  1.86082009e+02   3.71282420e+02   5.88442980e+02   9.32619273e+02
#    1.86082009e+03   1.86082009e+05   1.86082009e+07   4.67416873e+08]
# Best log Kd (Fresh):  3.5 cm3/g ( Num:  6 )
#  x factor:  2
#  R2:  0.997642722842
#  Effective Koc (fresh) - [cm3/g]: 93041.0044771
# --------------------------------------------
# Best log Kd (Aged):  1.2 cm3/g ( Num:  4 )
#  x factor: No factor considered.
#  R2:  0.931668175697
#  Effective Koc (aged) [cm3/g]: 932.619272956
# --------------------------------------------
# --------------------------------------------
# Scenario - modality - Predicted error prcnt (%) | Predicted | Observed |
# --------------------------------------------
# (A) 135 mm/h - Fresh  No obs | < LD  | 0.000102464060799 | nan
# (A) 135 mm/h - Aged  No obs | < LD  | 0.932189035039 | nan
# (B) 55 mm/h - Fresh  No obs | < LD  | 0.000144657767056 | nan
# (B) 55 mm/h - Aged  No obs | < LD  | 1.30638778969 | nan
# (C) 55 mm/h - Fresh  -99.6199620414 | 0.00190018979318 | 0.5
# (C) 55 mm/h - Aged  26.8177637172 | 12.6817763717 | 10.0
# (D) 30 mm/h - Fresh  No obs | < LD  | 0.00573536950602 | nan
# (D) 30 mm/h - Aged  No obs | < LD  | 22.1348999786 | nan

# %% [markdown]
# #### Time series

# %%
data_stack = pest_sterile_1st['Data_stack']
sterile1 = extract_pest(data_stack)

mass_percol_sterile1 = sterile1[0]
mass_pond_sterile1 = sterile1[1]

# %%
data_stack = pest_living_1st['Data_stack']
living1 = extract_pest(data_stack)

mass_percol_living1 = living1[0]
mass_pond_living1 = living1[1]

# %% [markdown]
# ## Plotting transport

# %% [markdown]
# ### Sterile (1st Pulse, Crop Soil)

# %%
pestiplot_condition(
    mass_percol_sterile1,
    pest_dict_S_1st,
    pesticide,
    soil_type,
    cycle = '1st pulse',
    LEACH = True,
    STERILE = True
)

# %% [markdown]
# ### Living (1st Pulse, Crop Soil)

# %%
pestiplot_condition(
    mass_percol_living1,
    pest_dict_L_1st,
    pesticide,
    soil_type,
    cycle = '1st pulse',
    LEACH = True,
    STERILE = False
)

# %% [markdown]
# # Hydrology - 2nd pulse

# %% [markdown]
# ### Inverse Ksat determination
#
# Based on hisotric rainfall pattern, fresh and aged.

# %%
water2_ktest = leachsim3(
    soil,
    kSat = [ kSat/5, kSat/10, kSat/15,
        kSat/25, kSat/50,  kSat/75, 
        kSat/100, kSat/125, kSat/150, 
        kSat/175, kSat/200, kSat/250,
        kSat/350, kSat/500, kSat/700, kSat/1000],
    soil_height=soil_height2,
    isFirstCycle = False
)

output_hydro_params = extract_goodness(
    water2_ktest,
    output_hydro_params,
    soil_short,
    isFirstCycle = False,
    isAGED = None
)
# Out:
# R2:  0.984388324547
# --------------------------------------------
# Sterile, Fresh Soil
# ksat high:  0.35240000000000005 cm/h | Error % -12.5148211298
# ksat med12:  0.01762 cm/h | Error % 128.69226691
# ksat med30:  0.01762 cm/h | Error % 363.760286176
# ksat low:  0.07048 cm/h | Error % 4.76959385113
# --------------------------------------------
# Sterile, Aged Soil
# ksat high:  0.14096 cm/h | Error % -0.626720468252
# ksat med12:  0.35240000000000005 cm/h | Error % -0.702170472638
# ksat med30:  1.1746666666666667 cm/h | Error % -5.73433335983
# ksat low:  0.7048000000000001 cm/h | Error % 9.70860633442
# --------------------------------------------
# Living, Fresh Soil
# ksat high:  0.01762 cm/h | Error % inf
# ksat med12:  0.03524 cm/h | Error % 3.53388184937
# ksat med30:  0.17620000000000002 cm/h | Error % 2.28902480468
# ksat low:  0.35240000000000005 cm/h | Error % -9.70964935858
# --------------------------------------------
# Living, Fresh Aged
# ksat high:  0.11746666666666668 cm/h | Error % 2.32506552889
# ksat med12:  0.23493333333333336 cm/h | Error % 1.77596424015
# ksat med30:  0.35240000000000005 cm/h | Error % -6.81514797032
# ksat low:  0.025171428571428574 cm/h | Error % -4.08530151711
# --------------------------------------------

# %% [markdown]
# ### Percolation - 2nd pulse

# %%
title = "Percolated Volume [mL] - " + str(soil_type) +  " 2nd Pulse"

# %%
extract_and_plothydro(
    water2_ktest,
    "Leached, 135mm/h", "Leached, 55mm/h - A", "Leached, 55mm/h - B", "Leached, 30mm/h",
    title,
    soil,
    isFirstCycle = False,
    isPercolation = True
)

# %% [markdown]
# ### Ponding - 2nd pulse

# %%
title = "Ponded Volume [mL] [mL] - " + str(soil_type) +  " 2nd Pulse"

# %%
extract_and_plothydro(
    water2_ktest,
    "Ponded, 135mm/h", "Ponded, 55mm/h - A", "Ponded, 55mm/h - B", "Ponded, 30mm/h",
    title,
    soil,
    isFirstCycle = False,
    isPercolation = False
)

# %%
hydro2 = extract(
    water2_ktest,
    isFirstCycle = False
)
percol_data2 = hydro2[0]
runoff_data2 = hydro2[1]
time_sizes2 = hydro2[2]

# %% [markdown]
# ## Transport - 2nd pulse

# %% [markdown]
# ### Computation transport - 2nd Pulse

# %% [markdown]
# #### Kd optimal (sterile)

# %%
x = 2

# %%
pest_sterile_2nd = pest_linear_x(
    Kd_pest_sterile,
    x,
    pest_dict_S_2nd,
    pb_i2, pb_f2,
    percol_data2, runoff_data2,
    time_sizes2,
    area, soil_height2,
    d, runoff_vel,
    soil = "Alteck",
    isFirstCycle = False,
    isLiving = False)

output_pesti_params = extract_goodness_pest(
        pest_sterile_2nd,
        output_pesti_params,
        soil_short,
        isLiving = False,
        isFirstCycle = False)
# Out:
# 2nd Pulse
# Sterile
# --------------------------------------------
# Koc tested:  [  1.40883795e+02   2.81100127e+02   4.45513677e+02   7.06091594e+02
#    1.40883795e+03   1.40883795e+05   1.40883795e+07   3.53884093e+08]
# Best log Kd (Fresh):  0.5 cm3/g ( Num:  1 )
#  x factor:  2
#  R2:  1.0
#  Effective Koc (fresh) - [cm3/g]: 70.4418974465
# --------------------------------------------
# Best log Kd (Aged):  3.5 cm3/g ( Num:  6 )
#  x factor: No factor considered.
#  R2:  0.750231448407
#  Effective Koc (aged) [cm3/g]: 140883.794893
# --------------------------------------------
# --------------------------------------------
# Scenario - modality - Predicted error prcnt (%) | Predicted | Observed |
# --------------------------------------------
# (A) 135 mm/h - Fresh  No obs | < LD  | 108.859487485 | nan
# (A) 135 mm/h - Aged  No obs | < LD  | 2.95268281649e-05 | nan
# (B) 55 mm/h - Fresh  No obs | < LD  | 33.7725759052 | nan
# (B) 55 mm/h - Aged  No obs | < LD  | 0.000106812473445 | nan
# (C) 55 mm/h - Fresh  No obs | < LD  | 128.513277144 | nan
# (C) 55 mm/h - Aged  -99.9536995999 | 0.000432086012613 | 1.6
# (D) 30 mm/h - Fresh  No obs | < LD  | 244.271355822 | nan
# (D) 30 mm/h - Aged  No obs | < LD  | 0.000290379453272 | nan

# %% [markdown]
# #### Kd optimal (living)

# %%
x = 2

# %%
pest_living_2nd = pest_linear_x(
    Kd_pest_living,
    x,
    pest_dict_L_2nd,          
    pb_i1, pb_f1,
    percol_data2, runoff_data2,
    time_sizes1,
    area, soil_height1, 
    d, runoff_vel,
    soil = "Alteck",
    KFILM = True,
    isFirstCycle = False,
    isLiving = True)

output_pesti_params = extract_goodness_pest(
        pest_living_2nd,
        output_pesti_params,
        soil_short,
        isLiving = True,
        isFirstCycle = False)
# Out:
# 2nd Pulse
# Living
# --------------------------------------------
# Koc tested:  [  9.89510501e+01   1.97433301e+02   3.12910695e+02   4.95930031e+02
#    9.89510501e+02   9.89510501e+04   9.89510501e+06   2.48553800e+08]
# Best log Kd (Fresh):  0.5 cm3/g ( Num:  1 )
#  x factor:  2
#  R2:  1
#  Effective Koc (fresh) - [cm3/g]: 49.4755250668
# --------------------------------------------
# Best log Kd (Aged):  0.5 cm3/g ( Num:  1 )
#  x factor: No factor considered.
#  R2:  1
#  Effective Koc (aged) [cm3/g]: 98.9510501336
# --------------------------------------------
# --------------------------------------------
# Scenario - modality - Predicted error prcnt (%) | Predicted | Observed |
# --------------------------------------------
# (A) 135 mm/h - Fresh  No obs | < LD  | 12.0546508416 | nan
# (A) 135 mm/h - Aged  No obs | < LD  | 21.5497219282 | nan
# (B) 55 mm/h - Fresh  No obs | < LD  | 77.9645311049 | nan
# (B) 55 mm/h - Aged  No obs | < LD  | 61.7752164541 | nan
# (C) 55 mm/h - Fresh  No obs | < LD  | 273.280936145 | nan
# (C) 55 mm/h - Aged  No obs | < LD  | 119.337109443 | nan
# (D) 30 mm/h - Fresh  No obs | < LD  | 155.822402565 | nan
# (D) 30 mm/h - Aged  No obs | < LD  | 106.784183883 | nan

# %% [markdown]
# #### Time series

# %%
data_stack = pest_sterile_2nd['Data_stack']
sterile2 = extract_pest(data_stack)

data_stack = pest_living_2nd['Data_stack']
living2 = extract_pest(data_stack)

mass_percol_sterile2 = sterile2[0]
mass_pond_sterile2 = sterile2[1]

mass_percol_living2 = living2[0]
mass_pond_living2 = living2[1]

# %% [markdown]
# ## Plotting transport

# %% [markdown]
# ### Sterile (2nd Pulse)

# %%
pestiplot_condition(
    mass_percol_sterile2,
    pest_dict_S_2nd,
    pesticide,
    soil_type,
    cycle = '2nd pulse',
    LEACH = True,
    STERILE = True
)

# %%
pestiplot_condition(
    mass_pond_sterile2,
    pest_dict_S_2nd,
    pesticide,
    soil_type,
    cycle = '2nd pulse',
    LEACH = False,
    STERILE = True
)

# %% [markdown]
# ### Living (2nd Pulse)

# %%
pestiplot_condition(
    mass_percol_living2,
    pest_dict_L_2nd,
    pesticide,
    soil_type,
    cycle = '2nd pulse',
    LEACH = True,
    STERILE = False
)

# %%
pestiplot_condition(
    mass_pond_living2,
    pest_dict_L_2nd,
    pesticide,
    soil_type,
    cycle = '2nd pulse',
    LEACH = False,
    STERILE = False
)

# %%
import pprint

# %%
pprint.pprint(output_hydro_params)
# Out:
# {'Vine': [{'Err1': [{'Aged': [-9.9497695760673803,
#                               -3.8366274590119529,
#                               -0.19171628147268441,
#                               -10.681750947175953],
#                      'Fresh': [-1.6576800420983793,
#                                55.714529041314499,
#                                4.5496322475756381,
#                                1.1782456331323563]}],
#            'Err2': [{'LA': [2.3250655288884485,
#                             1.775964240154662,
#                             -6.8151479703231335,
#                             -4.0853015171098992],
#                      'LF': [inf,
#                             3.5338818493703803,
#                             2.2890248046824371,
#                             -9.7096493585817267],
#                      'SA': [-0.62672046825181538,
#                             -0.70217047263768517,
#                             -5.7343333598281507,
#                             9.7086063344151547],
#                      'SF': [-12.514821129777932,
#                             128.69226690973363,
#                             363.76028617624922,
#                             4.7695938511324218]}],
#            'Ksat2': [{'LA': [0.11746666666666668,
#                              0.23493333333333336,
#                              0.35240000000000005,
#                              0.025171428571428574],
#                       'LF': [0.01762, 0.03524, 0.03524, 0.35240000000000005],
#                       'SA': [0.14096,
#                              0.35240000000000005,
#                              1.1746666666666667,
#                              0.7048000000000001],
#                       'SF': [0.35240000000000005, 0.01762, 0.01762, 0.07048]}],
#            'R1_FA': [0.97167044953232651, 0.98950154118247413],
#            'R2_ALL': [0.98438832454669278]}]}

# %%
pprint.pprint(output_pesti_params)
# Out:
# {'Vine': {'Err1': {'LA': ['No obs | < LD ',
#                           'No obs | < LD ',
#                           26.817763717208454,
#                           'No obs | < LD '],
#                    'LF': ['No obs | < LD ',
#                           'No obs | < LD ',
#                           -99.619962041364104,
#                           'No obs | < LD '],
#                    'SA': [-89.704156470834292,
#                           'No obs | < LD ',
#                           -0.5961129404687856,
#                           'No obs | < LD '],
#                    'SF': [46.081694610343582,
#                           55.613211427929876,
#                           -46.333697755050025,
#                           181.23603209138713]},
#           'Err2': {'LA': ['No obs | < LD ',
#                           'No obs | < LD ',
#                           'No obs | < LD ',
#                           'No obs | < LD '],
#                    'LF': ['No obs | < LD ',
#                           'No obs | < LD ',
#                           'No obs | < LD ',
#                           'No obs | < LD '],
#                    'SA': ['No obs | < LD ',
#                           'No obs | < LD ',
#                           -99.95369959992415,
#                           'No obs | < LD '],
#                    'SF': ['No obs | < LD ',
#                           'No obs | < LD ',
#                           'No obs | < LD ',
#                           'No obs | < LD ']},
#           'Koc1': {'LA': 932.61927295581563,
#                    'LF': 93041.004477120718,
#                    'SA': 1544.5333887703327,
#                    'SF': 772.26669438516637},
#           'Koc2': {'LA': 98.951050133562177,
#                    'LF': 49.475525066781088,
#                    'SA': 140883.79489300455,
#                    'SF': 70.441897446502267},
#           'R1': {'LA': 0.93166817569672,
#                  'LF': 0.99764272284153854,
#                  'SA': 0.98874266151191648,
#                  'SF': -0.86820412037203476},
#           'R2': {'LA': 1, 'LF': 1, 'SA': 0.75023144840720313, 'SF': 1.0},
#           'logKd1': {'LA': 3.5, 'LF': 3.5, 'SA': 1.5, 'SF': 1.5},
#           'logKd2': {'LA': 0.5, 'LF': 0.5, 'SA': 0.5, 'SF': 0.5}}}

# %% [markdown]
# END NOTEBOOK
