# %% [markdown]
# START NOTEBOOK

# %% [markdown]
# ## Set-up

# %%
from hydroplots import *
from leach_hydrology import *
import numpy as np

import mpld3
mpld3.enable_notebook()

# Plot graphs within this document
# %matplotlib inline

# Plot graphs outside (for interaction)
# %matplotlib

from pestmob import *
from mixinglayer import *

# %% [markdown]
# ### Pesticide, soil type and runoff calibration parameter.

# %%
# Soil and pesticide
pesticide = 'S-metolachlor'
initial_condition = 'mean'
soil_type = 'Vine Soil'
soil = 'Rouff'
soil_short = 'Vine'

pesti_obs = choose_pesticide(
    pesticide,
    soil)

# Kd ranges to test
Kd_pest_sterile = pesti_obs[0]
Kd_pest_living = pesti_obs[1]

# Initial concentrations and mass out observed
pest_dict_S_1st = pesti_obs[2]
pest_dict_L_1st = pesti_obs[3]
pest_dict_S_2nd = pesti_obs[4]
pest_dict_L_2nd = pesti_obs[5]

# Assumed (used to calculate Reynolds number)
runoff_vel = 10.0  # mm/min

# %% [markdown]
# ### Microcosm

# %%
d = (14.93 * 2)  # Diameter of falcon tube (mm)
area = ((d / 2) ** 2) * 3.1416  # (mm2)
soil_height1 = 20  # Mixing layer depth in mm
soil_height2 = 20  # mm

# %% [markdown]
# ### Soil hydrological characteristics

# %%
if soil == 'Alteck':
    kSat = 2.24  # mm/min (13.45 cm/h - Crop Soil) 
    psi = 1100  # soil suction Alteck (mm)
    eff_height = 0.80
elif soil == 'Rouff': 
    kSat = 17.62*10/60  # mm/min (17.62 cm/h - Vine Soil) 
    psi = 1100  # soil suction Alteck (mm)
    eff_height = 0.76
    
# Soil characteristics (Equivalent for Alteck and Rouffach)
# Initial bulk density options:
pb_i0 = 0.99/10**3  # bulk density (g/cm^3) -> g/mm^3  (M. Trautmann)
pb_i1 = 2.61/10**3 # inital 1st pulse, calc. from experiment cond.
pb_i2 = 3.59/10**3 # initial 2nd pulse, calc. from experiment cond.

# Final bulk density options (1st and 2nd pulses)
pb_f1 = 3.59/10**3 # final1, calculated from experimental conditions.
pb_f2 = 3.76/10**3 # final2, calculated from experimental conditions.

# %% [markdown]
# ### Store results

# %%
output_hydro_params = {
    soil_short : [{'R1_FA':[],
              'R2_ALL':[],
              'Err1':[{'Fresh':[], 'Aged':[]}],
              'Err2':[{'SF':[], 'SA':[], 'LF':[], 'LA':[]}],
              'Ksat2':[{'SF':[], 'SA':[], 'LF':[], 'LA':[]}]
             }]
    }

# %%
output_pesti_params = {
    soil_short: {'R1': {'SF': None, 'SA': None, 'LF': None, 'LA': None},
                 'R2': {'SF': None, 'SA': None, 'LF': None, 'LA': None},
                 'Err1': {'SF': [], 'SA': [], 'LF': [], 'LA': [],
                          'SFmax': [], 'SAmax': [], 'LFmax': [], 'LAmax': [],
                          'SFmin': [], 'SAmin': [], 'LFmin': [], 'LAmin': []},
                 'Err2': {'SF': [], 'SA': [], 'LF': [], 'LA': [],
                          'SFmax': [], 'SAmax': [], 'LFmax': [], 'LAmax': [],
                          'SFmin': [], 'SAmin': [], 'LFmin': [], 'LAmin': []},
                 'Koc1': {'SF': None, 'SA': None, 'LF': None, 'LA': None},
                 'Koc2': {'SF': None, 'SA': None, 'LF': None, 'LA': None},
                 'Kd1': {'SF': None, 'SA': None, 'LF': None, 'LA': None},
                 'Kd2': {'SF': None, 'SA': None, 'LF': None, 'LA': None}
                 }
}

# %% [markdown]
# ## Hydrology - 1st pulse

# %% [markdown]
# #### Computation

# %%
water_data = leachsim(kSat = kSat,
                      soil_height=soil_height1,
                      eff_height=eff_height,
                      soil = 'Alteck',
                      psi=psi)
# Out:
# Mass balance True
# Mass balance 0.0
# Mass balance 0.0

# %%
water_eval = leachsim2(
    kSat = [kSat],
    soil_height=soil_height1,
    eff_height = eff_height,
    soil = 'Alteck',
    isAGED = False,
    isFirstCycle=True 
)

output_hydro_params = extract_goodness(
    water_eval,
    output_hydro_params,
    soil_short,
    isFirstCycle = True,
    isAGED = False)
# Out:
# FRESH
# --------------------------------------------
# ksat high:  17.62 cm/h
# ksat med12:  17.62 cm/h
# ksat med30:  17.62 cm/h
# ksat low:  17.62 cm/h
# --------------------------------------------
# R2:  0.971670449532
# --------------------------------------------
# Simulation error percent (%), by modality
# --------------------------------------------
# 135 mm/h - 6min  -1.6576800421
# 55 mm/h - 12min  55.7145290413
# 55 mm/h - 30min  4.54963224758
# 30 mm/h - 30min  1.17824563313
# --------------------------------------------
# Mass balance:  True True True True

# %%
water_eval = leachsim2(
    kSat = [kSat],
    soil_height=soil_height1,
    eff_height = eff_height,
    soil = 'Alteck',
    isAGED = True,
    isFirstCycle=True 
)

output_hydro_params = extract_goodness(
    water_eval,
    output_hydro_params,
    soil_short,
    isFirstCycle = True,
    isAGED = True)
# Out:
# AGED
# --------------------------------------------
# ksat high:  17.62 cm/h
# ksat med12:  17.62 cm/h
# ksat med30:  17.62 cm/h
# ksat low:  17.62 cm/h
# --------------------------------------------
# R2:  0.989501541182
# --------------------------------------------
# Simulation error percent (%), by modality
# --------------------------------------------
# 135 mm/h - 6min  -9.94976957607
# 55 mm/h - 12min  -3.83662745901
# 55 mm/h - 30min  -0.191716281473
# 30 mm/h - 30min  -10.6817509472
# --------------------------------------------
# Mass balance:  True True True True

# %%
title = "Percolated Volume [mL] - " + str(soil_type) + "1st Pulse"

# %%
extract_and_plothydro(
    water_data,
    "Percolated at 135mm/h", "Percolated at 55mm/h", "Percolated at 30mm/h", "NA",
    title,
    soil,
    isFirstCycle = True,
    isPercolation = True
)

# %%
# Cummulative leaching
cum_leach_135mmh = water_data[:, 7]
cum_leach_55mmh = water_data[:, 8]
cum_leach_30mmh = water_data[:, 9]

# %%
print ("Modelled percolation for 1st pulse, Vineyard soil (mL):") 

print("135 mm/h at 6 min", cum_leach_135mmh[5]/1000)
 
print("55 mm/h at 12 min", cum_leach_55mmh[11]/1000)

print("55 mm/h at 30 min:" , cum_leach_55mmh[-1]/1000)

print("30 mm/h at 30 min:", cum_leach_30mmh[-1]/1000)
# Out:
# Modelled percolation for 1st pulse, Vineyard soil (mL):
# 135 mm/h at 6 min 14.1806301853
# 55 mm/h at 12 min 11.5966042404
# 55 mm/h at 30 min: 46.3864169616
# 30 mm/h at 30 min: 18.9075069137

# %%
hydro1 = extract(
    water_data, 
    isFirstCycle = True
)

percol_data1 = hydro1[0]
runoff_data1 = hydro1[1]
time_sizes1 = hydro1[2]

# %% [markdown]
# ## Transport - 1st pulse

# %% [markdown]
# ### Computation transport - 1st pulse

# %% [markdown]
# #### Test factor X (Sterile)

# %%
x = 2

# %%
pest_sterile_1st = pest_linear_x(
    Kd_pest_sterile,
    x,
    initial_condition,
    pest_dict_S_1st,          
    pb_i1, pb_f1,
    percol_data1, runoff_data1,
    time_sizes1,
    area, soil_height1, 
    d, runoff_vel,
    soil,
    isFirstCycle = True,
    isLiving = False,
    KFILM = True)

output_pesti_params = extract_goodness_pest(
        pest_sterile_1st,
        output_pesti_params,
        soil_short,
        isLiving = False,
        isFirstCycle = True)
# Out:
# 1st Pulse
# Sterile Vine
# --------------------------------------------
# Koc tested:  [ 369.  300.  250.  225.  200.  150.  125.  100.   75.   50.   30.]
# Best Kd (Fresh):  7.554906 cm3/g ( Num:  1 )
#  x factor:  2
#  R2:  -1.41732469057
#  Effective Koc (fresh) - [cm3/g]: 184.5
# --------------------------------------------
# Best Kd (Aged):  2.0474 cm3/g ( Num:  8 )
#  x factor: No factor considered.
#  R2:  -1.00945242787
#  Effective Koc (aged) [cm3/g]: 100.0
# --------------------------------------------
# --------------------------------------------
# Scenario - modality - Predicted error prcnt (%) | Predicted | Observed |
# --------------------------------------------
# (A) 135 mm/h - Fresh  -67.6697109429 | 48.0104792498 | 148.5
# (A) 135 mm/h - Aged  -58.049063337 | 46.7752943792 | 111.5
# (B) 55 mm/h - Fresh  -68.3361323701 | 50.6938520755 | 160.1
# (B) 55 mm/h - Aged  -42.6160256143 | 63.524059645 | 110.7
# (C) 55 mm/h - Fresh  37.2970944681 | 258.530428883 | 188.3
# (C) 55 mm/h - Aged  -12.7332973897 | 205.774884755 | 235.8
# (D) 30 mm/h - Fresh  -31.3318340811 | 271.555837374 | 237.4
# (D) 30 mm/h - Aged  16.2953240473 | 206.870899339 | 142.8

# %% [markdown]
# #### Test factor X (Living)

# %%
x = 2

# %%
pest_living_1st = pest_linear_x(
    Kd_pest_living,
    x,
    initial_condition,
    pest_dict_L_1st,          
    pb_i1, pb_f1,
    percol_data1, percol_data1,
    time_sizes1,
    area, soil_height1, 
    d, runoff_vel,
    soil,
    KFILM = True,
    isFirstCycle = True,
    isLiving = True)


output_pesti_params = extract_goodness_pest(
        pest_living_1st,
        output_pesti_params,
        soil_short,
        isLiving = True,
        isFirstCycle = True)
# Out:
# 1st Pulse
# Living Vine
# --------------------------------------------
# Koc tested:  [ 369.  300.  250.  225.  200.  150.  125.  100.   75.   50.   30.]
# Best Kd (Fresh):  4.2485 cm3/g ( Num:  3 )
#  x factor:  2
#  R2:  -1.32249273481
#  Effective Koc (fresh) - [cm3/g]: 125.0
# --------------------------------------------
# Best Kd (Aged):  3.3988 cm3/g ( Num:  5 )
#  x factor: No factor considered.
#  R2:  0.921940364833
#  Effective Koc (aged) [cm3/g]: 200.0
# --------------------------------------------
# --------------------------------------------
# Scenario - modality - Predicted error prcnt (%) | Predicted | Observed |
# --------------------------------------------
# (A) 135 mm/h - Fresh  -48.6365508298 | 57.4243361723 | 111.8
# (A) 135 mm/h - Aged  -20.8302348761 | 29.4511526261 | 37.2
# (B) 55 mm/h - Fresh  -30.7098964969 | 77.1198851989 | 111.3
# (B) 55 mm/h - Aged  -49.2506364305 | 40.2442453106 | 79.3
# (C) 55 mm/h - Fresh  -11.022133088 | 247.714381483 | 278.4
# (C) 55 mm/h - Aged  16.1668410569 | 181.33643889 | 156.1
# (D) 30 mm/h - Fresh  38.1691566047 | 254.951752564 | 142.0
# (D) 30 mm/h - Aged  -10.9817749123 | 193.390746682 | 134.7

# %% [markdown]
# #### Time series

# %%
data_stack = pest_sterile_1st['Data_stack']
sterile1 = extract_pest(data_stack)

mass_percol_sterile1 = sterile1[0]
mass_pond_sterile1 = sterile1[1]

# %%
data_stack = pest_living_1st['Data_stack']
living1 = extract_pest(data_stack)

mass_percol_living1 = living1[0]
mass_pond_living1 = living1[1]

# %% [markdown]
# ## Plotting transport

# %% [markdown]
# ### Sterile (1st Pulse, Crop Soil)

# %%
pestiplot_condition(
    mass_percol_sterile1,
    pest_dict_S_1st,
    pesticide,
    soil_type,
    cycle = '1st pulse',
    LEACH = True,
    STERILE = True
)

# %% [markdown]
# ### Living (1st Pulse, Crop Soil)

# %%
pestiplot_condition(
    mass_percol_living1,
    pest_dict_L_1st,
    pesticide,
    soil_type,
    cycle = '1st pulse',
    LEACH = True,
    STERILE = False
)

# %% [markdown]
# # Hydrology - 2nd pulse

# %% [markdown]
# ### Inverse Ksat determination
#
# Based on hisotric rainfall pattern, fresh and aged.

# %%
water2_ktest = leachsim3(
    soil,
    kSat = [ kSat/5, kSat/10, kSat/15,
        kSat/25, kSat/50,  kSat/75, 
        kSat/100, kSat/125, kSat/150, 
        kSat/175, kSat/200, kSat/250,
        kSat/350, kSat/500, kSat/700, kSat/1000],
    soil_height=soil_height2,
    isFirstCycle = False
)

output_hydro_params = extract_goodness(
    water2_ktest,
    output_hydro_params,
    soil_short,
    isFirstCycle = False,
    isAGED = None
)
# Out:
# R2:  0.984388324547
# --------------------------------------------
# Sterile, Fresh Soil
# ksat high:  0.35240000000000005 cm/h | Error % -12.5148211298
# ksat med12:  0.01762 cm/h | Error % 128.69226691
# ksat med30:  0.01762 cm/h | Error % 363.760286176
# ksat low:  0.07048 cm/h | Error % 4.76959385113
# --------------------------------------------
# Sterile, Aged Soil
# ksat high:  0.14096 cm/h | Error % -0.626720468252
# ksat med12:  0.35240000000000005 cm/h | Error % -0.702170472638
# ksat med30:  1.1746666666666667 cm/h | Error % -5.73433335983
# ksat low:  0.7048000000000001 cm/h | Error % 9.70860633442
# --------------------------------------------
# Living, Fresh Soil
# ksat high:  0.01762 cm/h | Error % inf
# ksat med12:  0.03524 cm/h | Error % 3.53388184937
# ksat med30:  0.17620000000000002 cm/h | Error % 2.28902480468
# ksat low:  0.35240000000000005 cm/h | Error % -9.70964935858
# --------------------------------------------
# Living, Fresh Aged
# ksat high:  0.11746666666666668 cm/h | Error % 2.32506552889
# ksat med12:  0.23493333333333336 cm/h | Error % 1.77596424015
# ksat med30:  0.35240000000000005 cm/h | Error % -6.81514797032
# ksat low:  0.025171428571428574 cm/h | Error % -4.08530151711
# --------------------------------------------

# %% [markdown]
# ### Percolation - 2nd pulse

# %%
title = "Percolated Volume [mL] - " + str(soil_type) +  " 2nd Pulse"

# %%
extract_and_plothydro(
    water2_ktest,
    "Leached, 135mm/h", "Leached, 55mm/h - A", "Leached, 55mm/h - B", "Leached, 30mm/h",
    title,
    soil,
    isFirstCycle = False,
    isPercolation = True
)

# %%
# Cummulative percolation (2nd pulse)
cum_leach_135mmh_SF = water2_ktest[0][:, 2]
cum_leach_135mmh_SA = water2_ktest[0][:, 4]
cum_leach_135mmh_LF = water2_ktest[0][:, 6]
cum_leach_135mmh_LA = water2_ktest[0][:, 8]

cum_leach_55mmhA_SF = water2_ktest[0][:, 10]
cum_leach_55mmhA_SA = water2_ktest[0][:, 12]
cum_leach_55mmhA_LF = water2_ktest[0][:, 14]
cum_leach_55mmhA_LA = water2_ktest[0][:, 16]

cum_leach_55mmhB_SF = water2_ktest[0][:, 18]
cum_leach_55mmhB_SA = water2_ktest[0][:, 20]
cum_leach_55mmhB_LF = water2_ktest[0][:, 22]
cum_leach_55mmhB_LA = water2_ktest[0][:, 24]

cum_leach_30mmh_SF = water2_ktest[0][:, 26]
cum_leach_30mmh_SA = water2_ktest[0][:, 28]
cum_leach_30mmh_LF = water2_ktest[0][:, 30]
cum_leach_30mmh_LA = water2_ktest[0][:, 32]

# %%
print ("Modelled percolation for 2nd pulse, Vineyard soil (mL):") 
print ("-----")
print("For 135 mm/h at 6 min:")
print("Fresh", cum_leach_135mmh_LF[5]/1000)
print("Aged", cum_leach_135mmh_LA[5]/1000)
print ("-----")
print ("-----")
print("A")
print("For 55 mm/h at 12 min:")
print("Fresh", cum_leach_55mmhA_LF[11]/1000)
print("Aged", cum_leach_55mmhA_LA[11]/1000)
print ("-----")
print("For 55 mm/h at 30 min:")
print("Fresh", cum_leach_55mmhA_LF[-1]/1000)
print("Aged", cum_leach_55mmhA_LA[-1]/1000)
print ("-----")
print ("-----")
print("B")
print("For 55 mm/h at 12 min:")
print("Fresh", cum_leach_55mmhB_LF[11]/1000)
print("Aged", cum_leach_55mmhB_LA[11]/1000)
print ("-----")
print("For 55 mm/h at 30 min:")
print("Fresh", cum_leach_55mmhB_LF[-1]/1000)
print("Aged", cum_leach_55mmhB_LA[-1]/1000)
print ("-----")
print ("-----")
print("For 30 mm/h at 30 min:")
print("Fresh", cum_leach_30mmh_LF[-1]/1000)
print("Aged", cum_leach_30mmh_LA[-1]/1000)
# Out:
# Modelled percolation for 2nd pulse, Vineyard soil (mL):
# -----
# For 135 mm/h at 6 min:
# Fresh 1.09604314132
# Aged 6.70126854149
# -----
# -----
# A
# For 55 mm/h at 12 min:
# Fresh 3.79865812505
# Aged 13.2186622355
# -----
# For 55 mm/h at 30 min:
# Fresh 6.92212515426
# Aged 22.0891061074
# -----
# -----
# B
# For 55 mm/h at 12 min:
# Fresh 11.5120825051
# Aged 15.9472314221
# -----
# For 55 mm/h at 30 min:
# Fresh 19.0267815039
# Aged 27.2397959453
# -----
# -----
# For 30 mm/h at 30 min:
# Fresh 24.140931051
# Aged 5.94383386498

# %% [markdown]
# ### Ponding - 2nd pulse

# %%
title = "Ponded Volume [mL] [mL] - " + str(soil_type) +  " 2nd Pulse"

# %%
extract_and_plothydro(
    water2_ktest,
    "Ponded, 135mm/h", "Ponded, 55mm/h - A", "Ponded, 55mm/h - B", "Ponded, 30mm/h",
    title,
    soil,
    isFirstCycle = False,
    isPercolation = False
)

# %%
# Ponding cumulative
cum_roff_135mmh_SF = water2_ktest[0][:, 1]
cum_roff_135mmh_SA = water2_ktest[0][:, 3]
cum_roff_135mmh_LF = water2_ktest[0][:, 5]
cum_roff_135mmh_LA = water2_ktest[0][:, 7]

#A
cum_roff_55mmhA_SF = water2_ktest[0][:, 9]
cum_roff_55mmhA_SA = water2_ktest[0][:, 11]
cum_roff_55mmhA_LF = water2_ktest[0][:, 13]
cum_roff_55mmhA_LA = water2_ktest[0][:, 15]
#B
cum_roff_55mmhB_SF = water2_ktest[0][:, 17]
cum_roff_55mmhB_SA = water2_ktest[0][:, 19]
cum_roff_55mmhB_LF = water2_ktest[0][:, 21]
cum_roff_55mmhB_LA = water2_ktest[0][:, 23]

cum_roff_30mmh_SF = water2_ktest[0][:, 25]
cum_roff_30mmh_SA = water2_ktest[0][:, 27]
cum_roff_30mmh_LF = water2_ktest[0][:, 29]
cum_roff_30mmh_LA = water2_ktest[0][:, 31]

# %%
print ("Modelled ponding for 2nd pulse, Vineyard soil (mL):") 
print ("-----")
print("For 135 mm/h at 6 min:")
print("Fresh", cum_roff_135mmh_LF[5]/1000)
print("Aged", cum_roff_135mmh_LA[5]/1000)
print ("-----")
print ("-----")
print("A")
print("For 55 mm/h at 12 min:")
print("Fresh", cum_roff_55mmhA_LF[11]/1000)
print("Aged", cum_roff_55mmhA_LA[11]/1000)
print ("-----")
print("For 55 mm/h at 30 min:")
print("Fresh", cum_roff_55mmhA_LF[-1]/1000)
print("Aged", cum_roff_55mmhA_LA[-1]/1000)
print ("-----")
print ("-----")
print("B")
print("For 55 mm/h at 12 min:")
print("Fresh", cum_roff_55mmhB_LF[11]/1000)
print("Aged", cum_roff_55mmhB_LA[11]/1000)
print ("-----")
print("For 55 mm/h at 30 min:")
print("Fresh", cum_roff_55mmhB_LF[-1]/1000)
print("Aged", cum_roff_55mmhB_LA[-1]/1000)
print ("-----")
print ("-----")
print("For 30 mm/h at 30 min:")
print("Fresh", cum_roff_30mmh_LF[-1]/1000)
print("Aged", cum_roff_30mmh_LA[-1]/1000)
# Out:
# Modelled ponding for 2nd pulse, Vineyard soil (mL):
# -----
# For 135 mm/h at 6 min:
# Fresh 25.7901092604
# Aged 21.659991829
# -----
# -----
# A
# For 55 mm/h at 12 min:
# Fresh 18.027707905
# Aged 9.97454624527
# -----
# For 55 mm/h at 30 min:
# Fresh 49.694053597
# Aged 35.8939150945
# -----
# -----
# B
# For 55 mm/h at 12 min:
# Fresh 11.6811259757
# Aged 7.24597705869
# -----
# For 55 mm/h at 30 min:
# Fresh 38.956239698
# Aged 30.7432252566
# -----
# -----
# For 30 mm/h at 30 min:
# Fresh 6.32116342104
# Aged 24.5647544325

# %%
hydro2 = extract(
    water2_ktest,
    isFirstCycle = False
)
percol_data2 = hydro2[0]
runoff_data2 = hydro2[1]
time_sizes2 = hydro2[2]

# %% [markdown]
# ## Transport - 2nd pulse

# %% [markdown]
# ### Computation transport - 2nd Pulse

# %% [markdown]
# #### Kd optimal (sterile)

# %%
x = 2

# %%
pest_sterile_2nd = pest_linear_x(
    Kd_pest_sterile,
    x,
    initial_condition,
    pest_dict_S_2nd,
    pb_i2, pb_f2,
    percol_data2, runoff_data2,
    time_sizes2,
    area, soil_height2,
    d, runoff_vel,
    soil = soil,
    isFirstCycle = False,
    isLiving = False)

output_pesti_params = extract_goodness_pest(
        pest_sterile_2nd,
        output_pesti_params,
        soil_short,
        isLiving = False,
        isFirstCycle = False)
# Out:
# 2nd Pulse
# Sterile Vine
# --------------------------------------------
# Koc tested:  [ 369.  300.  250.  225.  200.  150.  125.  100.   75.   50.   30.]
# Best Kd (Fresh):  7.554906 cm3/g ( Num:  1 )
#  x factor:  2
#  R2:  -2.77552294508
#  Effective Koc (fresh) - [cm3/g]: 184.5
# --------------------------------------------
# Best Kd (Aged):  4.0948 cm3/g ( Num:  5 )
#  x factor: No factor considered.
#  R2:  0.918214195529
#  Effective Koc (aged) [cm3/g]: 200.0
# --------------------------------------------
# --------------------------------------------
# Scenario - modality - Predicted error prcnt (%) | Predicted | Observed |
# --------------------------------------------
# (A) 135 mm/h - Fresh  No obs | 41.530848358 | nan
# (A) 135 mm/h - Aged  -67.6264346466 | 9.42070751783 | 29.1
# (B) 55 mm/h - Fresh  No obs | 11.4826023211 | nan
# (B) 55 mm/h - Aged  -28.9073178142 | 29.2190923784 | 41.1
# (C) 55 mm/h - Fresh  No obs | 51.119791136 | nan
# (C) 55 mm/h - Aged  -11.9094060947 | 60.5563915558 | 74.7
# (D) 30 mm/h - Fresh  161.508706057 | 164.057271376 | 40.5
# (D) 30 mm/h - Aged  -12.1928112813 | 51.4658355344 | 70.2

# %% [markdown]
# #### Kd optimal (living)

# %%
x = 2

# %%
pest_living_2nd = pest_linear_x(
    Kd_pest_living,
    x,
    initial_condition,
    pest_dict_L_2nd,          
    pb_i1, pb_f1,
    percol_data2, runoff_data2,
    time_sizes1,
    area, soil_height1, 
    d, runoff_vel,
    soil = soil,
    KFILM = True,
    isFirstCycle = False,
    isLiving = True)

output_pesti_params = extract_goodness_pest(
        pest_living_2nd,
        output_pesti_params,
        soil_short,
        isLiving = True,
        isFirstCycle = False)
# Out:
# 2nd Pulse
# Living Vine
# --------------------------------------------
# Koc tested:  [ 369.  300.  250.  225.  200.  150.  125.  100.   75.   50.   30.]
# Best Kd (Fresh):  6.270786 cm3/g ( Num:  1 )
#  x factor:  2
#  R2:  0.664122964265
#  Effective Koc (fresh) - [cm3/g]: 184.5
# --------------------------------------------
# Best Kd (Aged):  6.270786 cm3/g ( Num:  1 )
#  x factor: No factor considered.
#  R2:  0.601054600157
#  Effective Koc (aged) [cm3/g]: 369.0
# --------------------------------------------
# --------------------------------------------
# Scenario - modality - Predicted error prcnt (%) | Predicted | Observed |
# --------------------------------------------
# (A) 135 mm/h - Fresh  No obs | 2.79309682953 | nan
# (A) 135 mm/h - Aged  -58.7068108343 | 6.64820345568 | 16.1
# (B) 55 mm/h - Fresh  No obs | 17.5377713475 | nan
# (B) 55 mm/h - Aged  -21.5141238368 | 20.6417854309 | 26.3
# (C) 55 mm/h - Fresh  No obs | 98.0177983825 | nan
# (C) 55 mm/h - Aged  98.8516838348 | 52.487837297 | 28.5
# (D) 30 mm/h - Fresh  40.7219099658 | 42.0109516093 | 77.2
# (D) 30 mm/h - Aged  478.058480813 | 43.8684765029 | 3.4

# %% [markdown]
# #### Time series

# %%
data_stack = pest_sterile_2nd['Data_stack']
sterile2 = extract_pest(data_stack)

data_stack = pest_living_2nd['Data_stack']
living2 = extract_pest(data_stack)

mass_percol_sterile2 = sterile2[0]
mass_pond_sterile2 = sterile2[1]

mass_percol_living2 = living2[0]
mass_pond_living2 = living2[1]

# %% [markdown]
# ## Plotting transport

# %% [markdown]
# ### Sterile (2nd Pulse)

# %%
pestiplot_condition(
    mass_percol_sterile2,
    pest_dict_S_2nd,
    pesticide,
    soil_type,
    cycle = '2nd pulse',
    LEACH = True,
    STERILE = True
)

# %%
pestiplot_condition(
    mass_pond_sterile2,
    pest_dict_S_2nd,
    pesticide,
    soil_type,
    cycle = '2nd pulse',
    LEACH = False,
    STERILE = True
)

# %% [markdown]
# ### Living (2nd Pulse)

# %%
pestiplot_condition(
    mass_percol_living2,
    pest_dict_L_2nd,
    pesticide,
    soil_type,
    cycle = '2nd pulse',
    LEACH = True,
    STERILE = False
)

# %%
pestiplot_condition(
    mass_pond_living2,
    pest_dict_L_2nd,
    pesticide,
    soil_type,
    cycle = '2nd pulse',
    LEACH = False,
    STERILE = False
)

# %% [markdown]
# END NOTEBOOK

# %% [markdown]
# ### Max values

# %%
initial_condition = 'max'

# %% [markdown]
# #### 1st Pulse

# %%
Kd1_SF = output_pesti_params[soil_short]['Kd1']['SF']*10**3  # Convert back to mm3/g (model units)
Kd1_SA = output_pesti_params[soil_short]['Kd1']['SA']*10**3
Kd1_choice_sterile = [Kd1_SF, Kd1_SA]

Kd1_LF = output_pesti_params[soil_short]['Kd1']['LF']*10**3
Kd1_LA = output_pesti_params[soil_short]['Kd1']['LA']*10**3
Kd1_choice_living = [Kd1_LF, Kd1_LA]

# %%
max_sterile_1st = pest_Kd_choice(
    Kd1_choice_sterile,
    x,
    initial_condition,
    pest_dict_S_1st,          
    pb_i1, pb_f1,
    percol_data1, runoff_data1,
    time_sizes1,
    area, soil_height1, 
    d, runoff_vel,
    soil,
    isFirstCycle = True,
    isLiving = False,
    KFILM = True)

output_pesti_params = extract_goodness_maxmin(
        max_sterile_1st,
        initial_condition,
        output_pesti_params,
        soil_short,
        isLiving = False,
        isFirstCycle = True)
# Out:
# 1st Pulse
# Sterile Vine
# --------------------------------------------
# Koc tested:  [ 369.  100.]
# Best Kd (Fresh):  7.554906 cm3/g ( Num:  1 )
#  x factor:  2
#  R2:  -2.21379646046
#  Effective Koc (fresh) - [cm3/g]: 184.5
# --------------------------------------------
# Best Kd (Aged):  2.0474 cm3/g ( Num:  2 )
#  x factor: No factor considered.
#  R2:  -16.2217475257
#  Effective Koc (aged) [cm3/g]: 100.0
# --------------------------------------------
# --------------------------------------------
# Scenario - modality - Predicted error prcnt (%) | Predicted | Observed |
# --------------------------------------------
# (A) 135 mm/h - Fresh  -55.4705155813 | 66.1262843618 | 148.5
# (A) 135 mm/h - Aged  -16.0926295979 | 93.5567179983 | 111.5
# (B) 55 mm/h - Fresh  -56.3883979579 | 69.8221748694 | 160.1
# (B) 55 mm/h - Aged  14.7754681286 | 127.056443218 | 110.7
# (C) 55 mm/h - Fresh  89.1034385141 | 356.081774722 | 188.3
# (C) 55 mm/h - Aged  74.544840286 | 411.576733394 | 235.8
# (D) 30 mm/h - Fresh  -5.42125933525 | 374.022063576 | 237.4
# (D) 30 mm/h - Aged  132.60588695 | 413.76890618 | 142.8

# %%
max_living_1st = pest_Kd_choice(
    Kd1_choice_living,
    x,
    initial_condition,
    pest_dict_L_1st,          
    pb_i1, pb_f1,
    percol_data1, runoff_data1,
    time_sizes1,
    area, soil_height1, 
    d, runoff_vel,
    soil,
    isFirstCycle = True,
    isLiving = False,
    KFILM = True)

output_pesti_params = extract_goodness_maxmin(
        max_living_1st,
        initial_condition,
        output_pesti_params,
        soil_short,
        isLiving = True,
        isFirstCycle = True)
# Out:
# 1st Pulse
# Sterile Vine
# --------------------------------------------
# Koc tested:  [ 207.50708215  166.00566572]
# Best Kd (Fresh):  4.2485 cm3/g ( Num:  1 )
#  x factor:  2
#  R2:  -39.708917085
#  Effective Koc (fresh) - [cm3/g]: 103.753541076
# --------------------------------------------
# Best Kd (Aged):  3.3988 cm3/g ( Num:  2 )
#  x factor: No factor considered.
#  R2:  -1.22601476195
#  Effective Koc (aged) [cm3/g]: 166.005665722
# --------------------------------------------
# --------------------------------------------
# Scenario - modality - Predicted error prcnt (%) | Predicted | Observed |
# --------------------------------------------
# (A) 135 mm/h - Fresh  32.257858728 | 147.864286058 | 111.8
# (A) 135 mm/h - Aged  59.7493046617 | 59.4267413342 | 37.2
# (B) 55 mm/h - Fresh  41.5887669724 | 157.58829764 | 111.3
# (B) 55 mm/h - Aged  3.75136741462 | 82.2748343598 | 79.3
# (C) 55 mm/h - Fresh  88.4699974821 | 524.70047299 | 278.4
# (C) 55 mm/h - Aged  149.18122152 | 388.971886793 | 156.1
# (D) 30 mm/h - Fresh  194.387191034 | 523.020523233 | 142.0
# (D) 30 mm/h - Aged  90.5595598725 | 404.699201424 | 134.7

# %% [markdown]
# #### 2ndPulse Pulse

# %%
Kd2_SF = output_pesti_params[soil_short]['Kd2']['SF']*10**3
Kd2_SA = output_pesti_params[soil_short]['Kd2']['SA']*10**3
Kd2_choice_sterile = [Kd2_SF, Kd2_SA]

Kd2_LF = output_pesti_params[soil_short]['Kd2']['LF']*10**3
Kd2_LA = output_pesti_params[soil_short]['Kd2']['LA']*10**3
Kd2_choice_living = [Kd2_LF, Kd2_LA]

# %%
max_sterile_2nd = pest_Kd_choice(
    Kd2_choice_sterile,
    x,
    initial_condition,
    pest_dict_S_2nd,          
    pb_i2, pb_f2,
    percol_data2, runoff_data2,
    time_sizes2,
    area, soil_height2, 
    d, runoff_vel,
    soil,
    isFirstCycle = False,
    isLiving = False)

output_pesti_params = extract_goodness_maxmin(
        max_sterile_2nd,
        initial_condition,
        output_pesti_params,
        soil_short,
        isLiving = False,
        isFirstCycle = False)
# Out:
# 2nd Pulse
# Sterile Vine
# --------------------------------------------
# Koc tested:  [ 369.  200.]
# Best Kd (Fresh):  7.554906 cm3/g ( Num:  1 )
#  x factor:  2
#  R2:  -12.2957603794
#  Effective Koc (fresh) - [cm3/g]: 184.5
# --------------------------------------------
# Best Kd (Aged):  4.0948 cm3/g ( Num:  2 )
#  x factor: No factor considered.
#  R2:  0.801406082634
#  Effective Koc (aged) [cm3/g]: 200.0
# --------------------------------------------
# --------------------------------------------
# Scenario - modality - Predicted error prcnt (%) | Predicted | Observed |
# --------------------------------------------
# (A) 135 mm/h - Fresh  No obs | 63.6973314638 | nan
# (A) 135 mm/h - Aged  -50.2090244739 | 14.4891738781 | 29.1
# (B) 55 mm/h - Fresh  No obs | 17.6211768263 | nan
# (B) 55 mm/h - Aged  9.33071351928 | 44.9349232564 | 41.1
# (C) 55 mm/h - Fresh  No obs | 78.5757364323 | nan
# (C) 55 mm/h - Aged  37.8773594348 | 93.1273556347 | 74.7
# (D) 30 mm/h - Fresh  303.084670133 | 251.62044136 | 40.5
# (D) 30 mm/h - Aged  35.5973854662 | 79.1551418434 | 70.2

# %%
max_living_2nd = pest_Kd_choice(
    Kd2_choice_living,
    x,
    initial_condition,
    pest_dict_L_2nd,          
    pb_i2, pb_f2,
    percol_data2, runoff_data2,
    time_sizes2,
    area, soil_height2, 
    d, runoff_vel,
    soil,
    isFirstCycle = False,
    isLiving = True)

output_pesti_params = extract_goodness_maxmin(
        max_living_2nd,
        initial_condition,
        output_pesti_params,
        soil_short,
        isLiving = True,
        isFirstCycle = False)
# Out:
# 2nd Pulse
# Living Vine
# --------------------------------------------
# Koc tested:  [ 369.  369.]
# Best Kd (Fresh):  6.270786 cm3/g ( Num:  1 )
#  x factor:  2
#  R2:  -1.63195767029
#  Effective Koc (fresh) - [cm3/g]: 184.5
# --------------------------------------------
# Best Kd (Aged):  6.270786 cm3/g ( Num:  2 )
#  x factor: No factor considered.
#  R2:  -0.360685605415
#  Effective Koc (aged) [cm3/g]: 369.0
# --------------------------------------------
# --------------------------------------------
# Scenario - modality - Predicted error prcnt (%) | Predicted | Observed |
# --------------------------------------------
# (A) 135 mm/h - Fresh  No obs | 3.23453854613 | nan
# (A) 135 mm/h - Aged  -39.3223914336 | 9.76909497919 | 16.1
# (B) 55 mm/h - Fresh  No obs | 25.9654180412 | nan
# (B) 55 mm/h - Aged  15.9052793649 | 30.483088473 | 26.3
# (C) 55 mm/h - Fresh  No obs | 150.961491164 | nan
# (C) 55 mm/h - Aged  201.279398585 | 78.7451101355 | 28.5
# (D) 30 mm/h - Fresh  113.992803231 | 59.5248393024 | 77.2
# (D) 30 mm/h - Aged  763.452018588 | 65.4845521662 | 3.4

# %% [markdown]
# ### Min values

# %%
initial_condition = 'min'

# %% [markdown]
# #### 1st Pulse

# %%
min_sterile_1st = pest_Kd_choice(
    Kd1_choice_sterile,
    x,
    initial_condition,
    pest_dict_S_1st,          
    pb_i1, pb_f1,
    percol_data1, runoff_data1,
    time_sizes1,
    area, soil_height1, 
    d, runoff_vel,
    soil,
    isFirstCycle = True,
    isLiving = False,
    KFILM = True)

output_pesti_params = extract_goodness_maxmin(
        min_sterile_1st,
        initial_condition,
        output_pesti_params,
        soil_short,
        isLiving = False,
        isFirstCycle = True)
# Out:
# 1st Pulse
# Sterile Vine
# --------------------------------------------
# Koc tested:  [ 369.  100.]
# Best Kd (Fresh):  7.554906 cm3/g ( Num:  1 )
#  x factor:  2
#  R2:  -2.7004835302
#  Effective Koc (fresh) - [cm3/g]: 184.5
# --------------------------------------------
# Best Kd (Aged):  2.0474 cm3/g ( Num:  2 )
#  x factor: No factor considered.
#  R2:  -24.7521777817
#  Effective Koc (aged) [cm3/g]: 100.0
# --------------------------------------------
# --------------------------------------------
# Scenario - modality - Predicted error prcnt (%) | Predicted | Observed |
# --------------------------------------------
# (A) 135 mm/h - Fresh  -79.8689063045 | 29.8946741378 | 148.5
# (A) 135 mm/h - Aged  -100.005497076 | -0.00612923991079 | 111.5
# (B) 55 mm/h - Fresh  -80.2838667822 | 31.5655292817 | 160.1
# (B) 55 mm/h - Aged  -100.007519357 | -0.00832392840791 | 110.7
# (C) 55 mm/h - Fresh  -14.509249578 | 160.979083045 | 188.3
# (C) 55 mm/h - Aged  -100.011435066 | -0.0269638845253 | 235.8
# (D) 30 mm/h - Fresh  -57.242408827 | 169.089611171 | 237.4
# (D) 30 mm/h - Aged  -100.015238855 | -0.0271075017152 | 142.8

# %%
min_living_1st = pest_Kd_choice(
    Kd1_choice_living,
    x,
    initial_condition,
    pest_dict_L_1st,          
    pb_i1, pb_f1,
    percol_data1, runoff_data1,
    time_sizes1,
    area, soil_height1, 
    d, runoff_vel,
    soil,
    isFirstCycle = True,
    isLiving = False,
    KFILM = True)

output_pesti_params = extract_goodness_maxmin(
        min_living_1st,
        initial_condition,
        output_pesti_params,
        soil_short,
        isLiving = True,
        isFirstCycle = True)
# Out:
# 1st Pulse
# Sterile Vine
# --------------------------------------------
# Koc tested:  [ 207.50708215  166.00566572]
# Best Kd (Fresh):  4.2485 cm3/g ( Num:  1 )
#  x factor:  2
#  R2:  -34.5523100915
#  Effective Koc (fresh) - [cm3/g]: 103.753541076
# --------------------------------------------
# Best Kd (Aged):  3.3988 cm3/g ( Num:  2 )
#  x factor: No factor considered.
#  R2:  -0.605078883416
#  Effective Koc (aged) [cm3/g]: 166.005665722
# --------------------------------------------
# --------------------------------------------
# Scenario - modality - Predicted error prcnt (%) | Predicted | Observed |
# --------------------------------------------
# (A) 135 mm/h - Fresh  -99.9918121799 | 0.00915398291698 | 111.8
# (A) 135 mm/h - Aged  -100.008142581 | -0.00302904028412 | 37.2
# (B) 55 mm/h - Fresh  -99.9912345219 | 0.00975597707177 | 111.3
# (B) 55 mm/h - Aged  -100.005288311 | -0.00419363037667 | 79.3
# (C) 55 mm/h - Fresh  -99.9883321985 | 0.0324831593506 | 278.4
# (C) 55 mm/h - Aged  -100.012701015 | -0.0198262850703 | 156.1
# (D) 30 mm/h - Fresh  -99.9817750764 | 0.0323791570131 | 142.0
# (D) 30 mm/h - Aged  -100.009713011 | -0.020627921985 | 134.7

# %% [markdown]
# #### 2nd Pulse

# %%
min_sterile_2nd = pest_Kd_choice(
    Kd2_choice_sterile,
    x,
    initial_condition,
    pest_dict_S_2nd,          
    pb_i2, pb_f2,
    percol_data2, runoff_data2,
    time_sizes2,
    area, soil_height2, 
    d, runoff_vel,
    soil,
    isFirstCycle = False,
    isLiving = False)

output_pesti_params = extract_goodness_maxmin(
        min_sterile_2nd,
        initial_condition,
        output_pesti_params,
        soil_short,
        isLiving = False,
        isFirstCycle = False)
# Out:
# 2nd Pulse
# Sterile Vine
# --------------------------------------------
# Koc tested:  [ 369.  200.]
# Best Kd (Fresh):  7.554906 cm3/g ( Num:  1 )
#  x factor:  2
#  R2:  0.942493183192
#  Effective Koc (fresh) - [cm3/g]: 184.5
# --------------------------------------------
# Best Kd (Aged):  4.0948 cm3/g ( Num:  2 )
#  x factor: No factor considered.
#  R2:  0.366803340965
#  Effective Koc (aged) [cm3/g]: 200.0
# --------------------------------------------
# --------------------------------------------
# Scenario - modality - Predicted error prcnt (%) | Predicted | Observed |
# --------------------------------------------
# (A) 135 mm/h - Fresh  No obs | 19.3643652522 | nan
# (A) 135 mm/h - Aged  -85.0438448194 | 4.35224115756 | 29.1
# (B) 55 mm/h - Fresh  No obs | 5.34402781591 | nan
# (B) 55 mm/h - Aged  -67.1453491477 | 13.5032615003 | 41.1
# (C) 55 mm/h - Fresh  No obs | 23.6638458398 | nan
# (C) 55 mm/h - Aged  -61.6961716243 | 27.9854274768 | 74.7
# (D) 30 mm/h - Fresh  19.9327419815 | 76.4941013925 | 40.5
# (D) 30 mm/h - Aged  -59.9830080289 | 23.7765292254 | 70.2

# %%
min_living_2nd = pest_Kd_choice(
    Kd2_choice_living,
    x,
    initial_condition,
    pest_dict_L_2nd,          
    pb_i2, pb_f2,
    percol_data2, runoff_data2,
    time_sizes2,
    area, soil_height2, 
    d, runoff_vel,
    soil,
    isFirstCycle = False,
    isLiving = True)

output_pesti_params = extract_goodness_maxmin(
        min_living_2nd,
        initial_condition,
        output_pesti_params,
        soil_short,
        isLiving = True,
        isFirstCycle = False)
# Out:
# 2nd Pulse
# Living Vine
# --------------------------------------------
# Koc tested:  [ 369.  369.]
# Best Kd (Fresh):  6.270786 cm3/g ( Num:  1 )
#  x factor:  2
#  R2:  0.748924151534
#  Effective Koc (fresh) - [cm3/g]: 184.5
# --------------------------------------------
# Best Kd (Aged):  6.270786 cm3/g ( Num:  2 )
#  x factor: No factor considered.
#  R2:  0.831123582626
#  Effective Koc (aged) [cm3/g]: 369.0
# --------------------------------------------
# --------------------------------------------
# Scenario - modality - Predicted error prcnt (%) | Predicted | Observed |
# --------------------------------------------
# (A) 135 mm/h - Fresh  No obs | 0.992639229577 | nan
# (A) 135 mm/h - Aged  -81.2607630785 | 3.01701714437 | 16.1
# (B) 55 mm/h - Fresh  No obs | 7.97011578633 | nan
# (B) 55 mm/h - Aged  -64.717702938 | 9.27924412731 | 26.3
# (C) 55 mm/h - Fresh  No obs | 42.8850466533 | nan
# (C) 55 mm/h - Aged  -10.8563850728 | 23.9705074972 | 28.5
# (D) 30 mm/h - Fresh  -35.2079268322 | 18.2674251004 | 77.2
# (D) 30 mm/h - Aged  157.674636552 | 20.2237788656 | 3.4

# %% [markdown]
# ### Hydrology summary

# %%
import pprint

# %% [markdown]
# ### R-squared

# %%
# 1st pulse
output_hydro_params[soil_short][0]['R1_FA']
# Out:
# [0.97167044953232651, 0.98950154118247413]

# %%
# 2nd pulse 
output_hydro_params[soil_short][0]['R2_ALL']
# Out:
# [0.98438832454669278]

# %% [markdown]
# ### Percent error

# %%
# 1st pulse
pprint.pprint(output_hydro_params[soil_short][0]['Err1'][0])
# Out:
# {'Aged': [-9.9497695760673803,
#           -3.8366274590119529,
#           -0.19171628147268441,
#           -10.681750947175953],
#  'Fresh': [-1.6576800420983793,
#            55.714529041314499,
#            4.5496322475756381,
#            1.1782456331323563]}

# %%
# 2nd pulse
pprint.pprint(output_hydro_params[soil_short][0]['Err2'][0])
# Out:
# {'LA': [2.3250655288884485,
#         1.775964240154662,
#         -6.8151479703231335,
#         -4.0853015171098992],
#  'LF': [inf, 3.5338818493703803, 2.2890248046824371, -9.7096493585817267],
#  'SA': [-0.62672046825181538,
#         -0.70217047263768517,
#         -5.7343333598281507,
#         9.7086063344151547],
#  'SF': [-12.514821129777932,
#         128.69226690973363,
#         363.76028617624922,
#         4.7695938511324218]}

# %% [markdown]
# ## Transport

# %% [markdown]
# ### Summary tables
#
# 0. High rainfall intensity (135 mm/h) at 6 min.
# 1. Medium rainfall intensity (55 mm/h) at 12 min.
# 2. Medium rainfall intensity (55 mm/h) at 30 min.
# 3. Low rainfall intensity (30 mm/h) at 30 min.
#
#     a) LA : Living Aged
#
#     b) LF : Living Fresh
#
#     c) SA : Sterile Aged
#
#     d) SF : Sterile Fresh
#
#
# To compute max and min simualtions, the optimal Kd values obtained from the mean scenario were used. That is, the model has not been fitted to consider these extreme uncertainty scenarios.
#
# - max: initial calculated concentration + measurement error
#
# - min: initial calculated concentraion - measurement error

# %%
import pandas as pd

# %% [markdown]
# ### Percent error

# %%
pd.DataFrame.from_dict(output_pesti_params[soil_short]['Err1'], orient='columns')
# Out:
#           LA       LAmax       LAmin         LF       LFmax      LFmin  \
# 0 -20.830235   59.749305 -100.008143 -48.636551   32.257859 -99.991812
# 1 -49.250636    3.751367 -100.005288 -30.709896   41.588767 -99.991235
# 2  16.166841  149.181222 -100.012701 -11.022133   88.469997 -99.988332
# 3 -10.981775   90.559560 -100.009713  38.169157  194.387191 -99.981775
#
#           SA       SAmax       SAmin         SF      SFmax      SFmin
# 0 -58.049063  -16.092630 -100.005497 -67.669711 -55.470516 -79.868906
# 1 -42.616026   14.775468 -100.007519 -68.336132 -56.388398 -80.283867
# 2 -12.733297   74.544840 -100.011435  37.297094  89.103439 -14.509250
# 3  16.295324  132.605887 -100.015239 -31.331834  -5.421259 -57.242409

# %%
pd.DataFrame.from_dict(output_pesti_params[soil_short]['Err2'], orient='columns')
# Out:
#            LA       LAmax       LAmin       LF    LFmax    LFmin         SA  \
# 0  -58.706811  -39.322391  -81.260763   No obs   No obs   No obs -67.626435
# 1  -21.514124   15.905279  -64.717703   No obs   No obs   No obs -28.907318
# 2   98.851684  201.279399  -10.856385   No obs   No obs   No obs -11.909406
# 3  478.058481  763.452019  157.674637  40.7219  113.993 -35.2079 -12.192811
#
#        SAmax      SAmin       SF    SFmax    SFmin
# 0 -50.209024 -85.043845   No obs   No obs   No obs
# 1   9.330714 -67.145349   No obs   No obs   No obs
# 2  37.877359 -61.696172   No obs   No obs   No obs
# 3  35.597385 -59.983008  161.509  303.085  19.9327

# %% [markdown]
# ### R-squared & Sorption parameters

# %%
# 1st and 2nd Pulse
df = pd.DataFrame.from_dict(output_pesti_params[soil_short], orient='columns') 
df2 = df[['R1', 'R2', 'Kd1', 'Kd2', 'Koc1', 'Koc2']].dropna(axis=0)
df2
# Out:
#           R1        R2       Kd1       Kd2   Koc1   Koc2
# LA  0.921940  0.601055  3.398800  6.270786  200.0  369.0
# LF -1.322493  0.664123  4.248500  6.270786  125.0  184.5
# SA -1.009452  0.918214  2.047400  4.094800  100.0  200.0
# SF -1.417325 -2.775523  7.554906  7.554906  184.5  184.5

# %%
path = '..\ModelParameters\\' + str(soil_short) + str(pesticide) + '.csv'
df2.to_csv(path, sep=';')
